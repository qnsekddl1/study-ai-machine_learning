# %% [markdown]
# ### ☝️정밀도와 재현율 수립
# - TP: 이 경우는 모델이 데이트가 있는 사람을 1로 예측했고, 실제로도 그 사람이 데이트가 있는 경우이다.
# 모델이 예측을 정확히 맞춘 경우이다.
# - FP: 모델이 데이트가 있다고 예측했지만 (1로 예측), 실제로는 데이트가 없는 사람 (0)을 데이트가 있다고 잘못 예측한 경우이다. (error 1)
# - TN: 모델이 데이트가 없다고 예측했고 (0으로 예측), 실제로 데이트가 없는 경우이다 (0).
# 이 경우에도 모델의 예측이 정확한 경우이다.
# - FN: 모델이 데이트가 없다고 예측했지만 (0으로 예측), 실제로는 그 사람이 데이트가 있는 경우이다.
# 이는 또 다른 유형의 오류로, 모델이 실제 상황을 잘못 예측한 경우이다. (error 2)

# %% [markdown]
# #### 🤔 과연 어떤 오류가 더 치멱정인 오류일까??
# (만약 발렌타인 데이에 프로모션을 진행한다고 가정을 한다.)
# 1. <strong>error 1의 경우는</strong> 프로모션의 대상이 되어야 할 사람들이 프로모션을 받지 못하게 된다.
#    즉, 잠재적 매출을 증가시킬 수 있는 <strong>고객을 놓치게 되고</strong>, 고객 충성도나 만족도에 <strong>부정적인 영향</strong>을 미칠 수 있다.
# 2. <strong>error 2의 경우는</strong> 프로모션 대상이 아닌 사람들에게도 프로모션이 제공되는 상황이다.
#    이러한 오류는 <strong>프로모션 비용의 낭비</strong>로 이어지게 된다. <strong>하지만 프로모션 대상이 아닌 사람들에게도 프로모션이 제공이 된다면</strong> 오히려 긍정적인 반응이 있을 수 있으므로, <strong>긍정적인 효과</strong>로 이어질 수 있다.
#
# #### 💡따라서, <strong>FN을 낮춰 재현율을 높이는 쪽</strong>이 적합한 방향일듯 하다.

# %%
import pandas as pd

df = pd.read_csv('./datasets/valentine_dataset.csv')
df
# Out:
#                   Name  Age  Gender  Income  Appearance_Score  \
# 0            Leon Cruz   26    Male   77648             63.94
# 1         Samuel Brown   23    Male   71617              2.50
# 2           Lori Baker   34    Male   38616             27.50
# 3      Tina Fitzgerald   37    Male   79473             22.32
# 4        Jason Simmons   38    Male   43510             73.65
# ...                ...  ...     ...     ...               ...
# 19995     Michael Vega   26  Female   36355             65.62
# 19996       Debra Horn   21  Female   55355             32.17
# 19997    Aaron Burgess   31    Male   31910             45.02
# 19998   Rebecca Morton   33  Female   22483             73.67
# 19999       Erik Curry   21    Male   51812             50.02
#
#        Interests_Score  Confidence_Score Educational_Status       Job_Type  \
# 0                88.18             30.09                Bsc       Employed
# 1                49.98             76.45                Bsc       Employed
# 2                33.90             33.76                PhD       Employed
# 3                25.47             43.32             Master  Self Employed
# 4                43.63             32.44                Bsc       Employed
# ...                ...               ...                ...            ...
# 19995            45.80             87.23        High School       Employed
# 19996            19.26              7.88        High School       Employed
# 19997            13.93             39.64                PhD  Self Employed
# 19998            64.29             29.53             Master  Self Employed
# 19999            47.97             45.85             Master  Self Employed
#
#        Valentine_Date
# 0                   1
# 1                   1
# 2                   1
# 3                   1
# 4                   0
# ...               ...
# 19995               0
# 19996               1
# 19997               1
# 19998               1
# 19999               0
#
# [20000 rows x 10 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Name                20000 non-null  object
#  1   Age                 20000 non-null  int64
#  2   Gender              20000 non-null  object
#  3   Income              20000 non-null  int64
#  4   Appearance_Score    20000 non-null  float64
#  5   Interests_Score     20000 non-null  float64
#  6   Confidence_Score    20000 non-null  float64
#  7   Educational_Status  20000 non-null  object
#  8   Job_Type            20000 non-null  object
#  9   Valentine_Date      20000 non-null  int64
# dtypes: float64(3), int64(3), object(4)
# memory usage: 1.5+ MB

# %%
df.isna().sum()
# Out:
# Name                  0
# Age                   0
# Gender                0
# Income                0
# Appearance_Score      0
# Interests_Score       0
# Confidence_Score      0
# Educational_Status    0
# Job_Type              0
# Valentine_Date        0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df['Educational_Status'].value_counts()
# Out:
# Educational_Status
# High School    5107
# Bsc            4985
# PhD            4955
# Master         4953
# Name: count, dtype: int64

# %%
df['Job_Type'].value_counts()
# Out:
# Job_Type
# Employed         10014
# Self Employed     9986
# Name: count, dtype: int64

# %%
df['Valentine_Date'].value_counts()
# Out:
# Valentine_Date
# 0    10134
# 1     9866
# Name: count, dtype: int64

# %% [markdown]
# 🤔 타겟 데이터의 비중이 맞지 않기 때문에 이후 진행 과정에서 over sampling의 방법 중 SMOTE를 사용하여 타겟 데이터의 비중을 맞춰 줘야할 것 같다.

# %%
# 1-1. 전처리 시작

pre_df = df.copy()
pre_df
# Out:
#                   Name  Age  Gender  Income  Appearance_Score  \
# 0            Leon Cruz   26    Male   77648             63.94
# 1         Samuel Brown   23    Male   71617              2.50
# 2           Lori Baker   34    Male   38616             27.50
# 3      Tina Fitzgerald   37    Male   79473             22.32
# 4        Jason Simmons   38    Male   43510             73.65
# ...                ...  ...     ...     ...               ...
# 19995     Michael Vega   26  Female   36355             65.62
# 19996       Debra Horn   21  Female   55355             32.17
# 19997    Aaron Burgess   31    Male   31910             45.02
# 19998   Rebecca Morton   33  Female   22483             73.67
# 19999       Erik Curry   21    Male   51812             50.02
#
#        Interests_Score  Confidence_Score Educational_Status       Job_Type  \
# 0                88.18             30.09                Bsc       Employed
# 1                49.98             76.45                Bsc       Employed
# 2                33.90             33.76                PhD       Employed
# 3                25.47             43.32             Master  Self Employed
# 4                43.63             32.44                Bsc       Employed
# ...                ...               ...                ...            ...
# 19995            45.80             87.23        High School       Employed
# 19996            19.26              7.88        High School       Employed
# 19997            13.93             39.64                PhD  Self Employed
# 19998            64.29             29.53             Master  Self Employed
# 19999            47.97             45.85             Master  Self Employed
#
#        Valentine_Date
# 0                   1
# 1                   1
# 2                   1
# 3                   1
# 4                   0
# ...               ...
# 19995               0
# 19996               1
# 19997               1
# 19998               1
# 19999               0
#
# [20000 rows x 10 columns]

# %%
# 1-2. 필요 없는 feature 삭제

pre_df = pre_df.drop(labels=['Name'], axis=1)
pre_df
# Out:
#        Age  Gender  Income  Appearance_Score  Interests_Score  \
# 0       26    Male   77648             63.94            88.18
# 1       23    Male   71617              2.50            49.98
# 2       34    Male   38616             27.50            33.90
# 3       37    Male   79473             22.32            25.47
# 4       38    Male   43510             73.65            43.63
# ...    ...     ...     ...               ...              ...
# 19995   26  Female   36355             65.62            45.80
# 19996   21  Female   55355             32.17            19.26
# 19997   31    Male   31910             45.02            13.93
# 19998   33  Female   22483             73.67            64.29
# 19999   21    Male   51812             50.02            47.97
#
#        Confidence_Score Educational_Status       Job_Type  Valentine_Date
# 0                 30.09                Bsc       Employed               1
# 1                 76.45                Bsc       Employed               1
# 2                 33.76                PhD       Employed               1
# 3                 43.32             Master  Self Employed               1
# 4                 32.44                Bsc       Employed               0
# ...                 ...                ...            ...             ...
# 19995             87.23        High School       Employed               0
# 19996              7.88        High School       Employed               1
# 19997             39.64                PhD  Self Employed               1
# 19998             29.53             Master  Self Employed               1
# 19999             45.85             Master  Self Employed               0
#
# [20000 rows x 9 columns]

# %%
# 1-3. feature name 수정

pre_df.rename(columns={
    'Gender': 'gender',
            'Age':'age',
            'Income':'income',
            'Appearance_Score': 'appearance_score',
            'Interests_Score':'interests_score',
            'Confidence_Score':'confidence_score',
            'Educational_Status':'educational_status',
            'Job_Type':'job_type',
            'Valentine_Date':'valentine_date'
}, inplace=True)
pre_df
# Out:
#        age  gender  income  appearance_score  interests_score  \
# 0       26    Male   77648             63.94            88.18
# 1       23    Male   71617              2.50            49.98
# 2       34    Male   38616             27.50            33.90
# 3       37    Male   79473             22.32            25.47
# 4       38    Male   43510             73.65            43.63
# ...    ...     ...     ...               ...              ...
# 19995   26  Female   36355             65.62            45.80
# 19996   21  Female   55355             32.17            19.26
# 19997   31    Male   31910             45.02            13.93
# 19998   33  Female   22483             73.67            64.29
# 19999   21    Male   51812             50.02            47.97
#
#        confidence_score educational_status       job_type  valentine_date
# 0                 30.09                Bsc       Employed               1
# 1                 76.45                Bsc       Employed               1
# 2                 33.76                PhD       Employed               1
# 3                 43.32             Master  Self Employed               1
# 4                 32.44                Bsc       Employed               0
# ...                 ...                ...            ...             ...
# 19995             87.23        High School       Employed               0
# 19996              7.88        High School       Employed               1
# 19997             39.64                PhD  Self Employed               1
# 19998             29.53             Master  Self Employed               1
# 19999             45.85             Master  Self Employed               0
#
# [20000 rows x 9 columns]

# %%
pre_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   age                 20000 non-null  int64
#  1   gender              20000 non-null  object
#  2   income              20000 non-null  int64
#  3   appearance_score    20000 non-null  float64
#  4   interests_score     20000 non-null  float64
#  5   confidence_score    20000 non-null  float64
#  6   educational_status  20000 non-null  object
#  7   job_type            20000 non-null  object
#  8   valentine_date      20000 non-null  int64
# dtypes: float64(3), int64(3), object(3)
# memory usage: 1.4+ MB

# %%
# 1-4. Dtype이 'object' 인 것들을 LabelEncoder를 사용해서 'int'로 변환

from sklearn.preprocessing import LabelEncoder

columns = ['gender', 'educational_status', 'job_type']
encoders = {}

for column in columns:
    encoder = LabelEncoder()
    pre_df[column] = encoder.fit_transform(pre_df[column])
    encoders[column] = encoder.classes_.tolist()
pre_df
# Out:
#        age  gender  income  appearance_score  interests_score  \
# 0       26       1   77648             63.94            88.18
# 1       23       1   71617              2.50            49.98
# 2       34       1   38616             27.50            33.90
# 3       37       1   79473             22.32            25.47
# 4       38       1   43510             73.65            43.63
# ...    ...     ...     ...               ...              ...
# 19995   26       0   36355             65.62            45.80
# 19996   21       0   55355             32.17            19.26
# 19997   31       1   31910             45.02            13.93
# 19998   33       0   22483             73.67            64.29
# 19999   21       1   51812             50.02            47.97
#
#        confidence_score  educational_status  job_type  valentine_date
# 0                 30.09                   0         0               1
# 1                 76.45                   0         0               1
# 2                 33.76                   3         0               1
# 3                 43.32                   2         1               1
# 4                 32.44                   0         0               0
# ...                 ...                 ...       ...             ...
# 19995             87.23                   1         0               0
# 19996              7.88                   1         0               1
# 19997             39.64                   3         1               1
# 19998             29.53                   2         1               1
# 19999             45.85                   2         1               0
#
# [20000 rows x 9 columns]

# %%
encoders
# Out:
# {'gender': ['Female', 'Male'],
#  'educational_status': ['Bsc', 'High School', 'Master', 'PhD'],
#  'job_type': ['Employed', 'Self Employed']}

# %%
pre_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   age                 20000 non-null  int64
#  1   gender              20000 non-null  int32
#  2   income              20000 non-null  int64
#  3   appearance_score    20000 non-null  float64
#  4   interests_score     20000 non-null  float64
#  5   confidence_score    20000 non-null  float64
#  6   educational_status  20000 non-null  int32
#  7   job_type            20000 non-null  int32
#  8   valentine_date      20000 non-null  int64
# dtypes: float64(3), int32(3), int64(3)
# memory usage: 1.1 MB

# %%
# 1-5. 이상치 제거 StandardScaler 사용
std_pre_df = pre_df.copy()

from sklearn.preprocessing import StandardScaler

columns = ['age', 'income', 'appearance_score', 'interests_score', 'confidence_score']

std = StandardScaler()

scaled_columns = std.fit_transform(pre_df[columns])

std_pre_df[columns] = scaled_columns

# %%
std_pre_df.hist(figsize=(10,20))
# Out:
# array([[<Axes: title={'center': 'age'}>,
#         <Axes: title={'center': 'gender'}>,
#         <Axes: title={'center': 'income'}>],
#        [<Axes: title={'center': 'appearance_score'}>,
#         <Axes: title={'center': 'interests_score'}>,
#         <Axes: title={'center': 'confidence_score'}>],
#        [<Axes: title={'center': 'educational_status'}>,
#         <Axes: title={'center': 'job_type'}>,
#         <Axes: title={'center': 'valentine_date'}>]], dtype=object)

# %%
# <img src="./images/visual/vd/std_pre_d_hist.png">

# %%
feature_names = ['age', 'income', 'appearance_score', 'interests_score', 'confidence_score']
features = std_pre_df[feature_names]

for column in features.columns:
    std_pre_df.drop(
        std_pre_df[~std_pre_df[column].between(-1.96, 1.96)].index, 
        axis=0, 
        inplace=True)
    
for column in features.columns:
    print(f'{column}: {std_pre_df[~std_pre_df[column].between(-1.96, 1.96)].shape[0]}건')
# Out:
# age: 0건
# income: 0건
# appearance_score: 0건
# interests_score: 0건
# confidence_score: 0건

# %%
std_pre_df
# Out:
#             age  gender    income  appearance_score  interests_score  \
# 0     -0.458119       1  1.592499          0.478004         1.328635
# 1     -0.911135       1  1.244477         -1.649649         0.001020
# 2      0.749922       1 -0.659865         -0.783905        -0.557829
# 3      1.202937       1  1.697812         -0.963287        -0.850808
# 4      1.353942       1 -0.377454          0.814259        -0.219670
# ...         ...     ...       ...               ...              ...
# 19995 -0.458119       0 -0.790338          0.536182        -0.144253
# 19996 -1.213145       0  0.306068         -0.622184        -1.066632
# 19997  0.296906       1 -1.046839         -0.177191        -1.251873
# 19998  0.598916       0 -1.590829          0.814952         0.498355
# 19999 -1.213145       1  0.101618         -0.004042        -0.068836
#
#        confidence_score  educational_status  job_type  valentine_date
# 0             -0.684104                   0         0               1
# 1              0.915729                   0         0               1
# 2             -0.557457                   3         0               1
# 3             -0.227552                   2         1               1
# 4             -0.603008                   0         0               0
# ...                 ...                 ...       ...             ...
# 19995          1.287735                   1         0               0
# 19996         -1.450547                   1         0               1
# 19997         -0.354544                   3         1               1
# 19998         -0.703429                   2         1               1
# 19999         -0.140244                   2         1               0
#
# [20000 rows x 9 columns]

# %%
pre_df = std_pre_df

# %%
pre_df
# Out:
#             age  gender    income  appearance_score  interests_score  \
# 0     -0.458119       1  1.592499          0.478004         1.328635
# 1     -0.911135       1  1.244477         -1.649649         0.001020
# 2      0.749922       1 -0.659865         -0.783905        -0.557829
# 3      1.202937       1  1.697812         -0.963287        -0.850808
# 4      1.353942       1 -0.377454          0.814259        -0.219670
# ...         ...     ...       ...               ...              ...
# 19995 -0.458119       0 -0.790338          0.536182        -0.144253
# 19996 -1.213145       0  0.306068         -0.622184        -1.066632
# 19997  0.296906       1 -1.046839         -0.177191        -1.251873
# 19998  0.598916       0 -1.590829          0.814952         0.498355
# 19999 -1.213145       1  0.101618         -0.004042        -0.068836
#
#        confidence_score  educational_status  job_type  valentine_date
# 0             -0.684104                   0         0               1
# 1              0.915729                   0         0               1
# 2             -0.557457                   3         0               1
# 3             -0.227552                   2         1               1
# 4             -0.603008                   0         0               0
# ...                 ...                 ...       ...             ...
# 19995          1.287735                   1         0               0
# 19996         -1.450547                   1         0               1
# 19997         -0.354544                   3         1               1
# 19998         -0.703429                   2         1               1
# 19999         -0.140244                   2         1               0
#
# [20000 rows x 9 columns]

# %%
# 이상치 없음

# %%
corr = pre_df.corr()
corr[['valentine_date']].sort_values(by='valentine_date', ascending=False)[1:]
# Out:
#                     valentine_date
# age                       0.009658
# job_type                  0.008582
# confidence_score          0.006903
# educational_status        0.004948
# interests_score          -0.003844
# appearance_score         -0.005922
# income                   -0.010257
# gender                   -0.011438

# %%
import seaborn as sns
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(10, 7))
heatmap = sns.heatmap(corr, cmap='Reds')
heatmap.set_title('Correlation')
# Out:
# Text(0.5, 1.0, 'Correlation')

# %% [markdown]
# ### 1. DTC (DecissionTree Classifier)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE

dtc = DecisionTreeClassifier()

features, targets = pre_df.iloc[:,:-1], pre_df.iloc[:,-1]

X_train, X_test, y_train, y_test = \
train_test_split(features, targets, test_size=0.2, random_state=124)

smote = SMOTE(random_state=124)
X_train_over, y_train_over = smote.fit_resample(X_train, y_train)

dtc.fit(X_train_over.values, y_train_over)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# #### graphviz 확인

# %%
class_names = targets.unique().astype(str)
class_names
# Out:
# array(['1', '0'], dtype='<U21')

# %%
from sklearn.tree import export_graphviz

export_graphviz(
    dtc, 
    out_file='./images/pre_dtc01.dot', 
    class_names=class_names, 
    feature_names=features.columns,
    impurity=True, 
    filled=True
)

# %%
import graphviz

with open('./images/pre_dtc01.dot') as f:
    pre_dtc01 = f.read()

pre_dtc01_graph = graphviz.Source(pre_dtc01)

# %%
pre_dtc01_graph.render(filename='pre_dtc01', directory='./images', format='png')
# Out:
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.179185 to fit
# 'images\\pre_dtc01.png'

# %% [markdown]
# <img src='./images/pre_dtc01.png'>

# %%
from sklearn.metrics import accuracy_score

accuracy_score(y_test, dtc.predict(X_test))
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:432: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# 0.50025

# %%
dtc.get_params()
# Out:
# {'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': None,
#  'max_features': None,
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'random_state': None,
#  'splitter': 'best'}

# %%
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.tree import DecisionTreeClassifier
from imblearn.over_sampling import SMOTE

features, targets = pre_df.iloc[:, :-1], pre_df.iloc[:, -1]

X_train, X_test, y_train, y_test = \
train_test_split(features, targets, test_size=0.2, stratify=targets, random_state=124)

dtc = DecisionTreeClassifier()
parameters = {'max_depth': range(40, 49), 'min_samples_split': [110, 120, 130, 140, 150]}

g_dtc = GridSearchCV(dtc, param_grid=parameters, cv=10, refit=True, return_train_score=True, n_jobs=-1)

g_dtc.fit(X_train_over, y_train_over)

pd.DataFrame(g_dtc.cv_results_)[['params', 'mean_test_score', 'rank_test_score', 
           'split0_test_score', 'split1_test_score', 'split2_test_score']]
# Out:
#                                          params  mean_test_score  \
# 0   {'max_depth': 40, 'min_samples_split': 110}         0.505568
# 1   {'max_depth': 40, 'min_samples_split': 120}         0.503898
# 2   {'max_depth': 40, 'min_samples_split': 130}         0.504394
# 3   {'max_depth': 40, 'min_samples_split': 140}         0.504023
# 4   {'max_depth': 40, 'min_samples_split': 150}         0.502477
# 5   {'max_depth': 41, 'min_samples_split': 110}         0.504578
# 6   {'max_depth': 41, 'min_samples_split': 120}         0.504022
# 7   {'max_depth': 41, 'min_samples_split': 130}         0.504332
# 8   {'max_depth': 41, 'min_samples_split': 140}         0.503219
# 9   {'max_depth': 41, 'min_samples_split': 150}         0.502477
# 10  {'max_depth': 42, 'min_samples_split': 110}         0.505074
# 11  {'max_depth': 42, 'min_samples_split': 120}         0.504455
# 12  {'max_depth': 42, 'min_samples_split': 130}         0.504703
# 13  {'max_depth': 42, 'min_samples_split': 140}         0.502786
# 14  {'max_depth': 42, 'min_samples_split': 150}         0.504209
# 15  {'max_depth': 43, 'min_samples_split': 110}         0.505816
# 16  {'max_depth': 43, 'min_samples_split': 120}         0.504517
# 17  {'max_depth': 43, 'min_samples_split': 130}         0.505198
# 18  {'max_depth': 43, 'min_samples_split': 140}         0.502909
# 19  {'max_depth': 43, 'min_samples_split': 150}         0.502600
# 20  {'max_depth': 44, 'min_samples_split': 110}         0.504517
# 21  {'max_depth': 44, 'min_samples_split': 120}         0.504765
# 22  {'max_depth': 44, 'min_samples_split': 130}         0.504456
# 23  {'max_depth': 44, 'min_samples_split': 140}         0.502971
# 24  {'max_depth': 44, 'min_samples_split': 150}         0.503033
# 25  {'max_depth': 45, 'min_samples_split': 110}         0.504579
# 26  {'max_depth': 45, 'min_samples_split': 120}         0.503837
# 27  {'max_depth': 45, 'min_samples_split': 130}         0.504580
# 28  {'max_depth': 45, 'min_samples_split': 140}         0.503714
# 29  {'max_depth': 45, 'min_samples_split': 150}         0.502477
# 30  {'max_depth': 46, 'min_samples_split': 110}         0.504517
# 31  {'max_depth': 46, 'min_samples_split': 120}         0.503589
# 32  {'max_depth': 46, 'min_samples_split': 130}         0.504765
# 33  {'max_depth': 46, 'min_samples_split': 140}         0.502909
# 34  {'max_depth': 46, 'min_samples_split': 150}         0.503034
# 35  {'max_depth': 47, 'min_samples_split': 110}         0.506311
# 36  {'max_depth': 47, 'min_samples_split': 120}         0.504269
# 37  {'max_depth': 47, 'min_samples_split': 130}         0.504703
# 38  {'max_depth': 47, 'min_samples_split': 140}         0.504023
# 39  {'max_depth': 47, 'min_samples_split': 150}         0.502229
# 40  {'max_depth': 48, 'min_samples_split': 110}         0.505568
# 41  {'max_depth': 48, 'min_samples_split': 120}         0.504703
# 42  {'max_depth': 48, 'min_samples_split': 130}         0.504579
# 43  {'max_depth': 48, 'min_samples_split': 140}         0.502971
# 44  {'max_depth': 48, 'min_samples_split': 150}         0.502972
#
#     rank_test_score  split0_test_score  split1_test_score  split2_test_score
# 0                 3           0.507730           0.504638           0.517007
# 1                28           0.508349           0.501546           0.515152
# 2                21           0.500928           0.502165           0.515770
# 3                25           0.497217           0.502783           0.514533
# 4                43           0.500309           0.499691           0.520099
# 5                15           0.504638           0.504638           0.517007
# 6                27           0.508349           0.501546           0.515152
# 7                22           0.500928           0.502165           0.515770
# 8                32           0.497217           0.502783           0.514533
# 9                42           0.500309           0.499691           0.520099
# 10                6           0.506494           0.504020           0.517007
# 11               20           0.506494           0.501546           0.517625
# 12                9           0.499691           0.502165           0.515770
# 13               40           0.496599           0.502783           0.514533
# 14               24           0.500309           0.499691           0.520099
# 15                2           0.505257           0.504020           0.517007
# 16               16           0.503401           0.501546           0.517625
# 17                5           0.502165           0.502165           0.515770
# 18               39           0.499691           0.502783           0.514533
# 19               41           0.499072           0.499691           0.520099
# 20               17           0.505257           0.503401           0.517007
# 21                8           0.506494           0.501546           0.517625
# 22               19           0.502783           0.502165           0.515770
# 23               36           0.498454           0.502783           0.514533
# 24               34           0.501546           0.499691           0.520099
# 25               14           0.507730           0.503401           0.517007
# 26               29           0.508349           0.501546           0.515152
# 27               12           0.505257           0.500928           0.515770
# 28               30           0.499691           0.502783           0.514533
# 29               43           0.500309           0.499691           0.520099
# 30               18           0.507112           0.504020           0.517007
# 31               31           0.503401           0.501546           0.517625
# 32                7           0.503401           0.500928           0.515770
# 33               38           0.496599           0.502783           0.514533
# 34               33           0.500309           0.499691           0.520099
# 35                1           0.509586           0.504020           0.517007
# 36               23           0.506494           0.501546           0.517625
# 37                9           0.499691           0.502165           0.515770
# 38               26           0.499691           0.502783           0.514533
# 39               45           0.500309           0.499691           0.520099
# 40                4           0.507112           0.503401           0.517007
# 41               11           0.503401           0.501546           0.517625
# 42               13           0.502165           0.502165           0.515770
# 43               36           0.498454           0.502783           0.514533
# 44               35           0.500309           0.499691           0.520099

# %%
g_dtc.best_estimator_
# Out:
# DecisionTreeClassifier(max_depth=47, min_samples_split=110)

# %%
from sklearn.metrics import accuracy_score
import numpy as np

dtc = g_dtc.best_estimator_
prediction = dtc.predict(X_test)

print(f'정확도: {np.round(accuracy_score(y_test, prediction) * 100, 4)}%')
# Out:
# 정확도: 63.275%

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt


# 타겟 데이터와 예측 객체를 전달받는다.
def get_evaluation(y_test, prediction, classifier=None, X_test=None):
#     오차 행렬
    confusion = confusion_matrix(y_test, prediction)
#     정확도
    accuracy = accuracy_score(y_test , prediction)
#     정밀도
    precision = precision_score(y_test , prediction)
#     재현율
    recall = recall_score(y_test , prediction)
#     F1 score
    f1 = f1_score(y_test, prediction)
#     ROC-AUC
    roc_auc = roc_auc_score(y_test, prediction)
    
    print('오차 행렬')
    print(confusion)
    print('정확도: {0:.4f}, 정밀도: {1:.4f}, 재현율: {2:.4f}, F1: {3:.4f}, ROC-AUC: {4:.4f}'.format(accuracy, precision, recall, f1, roc_auc))
    print("#" * 80)
    
    if classifier is not None and  X_test is not None:
        fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(8,4))
        titles_options = [("Confusion matrix", None), ("Normalized confusion matrix", "true")]

        for (title, normalize), ax in zip(titles_options, axes.flatten()):
            disp = ConfusionMatrixDisplay.from_estimator(classifier, X_test, y_test, ax=ax, cmap=plt.cm.Blues, normalize=normalize)
            disp.ax_.set_title(title)
        plt.show()

# %%
# [0.49038461538461536, 0.5096153846153846] 1
# [0.5348837209302325, 0.46511627906976744] 0
# [0.5, 0.5] 0
# [0.4594594594594595, 0.5405405405405406] 1
# [0.21428571428571427, 0.7857142857142857] 1
# [0.7037037037037037, 0.2962962962962963] 0
# [0.3711340206185567, 0.6288659793814433] 1
# [0.6410256410256411, 0.358974358974359] 0

# %%
from sklearn.preprocessing import Binarizer

threshold = 0.5

proba = dtc.predict_proba(X_test)
prediction = dtc.predict(X_test)

# %%
custom_proba = proba[:, 1].reshape(-1, 1)
binarizer = Binarizer(threshold=threshold).fit(custom_proba)
custom_prediction = binarizer.transform(custom_proba)

get_evaluation(y_test, custom_prediction)
# Out:
# 오차 행렬
# [[1239  788]
#  [ 681 1292]]
# 정확도: 0.6328, 정밀도: 0.6212, 재현율: 0.6548, F1: 0.6376, ROC-AUC: 0.6330
# ################################################################################

# %%
def get_evaluation_by_thresholds(y_test, proba_class1, thresholds):
    for threshold in thresholds:
        print(threshold)
        binarizer = Binarizer(threshold=threshold).fit(proba_class1)
        custom_prediction = binarizer.transform(proba_class1)
        get_evaluation(y_test, custom_prediction)

# %%
from sklearn.metrics import precision_recall_curve
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

def precision_recall_curve_plot(y_test , proba_class1):

    precisions, recalls, thresholds = precision_recall_curve(y_test, proba_class1)
    
    plt.figure(figsize=(8,6))
    threshold_boundary = thresholds.shape[0]
    plt.plot(thresholds, precisions[0:threshold_boundary], linestyle='--', label='precision')
    plt.plot(thresholds, recalls[0:threshold_boundary],label='recall')
    
    # X축(threshold)의 Scale을 0 ~ 1 단위로 변경
    start, end = plt.xlim()
    plt.xticks(np.round(np.arange(start, end, 0.1),2))
    
    plt.xlabel('Threshold value'); plt.ylabel('Precision and Recall value')
    plt.legend()
    plt.grid()
    plt.show()
    
precision_recall_curve_plot(y_test, dtc.predict_proba(X_test)[:, 1].reshape(-1, 1))

# %%
from sklearn.metrics import roc_curve

def roc_curve_plot(y_test , proba_class1):
#     임계값에 따른 FPR, TPR 값
    fprs, tprs, thresholds = roc_curve(y_test, proba_class1)

#     ROC Curve를 plot 곡선으로 그림. 
    plt.plot(fprs , tprs, label='ROC')
#     가운데 대각선 직선을 그림. 
#     TPR과 FPR이 동일한 비율로 떨어진다는 것은 모델이 양성과 음성을 구별하지 못한다는 것을 의미한다.
#     다른 분류기를 판단하기 위한 기준선으로 사용되며, 
#     대각선에 가까울 수록 예측에 사용하기 힘든 모델이라는 뜻이다.
    plt.plot([0, 1], [0, 1], 'k--', label='Standard')
    
    # X축(FPR)의 Scale을 0.1 단위로 변경
    start, end = plt.xlim()
    plt.xticks(np.round(np.arange(start, end, 0.1),2))
    plt.xlim(0,1); plt.ylim(0,1)
    plt.xlabel('FPR( 1 - Sensitivity )'); plt.ylabel('TPR( Recall )')
    plt.legend()
    plt.show()
    
roc_curve_plot(y_test, dtc.predict_proba(X_test)[:, 1].reshape(-1, 1))

# %%
from sklearn.metrics import accuracy_score

dtc = g_dtc.best_estimator_
prediction = dtc.predict(X_test)

print(f'정확도: {np.round(accuracy_score(y_test, prediction) * 100, 4)}%')
# Out:
# 정확도: 63.275%

# %%
proba_class1 = dtc.predict_proba(X_test)[:, 1].reshape(-1, 1)
_, _, thresholds = precision_recall_curve(y_test, proba_class1)
thresholds
# Out:
# array([0.        , 0.07692308, 0.09090909, 0.1       , 0.10526316,
#        0.11111111, 0.125     , 0.14285714, 0.15      , 0.15384615,
#        0.16666667, 0.17241379, 0.18181818, 0.18461538, 0.1875    ,
#        0.19047619, 0.19354839, 0.2       , 0.20588235, 0.21052632,
#        0.21428571, 0.21568627, 0.22222222, 0.22727273, 0.23076923,
#        0.9       , 0.9047619 , 0.90909091, 0.91666667, 0.9375    ,
#        1.        ])

# %%
get_evaluation_by_thresholds(y_test, proba_class1, thresholds)
# Out:
# 0.0
# 오차 행렬
# [[  29 1998]
#  [   2 1971]]
# 정확도: 0.5000, 정밀도: 0.4966, 재현율: 0.9990, F1: 0.6634, ROC-AUC: 0.5066
# ################################################################################
# 0.07692307692307693
# 오차 행렬
# [[  34 1993]
#  [   4 1969]]
# 정확도: 0.5008, 정밀도: 0.4970, 재현율: 0.9980, F1: 0.6635, ROC-AUC: 0.5074
# ################################################################################
# 0.09090909090909091
# 오차 행렬
# [[  35 1992]
#  [   5 1968]]
# 정확도: 0.5008, 정밀도: 0.4970, 재현율: 0.9975, F1: 0.6634, ROC-AUC: 0.5074
# ################################################################################
# 0.1
# 오차 행렬
# [[  36 1991]
#  [   5 1968]]
# 정확도: 0.5010, 정밀도: 0.4971, 재현율: 0.9975, F1: 0.6635, ROC-AUC: 0.5076
# ################################################################################
# 0.10526315789473684
# 오차 행렬
# [[  42 1985]
#  [   5 1968]]
# 정확도: 0.5025, 정밀도: 0.4978, 재현율: 0.9975, F1: 0.6642, ROC-AUC: 0.5091
# ################################################################################
# 0.1111111111111111
# 오차 행렬
# [[  62 1965]
#  [  11 1962]]
# 정확도: 0.5060, 정밀도: 0.4996, 재현율: 0.9944, F1: 0.6651, ROC-AUC: 0.5125
# ################################################################################
# 0.125
# 오차 행렬
# [[  69 1958]
#  [  11 1962]]
# 정확도: 0.5078, 정밀도: 0.5005, 재현율: 0.9944, F1: 0.6659, ROC-AUC: 0.5142
# ################################################################################
# 0.14285714285714285
# 오차 행렬
# [[  83 1944]
#  [  14 1959]]
# 정확도: 0.5105, 정밀도: 0.5019, 재현율: 0.9929, F1: 0.6668, ROC-AUC: 0.5169
# ################################################################################
# 0.15
# 오차 행렬
# [[  85 1942]
#  [  16 1957]]
# 정확도: 0.5105, 정밀도: 0.5019, 재현율: 0.9919, F1: 0.6666, ROC-AUC: 0.5169
# ################################################################################
# 0.15384615384615385
# 오차 행렬
# [[  94 1933]
#  [  17 1956]]
# 정확도: 0.5125, 정밀도: 0.5030, 재현율: 0.9914, F1: 0.6673, ROC-AUC: 0.5189
# ################################################################################
# 0.16666666666666666
# 오차 행렬
# [[ 101 1926]
#  [  18 1955]]
# 정확도: 0.5140, 정밀도: 0.5037, 재현율: 0.9909, F1: 0.6679, ROC-AUC: 0.5204
# ################################################################################
# 0.1724137931034483
# 오차 행렬
# [[ 105 1922]
#  [  19 1954]]
# 정확도: 0.5148, 정밀도: 0.5041, 재현율: 0.9904, F1: 0.6681, ROC-AUC: 0.5211
# ################################################################################
# 0.18181818181818182
# 오차 행렬
# [[ 108 1919]
#  [  21 1952]]
# 정확도: 0.5150, 정밀도: 0.5043, 재현율: 0.9894, F1: 0.6680, ROC-AUC: 0.5213
# ################################################################################
# 0.18461538461538463
# 오차 행렬
# [[ 121 1906]
#  [  24 1949]]
# 정확도: 0.5175, 정밀도: 0.5056, 재현율: 0.9878, F1: 0.6688, ROC-AUC: 0.5238
# ################################################################################
# 0.1875
# 오차 행렬
# [[ 123 1904]
#  [  24 1949]]
# 정확도: 0.5180, 정밀도: 0.5058, 재현율: 0.9878, F1: 0.6691, ROC-AUC: 0.5243
# ################################################################################
# 0.19047619047619047
# 오차 행렬
# [[ 132 1895]
#  [  27 1946]]
# 정확도: 0.5195, 정밀도: 0.5066, 재현율: 0.9863, F1: 0.6694, ROC-AUC: 0.5257
# ################################################################################
# 0.1935483870967742
# 오차 행렬
# [[ 141 1886]
#  [  33 1940]]
# 정확도: 0.5202, 정밀도: 0.5071, 재현율: 0.9833, F1: 0.6691, ROC-AUC: 0.5264
# ################################################################################
# 0.2
# 오차 행렬
# [[ 163 1864]
#  [  40 1933]]
# 정확도: 0.5240, 정밀도: 0.5091, 재현율: 0.9797, F1: 0.6700, ROC-AUC: 0.5301
# ################################################################################
# 0.20588235294117646
# 오차 행렬
# [[ 172 1855]
#  [  41 1932]]
# 정확도: 0.5260, 정밀도: 0.5102, 재현율: 0.9792, F1: 0.6708, ROC-AUC: 0.5320
# ################################################################################
# 0.21052631578947367
# 오차 행렬
# [[ 183 1844]
#  [  45 1928]]
# 정확도: 0.5278, 정밀도: 0.5111, 재현율: 0.9772, F1: 0.6712, ROC-AUC: 0.5337
# ################################################################################
# 0.21428571428571427
# 오차 행렬
# [[ 190 1837]
#  [  45 1928]]
# 정확도: 0.5295, 정밀도: 0.5121, 재현율: 0.9772, F1: 0.6720, ROC-AUC: 0.5355
# ################################################################################
# 0.21568627450980393
# 오차 행렬
# [[ 199 1828]
#  [  48 1925]]
# 정확도: 0.5310, 정밀도: 0.5129, 재현율: 0.9757, F1: 0.6724, ROC-AUC: 0.5369
# ################################################################################
# 0.2222222222222222
# 오차 행렬
# [[ 221 1806]
#  [  54 1919]]
# 정확도: 0.5350, 정밀도: 0.5152, 재현율: 0.9726, F1: 0.6736, ROC-AUC: 0.5408
# ################################################################################
# 0.22727272727272727
# 오차 행렬
# [[ 231 1796]
#  [  57 1916]]
# 정확도: 0.5367, 정밀도: 0.5162, 재현율: 0.9711, F1: 0.6741, ROC-AUC: 0.5425
# ################################################################################
# 0.23076923076923078
# 오차 행렬
# [[ 243 1784]
#  [  61 1912]]
# 정확도: 0.5387, 정밀도: 0.5173, 재현율: 0.9691, F1: 0.6745, ROC-AUC: 0.5445
# ################################################################################
# 0.23333333333333334
# 오차 행렬
# [[ 253 1774]
#  [  68 1905]]
# 정확도: 0.5395, 정밀도: 0.5178, 재현율: 0.9655, F1: 0.6741, ROC-AUC: 0.5452
# ################################################################################
# 0.23529411764705882
# 오차 행렬
# [[ 254 1773]
#  [  69 1904]]
# 정확도: 0.5395, 정밀도: 0.5178, 재현율: 0.9650, F1: 0.6740, ROC-AUC: 0.5452
# ################################################################################
# 0.24
# 오차 행렬
# [[ 257 1770]
#  [  71 1902]]
# 정확도: 0.5397, 정밀도: 0.5180, 재현율: 0.9640, F1: 0.6739, ROC-AUC: 0.5454
# ################################################################################
# 0.24285714285714285
# 오차 행렬
# [[ 269 1758]
#  [  76 1897]]
# 정확도: 0.5415, 정밀도: 0.5190, 재현율: 0.9615, F1: 0.6741, ROC-AUC: 0.5471
# ################################################################################
# 0.25
# 오차 행렬
# [[ 278 1749]
#  [  82 1891]]
# 정확도: 0.5423, 정밀도: 0.5195, 재현율: 0.9584, F1: 0.6738, ROC-AUC: 0.5478
# ################################################################################
# 0.25806451612903225
# 오차 행렬
# [[ 284 1743]
#  [  83 1890]]
# 정확도: 0.5435, 정밀도: 0.5202, 재현율: 0.9579, F1: 0.6743, ROC-AUC: 0.5490
# ################################################################################
# 0.25925925925925924
# 오차 행렬
# [[ 292 1735]
#  [  84 1889]]
# 정확도: 0.5453, 정밀도: 0.5212, 재현율: 0.9574, F1: 0.6750, ROC-AUC: 0.5507
# ################################################################################
# 0.2619047619047619
# 오차 행렬
# [[ 295 1732]
#  [  86 1887]]
# 정확도: 0.5455, 정밀도: 0.5214, 재현율: 0.9564, F1: 0.6749, ROC-AUC: 0.5510
# ################################################################################
# 0.26666666666666666
# 오차 행렬
# [[ 322 1705]
#  [  92 1881]]
# 정확도: 0.5507, 정밀도: 0.5245, 재현율: 0.9534, F1: 0.6767, ROC-AUC: 0.5561
# ################################################################################
# 0.2682926829268293
# 오차 행렬
# [[ 325 1702]
#  [  95 1878]]
# 정확도: 0.5507, 정밀도: 0.5246, 재현율: 0.9518, F1: 0.6764, ROC-AUC: 0.5561
# ################################################################################
# 0.2692307692307692
# 오차 행렬
# [[ 328 1699]
#  [  98 1875]]
# 정확도: 0.5507, 정밀도: 0.5246, 재현율: 0.9503, F1: 0.6760, ROC-AUC: 0.5561
# ################################################################################
# 0.2727272727272727
# 오차 행렬
# [[ 346 1681]
#  [ 106 1867]]
# 정확도: 0.5533, 정밀도: 0.5262, 재현율: 0.9463, F1: 0.6763, ROC-AUC: 0.5585
# ################################################################################
# 0.27450980392156865
# 오차 행렬
# [[ 367 1660]
#  [ 111 1862]]
# 정확도: 0.5573, 정밀도: 0.5287, 재현율: 0.9437, F1: 0.6777, ROC-AUC: 0.5624
# ################################################################################
# 0.27692307692307694
# 오차 행렬
# [[ 378 1649]
#  [ 116 1857]]
# 정확도: 0.5587, 정밀도: 0.5297, 재현율: 0.9412, F1: 0.6779, ROC-AUC: 0.5638
# ################################################################################
# 0.28
# 오차 행렬
# [[ 392 1635]
#  [ 122 1851]]
# 정확도: 0.5607, 정밀도: 0.5310, 재현율: 0.9382, F1: 0.6781, ROC-AUC: 0.5658
# ################################################################################
# 0.28125
# 오차 행렬
# [[ 397 1630]
#  [ 125 1848]]
# 정확도: 0.5613, 정밀도: 0.5313, 재현율: 0.9366, F1: 0.6780, ROC-AUC: 0.5663
# ################################################################################
# 0.2839506172839506
# 오차 행렬
# [[ 404 1623]
#  [ 133 1840]]
# 정확도: 0.5610, 정밀도: 0.5313, 재현율: 0.9326, F1: 0.6770, ROC-AUC: 0.5659
# ################################################################################
# 0.28440366972477066
# 오차 행렬
# [[ 417 1610]
#  [ 142 1831]]
# 정확도: 0.5620, 정밀도: 0.5321, 재현율: 0.9280, F1: 0.6764, ROC-AUC: 0.5669
# ################################################################################
# 0.2857142857142857
# 오차 행렬
# [[ 430 1597]
#  [ 147 1826]]
# 정확도: 0.5640, 정밀도: 0.5335, 재현율: 0.9255, F1: 0.6768, ROC-AUC: 0.5688
# ################################################################################
# 0.2894736842105263
# 오차 행렬
# [[ 432 1595]
#  [ 151 1822]]
# 정확도: 0.5635, 정밀도: 0.5332, 재현율: 0.9235, F1: 0.6761, ROC-AUC: 0.5683
# ################################################################################
# 0.2903225806451613
# 오차 행렬
# [[ 440 1587]
#  [ 155 1818]]
# 정확도: 0.5645, 정밀도: 0.5339, 재현율: 0.9214, F1: 0.6761, ROC-AUC: 0.5693
# ################################################################################
# 0.2962962962962963
# 오차 행렬
# [[ 457 1570]
#  [ 170 1803]]
# 정확도: 0.5650, 정밀도: 0.5345, 재현율: 0.9138, F1: 0.6745, ROC-AUC: 0.5696
# ################################################################################
# 0.2972972972972973
# 오차 행렬
# [[ 467 1560]
#  [ 170 1803]]
# 정확도: 0.5675, 정밀도: 0.5361, 재현율: 0.9138, F1: 0.6758, ROC-AUC: 0.5721
# ################################################################################
# 0.3
# 오차 행렬
# [[ 468 1559]
#  [ 171 1802]]
# 정확도: 0.5675, 정밀도: 0.5361, 재현율: 0.9133, F1: 0.6757, ROC-AUC: 0.5721
# ################################################################################
# 0.30303030303030304
# 오차 행렬
# [[ 482 1545]
#  [ 177 1796]]
# 정확도: 0.5695, 정밀도: 0.5376, 재현율: 0.9103, F1: 0.6760, ROC-AUC: 0.5740
# ################################################################################
# 0.30337078651685395
# 오차 행렬
# [[ 499 1528]
#  [ 184 1789]]
# 정확도: 0.5720, 정밀도: 0.5393, 재현율: 0.9067, F1: 0.6764, ROC-AUC: 0.5765
# ################################################################################
# 0.30434782608695654
# 오차 행렬
# [[ 507 1520]
#  [ 184 1789]]
# 정확도: 0.5740, 정밀도: 0.5406, 재현율: 0.9067, F1: 0.6774, ROC-AUC: 0.5784
# ################################################################################
# 0.3076923076923077
# 오차 행렬
# [[ 513 1514]
#  [ 185 1788]]
# 정확도: 0.5753, 정밀도: 0.5415, 재현율: 0.9062, F1: 0.6779, ROC-AUC: 0.5797
# ################################################################################
# 0.3137254901960784
# 오차 행렬
# [[ 520 1507]
#  [ 187 1786]]
# 정확도: 0.5765, 정밀도: 0.5424, 재현율: 0.9052, F1: 0.6783, ROC-AUC: 0.5809
# ################################################################################
# 0.3142857142857143
# 오차 행렬
# [[ 525 1502]
#  [ 189 1784]]
# 정확도: 0.5773, 정밀도: 0.5429, 재현율: 0.9042, F1: 0.6785, ROC-AUC: 0.5816
# ################################################################################
# 0.3170731707317073
# 오차 행렬
# [[ 538 1489]
#  [ 191 1782]]
# 정확도: 0.5800, 정밀도: 0.5448, 재현율: 0.9032, F1: 0.6796, ROC-AUC: 0.5843
# ################################################################################
# 0.32075471698113206
# 오차 행렬
# [[ 539 1488]
#  [ 194 1779]]
# 정확도: 0.5795, 정밀도: 0.5445, 재현율: 0.9017, F1: 0.6790, ROC-AUC: 0.5838
# ################################################################################
# 0.3246753246753247
# 오차 행렬
# [[ 548 1479]
#  [ 201 1772]]
# 정확도: 0.5800, 정밀도: 0.5451, 재현율: 0.8981, F1: 0.6784, ROC-AUC: 0.5842
# ################################################################################
# 0.3269230769230769
# 오차 행렬
# [[ 553 1474]
#  [ 205 1768]]
# 정확도: 0.5803, 정밀도: 0.5453, 재현율: 0.8961, F1: 0.6780, ROC-AUC: 0.5845
# ################################################################################
# 0.3302752293577982
# 오차 행렬
# [[ 576 1451]
#  [ 211 1762]]
# 정확도: 0.5845, 정밀도: 0.5484, 재현율: 0.8931, F1: 0.6795, ROC-AUC: 0.5886
# ################################################################################
# 0.3333333333333333
# 오차 행렬
# [[ 618 1409]
#  [ 244 1729]]
# 정확도: 0.5867, 정밀도: 0.5510, 재현율: 0.8763, F1: 0.6766, ROC-AUC: 0.5906
# ################################################################################
# 0.3382352941176471
# 오차 행렬
# [[ 626 1401]
#  [ 250 1723]]
# 정확도: 0.5873, 정밀도: 0.5515, 재현율: 0.8733, F1: 0.6761, ROC-AUC: 0.5911
# ################################################################################
# 0.34782608695652173
# 오차 행렬
# [[ 633 1394]
#  [ 257 1716]]
# 정확도: 0.5873, 정밀도: 0.5518, 재현율: 0.8697, F1: 0.6752, ROC-AUC: 0.5910
# ################################################################################
# 0.3488372093023256
# 오차 행렬
# [[ 653 1374]
#  [ 264 1709]]
# 정확도: 0.5905, 정밀도: 0.5543, 재현율: 0.8662, F1: 0.6760, ROC-AUC: 0.5942
# ################################################################################
# 0.3490566037735849
# 오차 행렬
# [[ 670 1357]
#  [ 271 1702]]
# 정확도: 0.5930, 정밀도: 0.5564, 재현율: 0.8626, F1: 0.6765, ROC-AUC: 0.5966
# ################################################################################
# 0.35
# 오차 행렬
# [[ 673 1354]
#  [ 273 1700]]
# 정확도: 0.5933, 정밀도: 0.5566, 재현율: 0.8616, F1: 0.6763, ROC-AUC: 0.5968
# ################################################################################
# 0.3523809523809524
# 오차 행렬
# [[ 699 1328]
#  [ 283 1690]]
# 정확도: 0.5972, 정밀도: 0.5600, 재현율: 0.8566, F1: 0.6772, ROC-AUC: 0.6007
# ################################################################################
# 0.3548387096774194
# 오차 행렬
# [[ 705 1322]
#  [ 286 1687]]
# 정확도: 0.5980, 정밀도: 0.5607, 재현율: 0.8550, F1: 0.6772, ROC-AUC: 0.6014
# ################################################################################
# 0.35526315789473684
# 오차 행렬
# [[ 712 1315]
#  [ 295 1678]]
# 정확도: 0.5975, 정밀도: 0.5606, 재현율: 0.8505, F1: 0.6758, ROC-AUC: 0.6009
# ################################################################################
# 0.358974358974359
# 오차 행렬
# [[ 722 1305]
#  [ 298 1675]]
# 정확도: 0.5992, 정밀도: 0.5621, 재현율: 0.8490, F1: 0.6764, ROC-AUC: 0.6026
# ################################################################################
# 0.36
# 오차 행렬
# [[ 727 1300]
#  [ 299 1674]]
# 정확도: 0.6002, 정밀도: 0.5629, 재현율: 0.8485, F1: 0.6768, ROC-AUC: 0.6036
# ################################################################################
# 0.3611111111111111
# 오차 행렬
# [[ 740 1287]
#  [ 310 1663]]
# 정확도: 0.6008, 정밀도: 0.5637, 재현율: 0.8429, F1: 0.6756, ROC-AUC: 0.6040
# ################################################################################
# 0.36363636363636365
# 오차 행렬
# [[ 748 1279]
#  [ 316 1657]]
# 정확도: 0.6012, 정밀도: 0.5644, 재현율: 0.8398, F1: 0.6751, ROC-AUC: 0.6044
# ################################################################################
# 0.3673469387755102
# 오차 행렬
# [[ 754 1273]
#  [ 322 1651]]
# 정확도: 0.6012, 정밀도: 0.5646, 재현율: 0.8368, F1: 0.6743, ROC-AUC: 0.6044
# ################################################################################
# 0.3684210526315789
# 오차 행렬
# [[ 768 1259]
#  [ 329 1644]]
# 정확도: 0.6030, 정밀도: 0.5663, 재현율: 0.8332, F1: 0.6743, ROC-AUC: 0.6061
# ################################################################################
# 0.3695652173913043
# 오차 행렬
# [[ 773 1254]
#  [ 331 1642]]
# 정확도: 0.6038, 정밀도: 0.5670, 재현율: 0.8322, F1: 0.6745, ROC-AUC: 0.6068
# ################################################################################
# 0.3717948717948718
# 오차 행렬
# [[ 785 1242]
#  [ 338 1635]]
# 정확도: 0.6050, 정밀도: 0.5683, 재현율: 0.8287, F1: 0.6742, ROC-AUC: 0.6080
# ################################################################################
# 0.37209302325581395
# 오차 행렬
# [[ 807 1220]
#  [ 353 1620]]
# 정확도: 0.6068, 정밀도: 0.5704, 재현율: 0.8211, F1: 0.6732, ROC-AUC: 0.6096
# ################################################################################
# 0.3761467889908257
# 오차 행렬
# [[ 831 1196]
#  [ 364 1609]]
# 정확도: 0.6100, 정밀도: 0.5736, 재현율: 0.8155, F1: 0.6735, ROC-AUC: 0.6127
# ################################################################################
# 0.38095238095238093
# 오차 행렬
# [[ 842 1185]
#  [ 374 1599]]
# 정확도: 0.6102, 정밀도: 0.5744, 재현율: 0.8104, F1: 0.6723, ROC-AUC: 0.6129
# ################################################################################
# 0.38235294117647056
# 오차 행렬
# [[ 853 1174]
#  [ 378 1595]]
# 정확도: 0.6120, 정밀도: 0.5760, 재현율: 0.8084, F1: 0.6727, ROC-AUC: 0.6146
# ################################################################################
# 0.38823529411764707
# 오차 행렬
# [[ 867 1160]
#  [ 389 1584]]
# 정확도: 0.6128, 정밀도: 0.5773, 재현율: 0.8028, F1: 0.6716, ROC-AUC: 0.6153
# ################################################################################
# 0.3888888888888889
# 오차 행렬
# [[ 869 1158]
#  [ 390 1583]]
# 정확도: 0.6130, 정밀도: 0.5775, 재현율: 0.8023, F1: 0.6716, ROC-AUC: 0.6155
# ################################################################################
# 0.3902439024390244
# 오차 행렬
# [[ 880 1147]
#  [ 400 1573]]
# 정확도: 0.6132, 정밀도: 0.5783, 재현율: 0.7973, F1: 0.6704, ROC-AUC: 0.6157
# ################################################################################
# 0.39325842696629215
# 오차 행렬
# [[ 896 1131]
#  [ 415 1558]]
# 정확도: 0.6135, 정밀도: 0.5794, 재현율: 0.7897, F1: 0.6684, ROC-AUC: 0.6158
# ################################################################################
# 0.39436619718309857
# 오차 행렬
# [[ 908 1119]
#  [ 421 1552]]
# 정확도: 0.6150, 정밀도: 0.5811, 재현율: 0.7866, F1: 0.6684, ROC-AUC: 0.6173
# ################################################################################
# 0.3950617283950617
# 오차 행렬
# [[ 920 1107]
#  [ 428 1545]]
# 정확도: 0.6162, 정밀도: 0.5826, 재현율: 0.7831, F1: 0.6681, ROC-AUC: 0.6185
# ################################################################################
# 0.3956043956043956
# 오차 행렬
# [[ 937 1090]
#  [ 436 1537]]
# 정확도: 0.6185, 정밀도: 0.5851, 재현율: 0.7790, F1: 0.6683, ROC-AUC: 0.6206
# ################################################################################
# 0.4
# 오차 행렬
# [[ 947 1080]
#  [ 445 1528]]
# 정확도: 0.6188, 정밀도: 0.5859, 재현율: 0.7745, F1: 0.6671, ROC-AUC: 0.6208
# ################################################################################
# 0.40384615384615385
# 오차 행렬
# [[ 964 1063]
#  [ 455 1518]]
# 정확도: 0.6205, 정밀도: 0.5881, 재현율: 0.7694, F1: 0.6667, ROC-AUC: 0.6225
# ################################################################################
# 0.4050632911392405
# 오차 행렬
# [[ 974 1053]
#  [ 461 1512]]
# 정확도: 0.6215, 정밀도: 0.5895, 재현율: 0.7663, F1: 0.6664, ROC-AUC: 0.6234
# ################################################################################
# 0.41025641025641024
# 오차 행렬
# [[ 980 1047]
#  [ 471 1502]]
# 정확도: 0.6205, 정밀도: 0.5893, 재현율: 0.7613, F1: 0.6643, ROC-AUC: 0.6224
# ################################################################################
# 0.41237113402061853
# 오차 행렬
# [[ 989 1038]
#  [ 481 1492]]
# 정확도: 0.6202, 정밀도: 0.5897, 재현율: 0.7562, F1: 0.6627, ROC-AUC: 0.6221
# ################################################################################
# 0.42028985507246375
# 오차 행렬
# [[1001 1026]
#  [ 489 1484]]
# 정확도: 0.6212, 정밀도: 0.5912, 재현율: 0.7522, F1: 0.6621, ROC-AUC: 0.6230
# ################################################################################
# 0.422680412371134
# 오차 행렬
# [[1022 1005]
#  [ 498 1475]]
# 정확도: 0.6242, 정밀도: 0.5948, 재현율: 0.7476, F1: 0.6625, ROC-AUC: 0.6259
# ################################################################################
# 0.423728813559322
# 오차 행렬
# [[1027 1000]
#  [ 506 1467]]
# 정확도: 0.6235, 정밀도: 0.5946, 재현율: 0.7435, F1: 0.6608, ROC-AUC: 0.6251
# ################################################################################
# 0.42592592592592593
# 오차 행렬
# [[1037  990]
#  [ 514 1459]]
# 정확도: 0.6240, 정밀도: 0.5958, 재현율: 0.7395, F1: 0.6599, ROC-AUC: 0.6255
# ################################################################################
# 0.42857142857142855
# 오차 행렬
# [[1055  972]
#  [ 531 1442]]
# 정확도: 0.6242, 정밀도: 0.5973, 재현율: 0.7309, F1: 0.6574, ROC-AUC: 0.6257
# ################################################################################
# 0.43010752688172044
# 오차 행렬
# [[1064  963]
#  [ 542 1431]]
# 정확도: 0.6238, 정밀도: 0.5977, 재현율: 0.7253, F1: 0.6554, ROC-AUC: 0.6251
# ################################################################################
# 0.43103448275862066
# 오차 행렬
# [[1076  951]
#  [ 548 1425]]
# 정확도: 0.6252, 정밀도: 0.5997, 재현율: 0.7223, F1: 0.6553, ROC-AUC: 0.6265
# ################################################################################
# 0.43333333333333335
# 오차 행렬
# [[1080  947]
#  [ 548 1425]]
# 정확도: 0.6262, 정밀도: 0.6008, 재현율: 0.7223, F1: 0.6559, ROC-AUC: 0.6275
# ################################################################################
# 0.43636363636363634
# 오차 행렬
# [[1084  943]
#  [ 555 1418]]
# 정확도: 0.6255, 정밀도: 0.6006, 재현율: 0.7187, F1: 0.6544, ROC-AUC: 0.6267
# ################################################################################
# 0.45098039215686275
# 오차 행렬
# [[1086  941]
#  [ 561 1412]]
# 정확도: 0.6245, 정밀도: 0.6001, 재현율: 0.7157, F1: 0.6528, ROC-AUC: 0.6257
# ################################################################################
# 0.46226415094339623
# 오차 행렬
# [[1097  930]
#  [ 571 1402]]
# 정확도: 0.6248, 정밀도: 0.6012, 재현율: 0.7106, F1: 0.6513, ROC-AUC: 0.6259
# ################################################################################
# 0.4625
# 오차 행렬
# [[1107  920]
#  [ 576 1397]]
# 정확도: 0.6260, 정밀도: 0.6029, 재현율: 0.7081, F1: 0.6513, ROC-AUC: 0.6271
# ################################################################################
# 0.46296296296296297
# 오차 행렬
# [[1111  916]
#  [ 584 1389]]
# 정확도: 0.6250, 정밀도: 0.6026, 재현율: 0.7040, F1: 0.6494, ROC-AUC: 0.6261
# ################################################################################
# 0.46511627906976744
# 오차 행렬
# [[1117  910]
#  [ 589 1384]]
# 정확도: 0.6252, 정밀도: 0.6033, 재현율: 0.7015, F1: 0.6487, ROC-AUC: 0.6263
# ################################################################################
# 0.4672897196261682
# 오차 행렬
# [[1146  881]
#  [ 613 1360]]
# 정확도: 0.6265, 정밀도: 0.6069, 재현율: 0.6893, F1: 0.6455, ROC-AUC: 0.6273
# ################################################################################
# 0.4696969696969697
# 오차 행렬
# [[1157  870]
#  [ 617 1356]]
# 정확도: 0.6282, 정밀도: 0.6092, 재현율: 0.6873, F1: 0.6459, ROC-AUC: 0.6290
# ################################################################################
# 0.47058823529411764
# 오차 행렬
# [[1185  842]
#  [ 632 1341]]
# 정확도: 0.6315, 정밀도: 0.6143, 재현율: 0.6797, F1: 0.6453, ROC-AUC: 0.6321
# ################################################################################
# 0.48
# 오차 행렬
# [[1189  838]
#  [ 637 1336]]
# 정확도: 0.6312, 정밀도: 0.6145, 재현율: 0.6771, F1: 0.6443, ROC-AUC: 0.6319
# ################################################################################
# 0.49
# 오차 행렬
# [[1202  825]
#  [ 651 1322]]
# 정확도: 0.6310, 정밀도: 0.6157, 재현율: 0.6700, F1: 0.6417, ROC-AUC: 0.6315
# ################################################################################
# 0.49230769230769234
# 오차 행렬
# [[1210  817]
#  [ 656 1317]]
# 정확도: 0.6318, 정밀도: 0.6172, 재현율: 0.6675, F1: 0.6413, ROC-AUC: 0.6322
# ################################################################################
# 0.5
# 오차 행렬
# [[1239  788]
#  [ 681 1292]]
# 정확도: 0.6328, 정밀도: 0.6212, 재현율: 0.6548, F1: 0.6376, ROC-AUC: 0.6330
# ################################################################################
# 0.5048543689320388
# 오차 행렬
# [[1253  774]
#  [ 696 1277]]
# 정확도: 0.6325, 정밀도: 0.6226, 재현율: 0.6472, F1: 0.6347, ROC-AUC: 0.6327
# ################################################################################
# 0.5076923076923077
# 오차 행렬
# [[1260  767]
#  [ 706 1267]]
# 정확도: 0.6318, 정밀도: 0.6229, 재현율: 0.6422, F1: 0.6324, ROC-AUC: 0.6319
# ################################################################################
# 0.5096153846153846
# 오차 행렬
# [[1271  756]
#  [ 724 1249]]
# 정확도: 0.6300, 정밀도: 0.6229, 재현율: 0.6330, F1: 0.6280, ROC-AUC: 0.6300
# ################################################################################
# 0.5108695652173914
# 오차 행렬
# [[1283  744]
#  [ 734 1239]]
# 정확도: 0.6305, 정밀도: 0.6248, 재현율: 0.6280, F1: 0.6264, ROC-AUC: 0.6305
# ################################################################################
# 0.5111111111111111
# 오차 행렬
# [[1288  739]
#  [ 739 1234]]
# 정확도: 0.6305, 정밀도: 0.6254, 재현율: 0.6254, F1: 0.6254, ROC-AUC: 0.6304
# ################################################################################
# 0.5142857142857142
# 오차 행렬
# [[1290  737]
#  [ 745 1228]]
# 정확도: 0.6295, 정밀도: 0.6249, 재현율: 0.6224, F1: 0.6237, ROC-AUC: 0.6294
# ################################################################################
# 0.5172413793103449
# 오차 행렬
# [[1304  723]
#  [ 752 1221]]
# 정확도: 0.6312, 정밀도: 0.6281, 재현율: 0.6189, F1: 0.6234, ROC-AUC: 0.6311
# ################################################################################
# 0.5211267605633803
# 오차 행렬
# [[1305  722]
#  [ 763 1210]]
# 정확도: 0.6288, 정밀도: 0.6263, 재현율: 0.6133, F1: 0.6197, ROC-AUC: 0.6285
# ################################################################################
# 0.5227272727272727
# 오차 행렬
# [[1311  716]
#  [ 770 1203]]
# 정확도: 0.6285, 정밀도: 0.6269, 재현율: 0.6097, F1: 0.6182, ROC-AUC: 0.6282
# ################################################################################
# 0.5231788079470199
# 오차 행렬
# [[1334  693]
#  [ 792 1181]]
# 정확도: 0.6288, 정밀도: 0.6302, 재현율: 0.5986, F1: 0.6140, ROC-AUC: 0.6283
# ################################################################################
# 0.5233644859813084
# 오차 행렬
# [[1348  679]
#  [ 811 1162]]
# 정확도: 0.6275, 정밀도: 0.6312, 재현율: 0.5890, F1: 0.6093, ROC-AUC: 0.6270
# ################################################################################
# 0.5301204819277109
# 오차 행렬
# [[1360  667]
#  [ 822 1151]]
# 정확도: 0.6278, 정밀도: 0.6331, 재현율: 0.5834, F1: 0.6072, ROC-AUC: 0.6272
# ################################################################################
# 0.5306122448979592
# 오차 행렬
# [[1376  651]
#  [ 833 1140]]
# 정확도: 0.6290, 정밀도: 0.6365, 재현율: 0.5778, F1: 0.6057, ROC-AUC: 0.6283
# ################################################################################
# 0.5368421052631579
# 오차 행렬
# [[1386  641]
#  [ 842 1131]]
# 정확도: 0.6292, 정밀도: 0.6383, 재현율: 0.5732, F1: 0.6040, ROC-AUC: 0.6285
# ################################################################################
# 0.5377358490566038
# 오차 행렬
# [[1399  628]
#  [ 855 1118]]
# 정확도: 0.6292, 정밀도: 0.6403, 재현율: 0.5666, F1: 0.6012, ROC-AUC: 0.6284
# ################################################################################
# 0.5405405405405406
# 오차 행렬
# [[1410  617]
#  [ 866 1107]]
# 정확도: 0.6292, 정밀도: 0.6421, 재현율: 0.5611, F1: 0.5989, ROC-AUC: 0.6283
# ################################################################################
# 0.5425531914893617
# 오차 행렬
# [[1419  608]
#  [ 877 1096]]
# 정확도: 0.6288, 정밀도: 0.6432, 재현율: 0.5555, F1: 0.5961, ROC-AUC: 0.6278
# ################################################################################
# 0.55
# 오차 행렬
# [[1437  590]
#  [ 906 1067]]
# 정확도: 0.6260, 정밀도: 0.6439, 재현율: 0.5408, F1: 0.5879, ROC-AUC: 0.6249
# ################################################################################
# 0.5531914893617021
# 오차 행렬
# [[1447  580]
#  [ 917 1056]]
# 정확도: 0.6258, 정밀도: 0.6455, 재현율: 0.5352, F1: 0.5852, ROC-AUC: 0.6245
# ################################################################################
# 0.5555555555555556
# 오차 행렬
# [[1470  557]
#  [ 941 1032]]
# 정확도: 0.6255, 정밀도: 0.6495, 재현율: 0.5231, F1: 0.5794, ROC-AUC: 0.6241
# ################################################################################
# 0.5569620253164557
# 오차 행렬
# [[1477  550]
#  [ 959 1014]]
# 정확도: 0.6228, 정밀도: 0.6483, 재현율: 0.5139, F1: 0.5734, ROC-AUC: 0.6213
# ################################################################################
# 0.56
# 오차 행렬
# [[1486  541]
#  [ 968 1005]]
# 정확도: 0.6228, 정밀도: 0.6501, 재현율: 0.5094, F1: 0.5712, ROC-AUC: 0.6212
# ################################################################################
# 0.5657894736842105
# 오차 행렬
# [[1493  534]
#  [ 981  992]]
# 정확도: 0.6212, 정밀도: 0.6501, 재현율: 0.5028, F1: 0.5670, ROC-AUC: 0.6197
# ################################################################################
# 0.5660377358490566
# 오차 행렬
# [[1501  526]
#  [ 986  987]]
# 정확도: 0.6220, 정밀도: 0.6523, 재현율: 0.5003, F1: 0.5663, ROC-AUC: 0.6204
# ################################################################################
# 0.5679012345679012
# 오차 행렬
# [[1506  521]
#  [ 998  975]]
# 정확도: 0.6202, 정밀도: 0.6517, 재현율: 0.4942, F1: 0.5621, ROC-AUC: 0.6186
# ################################################################################
# 0.5681818181818182
# 오차 행렬
# [[1512  515]
#  [1009  964]]
# 정확도: 0.6190, 정밀도: 0.6518, 재현율: 0.4886, F1: 0.5585, ROC-AUC: 0.6173
# ################################################################################
# 0.5737704918032787
# 오차 행렬
# [[1517  510]
#  [1018  955]]
# 정확도: 0.6180, 정밀도: 0.6519, 재현율: 0.4840, F1: 0.5556, ROC-AUC: 0.6162
# ################################################################################
# 0.5742574257425742
# 오차 행렬
# [[1527  500]
#  [1037  936]]
# 정확도: 0.6158, 정밀도: 0.6518, 재현율: 0.4744, F1: 0.5491, ROC-AUC: 0.6139
# ################################################################################
# 0.5769230769230769
# 오차 행렬
# [[1527  500]
#  [1040  933]]
# 정확도: 0.6150, 정밀도: 0.6511, 재현율: 0.4729, F1: 0.5479, ROC-AUC: 0.6131
# ################################################################################
# 0.581081081081081
# 오차 행렬
# [[1534  493]
#  [1050  923]]
# 정확도: 0.6142, 정밀도: 0.6518, 재현율: 0.4678, F1: 0.5447, ROC-AUC: 0.6123
# ################################################################################
# 0.5853658536585366
# 오차 행렬
# [[1536  491]
#  [1058  915]]
# 정확도: 0.6128, 정밀도: 0.6508, 재현율: 0.4638, F1: 0.5416, ROC-AUC: 0.6108
# ################################################################################
# 0.5869565217391305
# 오차 행렬
# [[1543  484]
#  [1064  909]]
# 정확도: 0.6130, 정밀도: 0.6525, 재현율: 0.4607, F1: 0.5401, ROC-AUC: 0.6110
# ################################################################################
# 0.5882352941176471
# 오차 행렬
# [[1552  475]
#  [1075  898]]
# 정확도: 0.6125, 정밀도: 0.6540, 재현율: 0.4551, F1: 0.5368, ROC-AUC: 0.6104
# ################################################################################
# 0.59
# 오차 행렬
# [[1564  463]
#  [1087  886]]
# 정확도: 0.6125, 정밀도: 0.6568, 재현율: 0.4491, F1: 0.5334, ROC-AUC: 0.6103
# ################################################################################
# 0.5921052631578947
# 오차 행렬
# [[1574  453]
#  [1094  879]]
# 정확도: 0.6132, 정밀도: 0.6599, 재현율: 0.4455, F1: 0.5319, ROC-AUC: 0.6110
# ################################################################################
# 0.5943396226415094
# 오차 행렬
# [[1588  439]
#  [1103  870]]
# 정확도: 0.6145, 정밀도: 0.6646, 재현율: 0.4410, F1: 0.5302, ROC-AUC: 0.6122
# ################################################################################
# 0.5952380952380952
# 오차 행렬
# [[1593  434]
#  [1107  866]]
# 정확도: 0.6148, 정밀도: 0.6662, 재현율: 0.4389, F1: 0.5292, ROC-AUC: 0.6124
# ################################################################################
# 0.5963302752293578
# 오차 행렬
# [[1608  419]
#  [1118  855]]
# 정확도: 0.6158, 정밀도: 0.6711, 재현율: 0.4334, F1: 0.5266, ROC-AUC: 0.6133
# ################################################################################
# 0.5972222222222222
# 오차 행렬
# [[1613  414]
#  [1124  849]]
# 정확도: 0.6155, 정밀도: 0.6722, 재현율: 0.4303, F1: 0.5247, ROC-AUC: 0.6130
# ################################################################################
# 0.5978260869565217
# 오차 행렬
# [[1619  408]
#  [1140  833]]
# 정확도: 0.6130, 정밀도: 0.6712, 재현율: 0.4222, F1: 0.5184, ROC-AUC: 0.6105
# ################################################################################
# 0.6
# 오차 행렬
# [[1642  385]
#  [1162  811]]
# 정확도: 0.6132, 정밀도: 0.6781, 재현율: 0.4110, F1: 0.5118, ROC-AUC: 0.6106
# ################################################################################
# 0.6041666666666666
# 오차 행렬
# [[1649  378]
#  [1171  802]]
# 정확도: 0.6128, 정밀도: 0.6797, 재현율: 0.4065, F1: 0.5087, ROC-AUC: 0.6100
# ################################################################################
# 0.6063829787234043
# 오차 행렬
# [[1656  371]
#  [1190  783]]
# 정확도: 0.6098, 정밀도: 0.6785, 재현율: 0.3969, F1: 0.5008, ROC-AUC: 0.6069
# ################################################################################
# 0.609375
# 오차 행렬
# [[1667  360]
#  [1202  771]]
# 정확도: 0.6095, 정밀도: 0.6817, 재현율: 0.3908, F1: 0.4968, ROC-AUC: 0.6066
# ################################################################################
# 0.6116504854368932
# 오차 행렬
# [[1676  351]
#  [1216  757]]
# 정확도: 0.6082, 정밀도: 0.6832, 재현율: 0.3837, F1: 0.4914, ROC-AUC: 0.6053
# ################################################################################
# 0.6132075471698113
# 오차 행렬
# [[1684  343]
#  [1233  740]]
# 정확도: 0.6060, 정밀도: 0.6833, 재현율: 0.3751, F1: 0.4843, ROC-AUC: 0.6029
# ################################################################################
# 0.6142857142857143
# 오차 행렬
# [[1693  334]
#  [1243  730]]
# 정확도: 0.6058, 정밀도: 0.6861, 재현율: 0.3700, F1: 0.4807, ROC-AUC: 0.6026
# ################################################################################
# 0.6190476190476191
# 오차 행렬
# [[1696  331]
#  [1246  727]]
# 정확도: 0.6058, 정밀도: 0.6871, 재현율: 0.3685, F1: 0.4797, ROC-AUC: 0.6026
# ################################################################################
# 0.625
# 오차 행렬
# [[1698  329]
#  [1251  722]]
# 정확도: 0.6050, 정밀도: 0.6870, 재현율: 0.3659, F1: 0.4775, ROC-AUC: 0.6018
# ################################################################################
# 0.6268656716417911
# 오차 행렬
# [[1709  318]
#  [1258  715]]
# 정확도: 0.6060, 정밀도: 0.6922, 재현율: 0.3624, F1: 0.4757, ROC-AUC: 0.6028
# ################################################################################
# 0.6288659793814433
# 오차 행렬
# [[1718  309]
#  [1275  698]]
# 정확도: 0.6040, 정밀도: 0.6931, 재현율: 0.3538, F1: 0.4685, ROC-AUC: 0.6007
# ################################################################################
# 0.6296296296296297
# 오차 행렬
# [[1727  300]
#  [1289  684]]
# 정확도: 0.6028, 정밀도: 0.6951, 재현율: 0.3467, F1: 0.4626, ROC-AUC: 0.5993
# ################################################################################
# 0.6363636363636364
# 오차 행렬
# [[1741  286]
#  [1298  675]]
# 정확도: 0.6040, 정밀도: 0.7024, 재현율: 0.3421, F1: 0.4601, ROC-AUC: 0.6005
# ################################################################################
# 0.6395348837209303
# 오차 행렬
# [[1751  276]
#  [1310  663]]
# 정확도: 0.6035, 정밀도: 0.7061, 재현율: 0.3360, F1: 0.4554, ROC-AUC: 0.5999
# ################################################################################
# 0.6428571428571429
# 오차 행렬
# [[1752  275]
#  [1312  661]]
# 정확도: 0.6032, 정밀도: 0.7062, 재현율: 0.3350, F1: 0.4545, ROC-AUC: 0.5997
# ################################################################################
# 0.6451612903225806
# 오차 행렬
# [[1761  266]
#  [1323  650]]
# 정확도: 0.6028, 정밀도: 0.7096, 재현율: 0.3294, F1: 0.4500, ROC-AUC: 0.5991
# ################################################################################
# 0.6511627906976745
# 오차 행렬
# [[1765  262]
#  [1327  646]]
# 정확도: 0.6028, 정밀도: 0.7115, 재현율: 0.3274, F1: 0.4485, ROC-AUC: 0.5991
# ################################################################################
# 0.6555555555555556
# 오차 행렬
# [[1775  252]
#  [1341  632]]
# 정확도: 0.6018, 정밀도: 0.7149, 재현율: 0.3203, F1: 0.4424, ROC-AUC: 0.5980
# ################################################################################
# 0.6593406593406593
# 오차 행렬
# [[1784  243]
#  [1356  617]]
# 정확도: 0.6002, 정밀도: 0.7174, 재현율: 0.3127, F1: 0.4356, ROC-AUC: 0.5964
# ################################################################################
# 0.6601941747572816
# 오차 행렬
# [[1799  228]
#  [1374  599]]
# 정확도: 0.5995, 정밀도: 0.7243, 재현율: 0.3036, F1: 0.4279, ROC-AUC: 0.5956
# ################################################################################
# 0.6666666666666666
# 오차 행렬
# [[1804  223]
#  [1382  591]]
# 정확도: 0.5988, 정밀도: 0.7260, 재현율: 0.2995, F1: 0.4241, ROC-AUC: 0.5948
# ################################################################################
# 0.6705882352941176
# 오차 행렬
# [[1809  218]
#  [1397  576]]
# 정확도: 0.5962, 정밀도: 0.7254, 재현율: 0.2919, F1: 0.4163, ROC-AUC: 0.5922
# ################################################################################
# 0.6708860759493671
# 오차 행렬
# [[1816  211]
#  [1409  564]]
# 정확도: 0.5950, 정밀도: 0.7277, 재현율: 0.2859, F1: 0.4105, ROC-AUC: 0.5909
# ################################################################################
# 0.6744186046511628
# 오차 행렬
# [[1817  210]
#  [1417  556]]
# 정확도: 0.5933, 정밀도: 0.7258, 재현율: 0.2818, F1: 0.4060, ROC-AUC: 0.5891
# ################################################################################
# 0.6764705882352942
# 오차 행렬
# [[1824  203]
#  [1424  549]]
# 정확도: 0.5933, 정밀도: 0.7301, 재현율: 0.2783, F1: 0.4029, ROC-AUC: 0.5891
# ################################################################################
# 0.6779661016949152
# 오차 행렬
# [[1831  196]
#  [1436  537]]
# 정확도: 0.5920, 정밀도: 0.7326, 재현율: 0.2722, F1: 0.3969, ROC-AUC: 0.5877
# ################################################################################
# 0.6818181818181818
# 오차 행렬
# [[1833  194]
#  [1440  533]]
# 정확도: 0.5915, 정밀도: 0.7331, 재현율: 0.2701, F1: 0.3948, ROC-AUC: 0.5872
# ################################################################################
# 0.6823529411764706
# 오차 행렬
# [[1842  185]
#  [1458  515]]
# 정확도: 0.5893, 정밀도: 0.7357, 재현율: 0.2610, F1: 0.3853, ROC-AUC: 0.5849
# ################################################################################
# 0.6851851851851852
# 오차 행렬
# [[1844  183]
#  [1472  501]]
# 정확도: 0.5863, 정밀도: 0.7325, 재현율: 0.2539, F1: 0.3771, ROC-AUC: 0.5818
# ################################################################################
# 0.6896551724137931
# 오차 행렬
# [[1847  180]
#  [1475  498]]
# 정확도: 0.5863, 정밀도: 0.7345, 재현율: 0.2524, F1: 0.3757, ROC-AUC: 0.5818
# ################################################################################
# 0.6923076923076923
# 오차 행렬
# [[1848  179]
#  [1475  498]]
# 정확도: 0.5865, 정밀도: 0.7356, 재현율: 0.2524, F1: 0.3758, ROC-AUC: 0.5820
# ################################################################################
# 0.696969696969697
# 오차 행렬
# [[1848  179]
#  [1477  496]]
# 정확도: 0.5860, 정밀도: 0.7348, 재현율: 0.2514, F1: 0.3746, ROC-AUC: 0.5815
# ################################################################################
# 0.7
# 오차 행렬
# [[1854  173]
#  [1488  485]]
# 정확도: 0.5847, 정밀도: 0.7371, 재현율: 0.2458, F1: 0.3687, ROC-AUC: 0.5802
# ################################################################################
# 0.7027027027027027
# 오차 행렬
# [[1858  169]
#  [1494  479]]
# 정확도: 0.5843, 정밀도: 0.7392, 재현율: 0.2428, F1: 0.3655, ROC-AUC: 0.5797
# ################################################################################
# 0.7037037037037037
# 오차 행렬
# [[1860  167]
#  [1495  478]]
# 정확도: 0.5845, 정밀도: 0.7411, 재현율: 0.2423, F1: 0.3652, ROC-AUC: 0.5799
# ################################################################################
# 0.7058823529411765
# 오차 행렬
# [[1865  162]
#  [1513  460]]
# 정확도: 0.5813, 정밀도: 0.7395, 재현율: 0.2331, F1: 0.3545, ROC-AUC: 0.5766
# ################################################################################
# 0.7083333333333334
# 오차 행렬
# [[1866  161]
#  [1517  456]]
# 정확도: 0.5805, 정밀도: 0.7391, 재현율: 0.2311, F1: 0.3521, ROC-AUC: 0.5758
# ################################################################################
# 0.7090909090909091
# 오차 행렬
# [[1873  154]
#  [1531  442]]
# 정확도: 0.5787, 정밀도: 0.7416, 재현율: 0.2240, F1: 0.3441, ROC-AUC: 0.5740
# ################################################################################
# 0.7096774193548387
# 오차 행렬
# [[1876  151]
#  [1535  438]]
# 정확도: 0.5785, 정밀도: 0.7436, 재현율: 0.2220, F1: 0.3419, ROC-AUC: 0.5738
# ################################################################################
# 0.7102803738317757
# 오차 행렬
# [[1886  141]
#  [1554  419]]
# 정확도: 0.5763, 정밀도: 0.7482, 재현율: 0.2124, F1: 0.3308, ROC-AUC: 0.5714
# ################################################################################
# 0.7121212121212122
# 오차 행렬
# [[1896  131]
#  [1573  400]]
# 정확도: 0.5740, 정밀도: 0.7533, 재현율: 0.2027, F1: 0.3195, ROC-AUC: 0.5691
# ################################################################################
# 0.7142857142857143
# 오차 행렬
# [[1898  129]
#  [1575  398]]
# 정확도: 0.5740, 정밀도: 0.7552, 재현율: 0.2017, F1: 0.3184, ROC-AUC: 0.5690
# ################################################################################
# 0.7183098591549296
# 오차 행렬
# [[1902  125]
#  [1591  382]]
# 정확도: 0.5710, 정밀도: 0.7535, 재현율: 0.1936, F1: 0.3081, ROC-AUC: 0.5660
# ################################################################################
# 0.7222222222222222
# 오차 행렬
# [[1906  121]
#  [1599  374]]
# 정확도: 0.5700, 정밀도: 0.7556, 재현율: 0.1896, F1: 0.3031, ROC-AUC: 0.5649
# ################################################################################
# 0.723404255319149
# 오차 행렬
# [[1909  118]
#  [1605  368]]
# 정확도: 0.5693, 정밀도: 0.7572, 재현율: 0.1865, F1: 0.2993, ROC-AUC: 0.5642
# ################################################################################
# 0.7272727272727273
# 오차 행렬
# [[1911  116]
#  [1611  362]]
# 정확도: 0.5683, 정밀도: 0.7573, 재현율: 0.1835, F1: 0.2954, ROC-AUC: 0.5631
# ################################################################################
# 0.7333333333333333
# 오차 행렬
# [[1913  114]
#  [1622  351]]
# 정확도: 0.5660, 정밀도: 0.7548, 재현율: 0.1779, F1: 0.2879, ROC-AUC: 0.5608
# ################################################################################
# 0.7352941176470589
# 오차 행렬
# [[1919  108]
#  [1629  344]]
# 정확도: 0.5657, 정밀도: 0.7611, 재현율: 0.1744, F1: 0.2837, ROC-AUC: 0.5605
# ################################################################################
# 0.7368421052631579
# 오차 행렬
# [[1919  108]
#  [1632  341]]
# 정확도: 0.5650, 정밀도: 0.7595, 재현율: 0.1728, F1: 0.2816, ROC-AUC: 0.5598
# ################################################################################
# 0.7391304347826086
# 오차 행렬
# [[1923  104]
#  [1640  333]]
# 정확도: 0.5640, 정밀도: 0.7620, 재현율: 0.1688, F1: 0.2763, ROC-AUC: 0.5587
# ################################################################################
# 0.7407407407407407
# 오차 행렬
# [[1926  101]
#  [1645  328]]
# 정확도: 0.5635, 정밀도: 0.7646, 재현율: 0.1662, F1: 0.2731, ROC-AUC: 0.5582
# ################################################################################
# 0.7441860465116279
# 오차 행렬
# [[1937   90]
#  [1655  318]]
# 정확도: 0.5637, 정밀도: 0.7794, 재현율: 0.1612, F1: 0.2671, ROC-AUC: 0.5584
# ################################################################################
# 0.75
# 오차 행렬
# [[1944   83]
#  [1667  306]]
# 정확도: 0.5625, 정밀도: 0.7866, 재현율: 0.1551, F1: 0.2591, ROC-AUC: 0.5571
# ################################################################################
# 0.7547169811320755
# 오차 행렬
# [[1947   80]
#  [1675  298]]
# 정확도: 0.5613, 정밀도: 0.7884, 재현율: 0.1510, F1: 0.2535, ROC-AUC: 0.5558
# ################################################################################
# 0.7555555555555555
# 오차 행렬
# [[1950   77]
#  [1683  290]]
# 정확도: 0.5600, 정밀도: 0.7902, 재현율: 0.1470, F1: 0.2479, ROC-AUC: 0.5545
# ################################################################################
# 0.7619047619047619
# 오차 행렬
# [[1952   75]
#  [1688  285]]
# 정확도: 0.5593, 정밀도: 0.7917, 재현율: 0.1445, F1: 0.2443, ROC-AUC: 0.5537
# ################################################################################
# 0.7647058823529411
# 오차 행렬
# [[1956   71]
#  [1693  280]]
# 정확도: 0.5590, 정밀도: 0.7977, 재현율: 0.1419, F1: 0.2410, ROC-AUC: 0.5534
# ################################################################################
# 0.7666666666666667
# 오차 행렬
# [[1957   70]
#  [1701  272]]
# 정확도: 0.5573, 정밀도: 0.7953, 재현율: 0.1379, F1: 0.2350, ROC-AUC: 0.5517
# ################################################################################
# 0.7692307692307693
# 오차 행렬
# [[1959   68]
#  [1709  264]]
# 정확도: 0.5557, 정밀도: 0.7952, 재현율: 0.1338, F1: 0.2291, ROC-AUC: 0.5501
# ################################################################################
# 0.7727272727272727
# 오차 행렬
# [[1962   65]
#  [1717  256]]
# 정확도: 0.5545, 정밀도: 0.7975, 재현율: 0.1298, F1: 0.2232, ROC-AUC: 0.5488
# ################################################################################
# 0.7741935483870968
# 오차 행렬
# [[1965   62]
#  [1721  252]]
# 정확도: 0.5543, 정밀도: 0.8025, 재현율: 0.1277, F1: 0.2204, ROC-AUC: 0.5486
# ################################################################################
# 0.7777777777777778
# 오차 행렬
# [[1967   60]
#  [1726  247]]
# 정확도: 0.5535, 정밀도: 0.8046, 재현율: 0.1252, F1: 0.2167, ROC-AUC: 0.5478
# ################################################################################
# 0.782608695652174
# 오차 행렬
# [[1969   58]
#  [1734  239]]
# 정확도: 0.5520, 정밀도: 0.8047, 재현율: 0.1211, F1: 0.2106, ROC-AUC: 0.5463
# ################################################################################
# 0.7857142857142857
# 오차 행렬
# [[1970   57]
#  [1739  234]]
# 정확도: 0.5510, 정밀도: 0.8041, 재현율: 0.1186, F1: 0.2067, ROC-AUC: 0.5452
# ################################################################################
# 0.7868852459016393
# 오차 행렬
# [[1974   53]
#  [1752  221]]
# 정확도: 0.5487, 정밀도: 0.8066, 재현율: 0.1120, F1: 0.1967, ROC-AUC: 0.5429
# ################################################################################
# 0.7948717948717948
# 오차 행렬
# [[1974   53]
#  [1759  214]]
# 정확도: 0.5470, 정밀도: 0.8015, 재현율: 0.1085, F1: 0.1911, ROC-AUC: 0.5412
# ################################################################################
# 0.8
# 오차 행렬
# [[1979   48]
#  [1777  196]]
# 정확도: 0.5437, 정밀도: 0.8033, 재현율: 0.0993, F1: 0.1768, ROC-AUC: 0.5378
# ################################################################################
# 0.8148148148148148
# 오차 행렬
# [[1979   48]
#  [1782  191]]
# 정확도: 0.5425, 정밀도: 0.7992, 재현율: 0.0968, F1: 0.1727, ROC-AUC: 0.5366
# ################################################################################
# 0.8181818181818182
# 오차 행렬
# [[1981   46]
#  [1787  186]]
# 정확도: 0.5417, 정밀도: 0.8017, 재현율: 0.0943, F1: 0.1687, ROC-AUC: 0.5358
# ################################################################################
# 0.8229166666666666
# 오차 행렬
# [[1985   42]
#  [1804  169]]
# 정확도: 0.5385, 정밀도: 0.8009, 재현율: 0.0857, F1: 0.1548, ROC-AUC: 0.5325
# ################################################################################
# 0.8260869565217391
# 오차 행렬
# [[1986   41]
#  [1812  161]]
# 정확도: 0.5367, 정밀도: 0.7970, 재현율: 0.0816, F1: 0.1480, ROC-AUC: 0.5307
# ################################################################################
# 0.8333333333333334
# 오차 행렬
# [[1989   38]
#  [1826  147]]
# 정확도: 0.5340, 정밀도: 0.7946, 재현율: 0.0745, F1: 0.1362, ROC-AUC: 0.5279
# ################################################################################
# 0.84
# 오차 행렬
# [[1991   36]
#  [1828  145]]
# 정확도: 0.5340, 정밀도: 0.8011, 재현율: 0.0735, F1: 0.1346, ROC-AUC: 0.5279
# ################################################################################
# 0.84375
# 오차 행렬
# [[1995   32]
#  [1835  138]]
# 정확도: 0.5333, 정밀도: 0.8118, 재현율: 0.0699, F1: 0.1288, ROC-AUC: 0.5271
# ################################################################################
# 0.8461538461538461
# 오차 행렬
# [[1999   28]
#  [1843  130]]
# 정확도: 0.5323, 정밀도: 0.8228, 재현율: 0.0659, F1: 0.1220, ROC-AUC: 0.5260
# ################################################################################
# 0.8571428571428571
# 오차 행렬
# [[2000   27]
#  [1846  127]]
# 정확도: 0.5317, 정밀도: 0.8247, 재현율: 0.0644, F1: 0.1194, ROC-AUC: 0.5255
# ################################################################################
# 0.8620689655172413
# 오차 행렬
# [[2002   25]
#  [1852  121]]
# 정확도: 0.5308, 정밀도: 0.8288, 재현율: 0.0613, F1: 0.1142, ROC-AUC: 0.5245
# ################################################################################
# 0.8666666666666667
# 오차 행렬
# [[2007   20]
#  [1866  107]]
# 정확도: 0.5285, 정밀도: 0.8425, 재현율: 0.0542, F1: 0.1019, ROC-AUC: 0.5222
# ################################################################################
# 0.875
# 오차 행렬
# [[2007   20]
#  [1872  101]]
# 정확도: 0.5270, 정밀도: 0.8347, 재현율: 0.0512, F1: 0.0965, ROC-AUC: 0.5207
# ################################################################################
# 0.8888888888888888
# 오차 행렬
# [[2009   18]
#  [1881   92]]
# 정확도: 0.5252, 정밀도: 0.8364, 재현율: 0.0466, F1: 0.0883, ROC-AUC: 0.5189
# ################################################################################
# 0.8947368421052632
# 오차 행렬
# [[2011   16]
#  [1891   82]]
# 정확도: 0.5232, 정밀도: 0.8367, 재현율: 0.0416, F1: 0.0792, ROC-AUC: 0.5168
# ################################################################################
# 0.9
# 오차 행렬
# [[2014   13]
#  [1902   71]]
# 정확도: 0.5212, 정밀도: 0.8452, 재현율: 0.0360, F1: 0.0690, ROC-AUC: 0.5148
# ################################################################################
# 0.9047619047619048
# 오차 행렬
# [[2015   12]
#  [1905   68]]
# 정확도: 0.5208, 정밀도: 0.8500, 재현율: 0.0345, F1: 0.0662, ROC-AUC: 0.5143
# ################################################################################
# 0.9090909090909091
# 오차 행렬
# [[2015   12]
#  [1909   64]]
# 정확도: 0.5198, 정밀도: 0.8421, 재현율: 0.0324, F1: 0.0625, ROC-AUC: 0.5133
# ################################################################################
# 0.9166666666666666
# 오차 행렬
# [[2018    9]
#  [1917   56]]
# 정확도: 0.5185, 정밀도: 0.8615, 재현율: 0.0284, F1: 0.0550, ROC-AUC: 0.5120
# ################################################################################
# 0.9375
# 오차 행렬
# [[2020    7]
#  [1919   54]]
# 정확도: 0.5185, 정밀도: 0.8852, 재현율: 0.0274, F1: 0.0531, ROC-AUC: 0.5120
# ################################################################################
# 1.0
# 오차 행렬
# [[2027    0]
#  [1973    0]]
# 정확도: 0.5068, 정밀도: 0.0000, 재현율: 0.0000, F1: 0.0000, ROC-AUC: 0.5000
# ################################################################################
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, confusion_matrix, ConfusionMatrixDisplay

# 타겟 데이터와 예측 객체를 전달받는다.
def get_evaluation_by_custom_proba(y_test, prediction, visualize=False):
#     오차 행렬
    confusion = confusion_matrix(y_test, prediction)
#     정확도
    accuracy = accuracy_score(y_test , prediction)
#     정밀도
    precision = precision_score(y_test , prediction)
#     재현율
    recall = recall_score(y_test , prediction)
#     F1 score
    f1 = f1_score(y_test, prediction)
#     ROC-AUC
    roc_auc = roc_auc_score(y_test, prediction)
    
    print('오차 행렬')
    print(confusion)
    print('정확도: {0:.4f}, 정밀도: {1:.4f}, 재현율: {2:.4f}, F1: {3:.4f}, ROC-AUC: {4:.4f}'.format(accuracy, precision, recall, f1, roc_auc))
    print("#" * 80)
    
    if visualize:
        fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(8,4))
        titles_options = [("Confusion matrix", None), ("Normalized confusion matrix", "true")]

        for (title, normalize), ax in zip(titles_options, axes.flatten()):
            disp = ConfusionMatrixDisplay.from_predictions(y_test, prediction, ax=ax, cmap=plt.cm.Blues, normalize=normalize)
            disp.ax_.set_title(title)
        plt.show()

# %%
from sklearn.preprocessing import Binarizer

threshold = 0.4657534246575342

proba = dtc.predict_proba(X_test)
prediction = dtc.predict(X_test)

# %%
custom_proba = proba[:, 1].reshape(-1, 1)
binarizer = Binarizer(threshold=threshold).fit(custom_proba)
custom_prediction = binarizer.transform(custom_proba)

dtc_ac = round(accuracy_score(y_test , custom_prediction), 4)
dtc_pr = round(precision_score(y_test , custom_prediction), 4)
dtc_rc = round(recall_score(y_test , custom_prediction), 4)
dtc_f1 = round(f1_score(y_test , custom_prediction), 4)
dtc_rac =round(roc_auc_score(y_test , custom_prediction), 4)

get_evaluation_by_custom_proba(y_test, custom_prediction, visualize=True)
# Out:
# 오차 행렬
# [[1117  910]
#  [ 589 1384]]
# 정확도: 0.6252, 정밀도: 0.6033, 재현율: 0.7015, F1: 0.6487, ROC-AUC: 0.6263
# ################################################################################

# %%
roc_curve_plot(y_test, custom_prediction)

# %% [markdown]
# #### 📌 1. DTC 결과
# DCT를 사용하여 <strong>임계치를 0.5로</strong> 두었을 때는
# <strong>정확도: 0.6318, 정밀도: 0.6196, 재현율: 0.6564, F1: 0.6375, ROC-AUC: 0.6321</strong>이 나왔고,
# 위에서 수립했던 결과, 재현율을 조금 더 높이게 위해 <strong>임계치를 0.4657534246575342로 조정</strong> 했을 때,
# <strong>정확도: 0.6242, 정밀도: 0.6020, 재현율: 0.7030, F1: 0.6486, ROC-AUC: 0.6253</strong>이 나왔다.
# 이는 정확도와 ROC-AUC, 정밀도 점수가 미세하게 떨어지긴 했지만 <strong>재현율과 F1 점수는 상승한 것</strong>을 알 수 있다.
#
# #### KNN을 사용해보도록 하겠다.

# %% [markdown]
# ### 2. KNN (K-Nearest Neighbor)

# %%
y_train_over.value_counts()
# Out:
# valentine_date
# 1    8084
# 0    8084
# Name: count, dtype: int64

# %%
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.neighbors import KNeighborsClassifier

features, targets = pre_df.iloc[:, :-1], pre_df.iloc[:, -1]

X_train, X_test, y_train, y_test = \
train_test_split(features, targets, stratify=targets, test_size=0.2, random_state=124)

knn = KNeighborsClassifier()

parameters = {
    'n_neighbors': [3, 5, 7]
}

g_knn = GridSearchCV(knn, param_grid=parameters, cv=5, refit=True, return_train_score=True)
# g_knn.fit(X_train, y_train)
g_knn.fit(X_train_over, y_train_over)
# Out:
# GridSearchCV(cv=5, estimator=KNeighborsClassifier(),
#              param_grid={'n_neighbors': [3, 5, 7]}, return_train_score=True)

# %%
knn_result_df = pd.DataFrame(g_knn.cv_results_)[['params', 'mean_test_score', 'rank_test_score']]
display(knn_result_df)
# Out:
#                params  mean_test_score  rank_test_score
# 0  {'n_neighbors': 3}         0.506742                1
# 1  {'n_neighbors': 5}         0.505504                3
# 2  {'n_neighbors': 7}         0.505998                2

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, confusion_matrix, ConfusionMatrixDisplay

def get_evaluation(y_test, prediction, classifier=None, X_test=None):
    confusion = confusion_matrix(y_test, prediction)
    accuracy = accuracy_score(y_test , prediction)
    precision = precision_score(y_test , prediction, average='macro')
    recall = recall_score(y_test , prediction, average='macro')
    f1 = f1_score(y_test, prediction, average='macro')
    
    print('오차 행렬')
    print(confusion)
    print('정확도: {0:.4f}, 정밀도: {1:.4f}, 재현율: {2:.4f}, F1: {3:.4f}'.format(accuracy, precision, recall, f1))
    print("#" * 80)
    
    if classifier is not None and  X_test is not None:
        fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12,4))
        titles_options = [("Confusion matrix", None), ("Normalized confusion matrix", "true")]

        for (title, normalize), ax in zip(titles_options, axes.flatten()):
            disp = ConfusionMatrixDisplay.from_estimator(classifier, X_test, y_test, ax=ax, cmap=plt.cm.Blues, normalize=normalize)
            disp.ax_.set_title(title)
        plt.show()

# %%
knn = g_knn.best_estimator_
prediction = knn.predict(X_test)
knn_ac = round(accuracy_score(y_test , prediction), 4)
knn_pr = round(precision_score(y_test , prediction), 4)
knn_rc = round(recall_score(y_test , prediction), 4)
knn_f1 = round(f1_score(y_test , prediction), 4)
knn_rac =round(roc_auc_score(y_test , prediction), 4)

# %%
get_evaluation(y_test, prediction, knn, X_test)
# Out:
# 오차 행렬
# [[1232  795]
#  [ 754 1219]]
# 정확도: 0.6128, 정밀도: 0.6053, 재현율: 0.6178, F1: 0.6115, ROC-AUC: 0.6128
# ################################################################################

# %%
print(f"정확도: {knn_ac}, 정밀도: {knn_pr}, 재현율: {knn_rc}, F1 점수: {knn_f1}, ROC-AUC: {knn_rac}")
# Out:
# 정확도: 0.6128, 정밀도: 0.6053, 재현율: 0.6178, F1 점수: 0.6115, ROC-AUC: 0.6128

# %% [markdown]
# #### 📌 2. KNN (K-Nearest Neighbor) 결과
# KNN을 사용하여 <strong>n_neighbors=3</strong>일 때,
# <strong>정확도: 0.6128, 정밀도: 0.6053, 재현율: 0.6178, F1: 0.6115, ROC-AUC: 0.6128</strong>로 전체적으로 <strong>낮은 성능</strong>이 나왔다.
#
# <strong>다음으로는 bagging의 Random Forest을 사용해보도록 하겠다.</strong>

# %% [markdown]
# ### 3. Bagging (Random Forest)

# %%
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.ensemble import RandomForestClassifier

features, targets = pre_df.iloc[:, :-1], pre_df.iloc[:, -1]

parameters = {'max_depth': range(40, 44), 'min_samples_split': [110, 120, 130, 140]}

rfc = RandomForestClassifier(n_estimators=100)

X_train, X_test, y_train, y_test = \
train_test_split(features, targets, stratify=targets, test_size=0.2, random_state=124)

g_rfc = GridSearchCV(rfc, param_grid=parameters, cv=10, n_jobs=-1)

# g_rfc.fit(X_train, y_train)
g_rfc.fit(X_train_over, y_train_over)
# Out:
# GridSearchCV(cv=10, estimator=RandomForestClassifier(), n_jobs=-1,
#              param_grid={'max_depth': range(40, 44),
#                          'min_samples_split': [110, 120, 130, 140]})

# %%
rfc_result_df = pd.DataFrame(g_rfc.cv_results_)[['params', 'mean_test_score', 'rank_test_score']]
display(rfc_result_df)
# Out:
#                                          params  mean_test_score  \
# 0   {'max_depth': 40, 'min_samples_split': 110}         0.508227
# 1   {'max_depth': 40, 'min_samples_split': 120}         0.510948
# 2   {'max_depth': 40, 'min_samples_split': 130}         0.510020
# 3   {'max_depth': 40, 'min_samples_split': 140}         0.508289
# 4   {'max_depth': 41, 'min_samples_split': 110}         0.509155
# 5   {'max_depth': 41, 'min_samples_split': 120}         0.506495
# 6   {'max_depth': 41, 'min_samples_split': 130}         0.509834
# 7   {'max_depth': 41, 'min_samples_split': 140}         0.506000
# 8   {'max_depth': 42, 'min_samples_split': 110}         0.508164
# 9   {'max_depth': 42, 'min_samples_split': 120}         0.509650
# 10  {'max_depth': 42, 'min_samples_split': 130}         0.507361
# 11  {'max_depth': 42, 'min_samples_split': 140}         0.507361
# 12  {'max_depth': 43, 'min_samples_split': 110}         0.504206
# 13  {'max_depth': 43, 'min_samples_split': 120}         0.504762
# 14  {'max_depth': 43, 'min_samples_split': 130}         0.510514
# 15  {'max_depth': 43, 'min_samples_split': 140}         0.504577
#
#     rank_test_score
# 0                 8
# 1                 1
# 2                 3
# 3                 7
# 4                 6
# 5                12
# 6                 4
# 7                13
# 8                 9
# 9                 5
# 10               11
# 11               10
# 12               16
# 13               14
# 14                2
# 15               15

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, confusion_matrix, ConfusionMatrixDisplay

def get_evaluation(y_test, prediction, classifier=None, X_test=None):
    confusion = confusion_matrix(y_test, prediction)
    accuracy = accuracy_score(y_test , prediction)
    precision = precision_score(y_test , prediction, average='macro')
    recall = recall_score(y_test , prediction, average='macro')
    f1 = f1_score(y_test, prediction, average='macro')
    
    print('오차 행렬')
    print(confusion)
    print('정확도: {0:.4f}, 정밀도: {1:.4f}, 재현율: {2:.4f}, F1: {3:.4f}'.format(accuracy, precision, recall, f1))
    print("#" * 80)
    
    if classifier is not None and  X_test is not None:
        fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12,4))
        titles_options = [("Confusion matrix", None), ("Normalized confusion matrix", "true")]

        for (title, normalize), ax in zip(titles_options, axes.flatten()):
            disp = ConfusionMatrixDisplay.from_estimator(classifier, X_test, y_test, ax=ax, cmap=plt.cm.Blues, normalize=normalize)
            disp.ax_.set_title(title)
        plt.show()

# %%
rfc = g_rfc.best_estimator_
prediction = rfc.predict(X_test)
rfc_ac = round(accuracy_score(y_test , prediction), 4)
rfc_pr = round(precision_score(y_test , prediction), 4)
rfc_rc = round(recall_score(y_test , prediction), 4)
rfc_f1 = round(f1_score(y_test , prediction), 4)
rfc_rac = round(roc_auc_score(y_test , prediction), 4)

# %%
get_evaluation(y_test, prediction, rfc, X_test)
# Out:
# 오차 행렬
# [[1464  563]
#  [ 557 1416]]
# 정확도: 0.7200, 정밀도: 0.7155, 재현율: 0.7177, F1: 0.7166, ROC-AUC: 0.7200
# ################################################################################

# %%
print(rfc)
# Out:
# RandomForestClassifier(max_depth=40, min_samples_split=120)

# %%
print(f"정확도: {rfc_ac}, 정밀도: {rfc_pr}, 재현율: {rfc_rc}, F1 점수: {rfc_f1}, ROC-AUC: {rfc_rac}")
# Out:
# 정확도: 0.72, 정밀도: 0.7155, 재현율: 0.7177, F1 점수: 0.7166, ROC-AUC: 0.72

# %% [markdown]
# #### 📌 3. Bagging (Random Forest) 결과
# Random Forest의 결과는
# <strong>정확도: 0.7200, 정밀도: 0.7155, 재현율: 0.7177, F1: 0.7166, ROC-AUC: 0.7200</strong>로 DTC, KNN보다 더 높은 결과가 나왔다.

# %% [markdown]
# ### 중간 시각화

# %%
import matplotlib.pyplot as plt

plt.rcParams['font.family'] = 'Malgun Gothic'
plt.figure(figsize=(8,4))
colors = ['salmon', 'olive', 'orchid']
accuracies = [dtc_ac,
           knn_ac,
           rfc_ac
             ]
classifiers = ['DTC', 'KNN', 'RFC']
plt.bar(classifiers, accuracies, color=colors)
plt.xlabel('분류기법')
plt.ylabel('정확도')
plt.title('정확도 점수 비교')
plt.ylim(0, 1)
# plt.xticks(rotation=60)

for i, v in enumerate(accuracies):
    plt.text(i, v + 0.01, str(v), color='black', ha='center')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.rcParams['font.family'] = 'Malgun Gothic'
plt.figure(figsize=(8,4))
colors = ['salmon', 'olive', 'orchid']
recalls = [dtc_rc,
           knn_rc,
           rfc_rc
             ]
classifiers = ['DTC', 'KNN', 'RFC']
plt.bar(classifiers, recalls, color=colors)
plt.xlabel('분류기법')
plt.ylabel('재현율')
plt.title('재현율 점수 비교')
plt.ylim(0, 1)
# plt.xticks(rotation=60)

for i, v in enumerate(recalls):
    plt.text(i, v + 0.01, str(v), color='black', ha='center')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.rcParams['font.family'] = 'Malgun Gothic'
plt.figure(figsize=(8,4))
colors = ['salmon', 'olive', 'orchid']
f1s = [dtc_f1,
           knn_f1,
           rfc_f1
             ]
classifiers = ['DTC', 'KNN', 'RFC']
plt.bar(classifiers, f1s, color=colors)
plt.xlabel('분류기법')
plt.ylabel('F1 점수')
plt.title('F1 점수 비교')
plt.ylim(0, 1)
# plt.xticks(rotation=60)

for i, v in enumerate(f1s):
    plt.text(i, v + 0.01, str(v), color='black', ha='center')
plt.show()

# %% [markdown]
# ### 📝 결과
# DTC, KNN, RFC를 각각 사용했을 때, <strong>RFC를 사용했을 때의 정확도, 재현율, F1 점수가 가장 높게 나왔다.</strong>
# 다음으로는 앙상블 학습의 Voting, Bagging, Boosting을 통해 각 결과들을 확인 해보도록 하겠다.

# %% [markdown]
# ### 4. Voting

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

dtc_parameters = {'max_depth': range(40, 44), 'min_samples_split': [110, 120, 130, 140]}

dtc = DecisionTreeClassifier()

g_dtc = GridSearchCV(dtc, param_grid=dtc_parameters, cv=5, refit=True, return_train_score=True, n_jobs=-1)

# %%
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.neighbors import KNeighborsClassifier

features, targets = pre_df.iloc[:, :-1], pre_df.iloc[:, -1]

X_train, X_test, y_train, y_test = \
train_test_split(features, targets, stratify=targets, test_size=0.2, random_state=124)

knn = KNeighborsClassifier()

parameters = {
    'n_neighbors': [3, 5, 7, 11]
}

g_knn = GridSearchCV(knn, param_grid=parameters, cv=5, refit=True, return_train_score=True)
# g_knn.fit(X_train, y_train)

# %%
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.ensemble import RandomForestClassifier

features, targets = pre_df.iloc[:, :-1], pre_df.iloc[:, -1]

parameters = {'max_depth': range(40, 44), 'min_samples_split': [110, 120, 130, 140]}

rfc = RandomForestClassifier(n_estimators=100)

X_train, X_test, y_train, y_test = \
train_test_split(features, targets, stratify=targets, test_size=0.2, random_state=124)

g_rfc = GridSearchCV(rfc, param_grid=parameters, cv=10, n_jobs=-1)

# %%
g_dtc.fit(X_train_over, y_train_over)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(), n_jobs=-1,
#              param_grid={'max_depth': range(40, 44),
#                          'min_samples_split': [110, 120, 130, 140]},
#              return_train_score=True)

# %%
g_knn.fit(X_train_over, y_train_over)
# Out:
# GridSearchCV(cv=5, estimator=KNeighborsClassifier(),
#              param_grid={'n_neighbors': [3, 5, 7, 11]},
#              return_train_score=True)

# %%
g_rfc.fit(X_train_over, y_train_over)
# Out:
# GridSearchCV(cv=10, estimator=RandomForestClassifier(), n_jobs=-1,
#              param_grid={'max_depth': range(40, 44),
#                          'min_samples_split': [110, 120, 130, 140]})

# %%
dtc_result_df = pd.DataFrame(g_dtc.cv_results_)[['params', 'mean_test_score', 'rank_test_score']]
display(dtc_result_df)

dtc = g_dtc.best_estimator_

print(dtc_result_df[dtc_result_df['rank_test_score'] == 1])
# print(g_dtc.best_estimator_)
# Out:
#                                          params  mean_test_score  \
# 0   {'max_depth': 40, 'min_samples_split': 110}         0.503959
# 1   {'max_depth': 40, 'min_samples_split': 120}         0.505134
# 2   {'max_depth': 40, 'min_samples_split': 130}         0.505629
# 3   {'max_depth': 40, 'min_samples_split': 140}         0.506061
# 4   {'max_depth': 41, 'min_samples_split': 110}         0.504949
# 5   {'max_depth': 41, 'min_samples_split': 120}         0.505629
# 6   {'max_depth': 41, 'min_samples_split': 130}         0.505443
# 7   {'max_depth': 41, 'min_samples_split': 140}         0.506804
# 8   {'max_depth': 42, 'min_samples_split': 110}         0.504887
# 9   {'max_depth': 42, 'min_samples_split': 120}         0.504887
# 10  {'max_depth': 42, 'min_samples_split': 130}         0.505876
# 11  {'max_depth': 42, 'min_samples_split': 140}         0.506495
# 12  {'max_depth': 43, 'min_samples_split': 110}         0.505196
# 13  {'max_depth': 43, 'min_samples_split': 120}         0.506062
# 14  {'max_depth': 43, 'min_samples_split': 130}         0.505320
# 15  {'max_depth': 43, 'min_samples_split': 140}         0.506495
#
#     rank_test_score
# 0                16
# 1                12
# 2                 7
# 3                 5
# 4                13
# 5                 8
# 6                 9
# 7                 1
# 8                14
# 9                15
# 10                6
# 11                2
# 12               11
# 13                4
# 14               10
# 15                2
#                                         params  mean_test_score  \
# 7  {'max_depth': 41, 'min_samples_split': 140}         0.506804
#
#    rank_test_score
# 7                1

# %%
knn_result_df = pd.DataFrame(g_knn.cv_results_)[['params', 'mean_test_score', 'rank_test_score']]
display(knn_result_df)

knn = g_knn.best_estimator_
print(knn_result_df[knn_result_df['rank_test_score'] == 1])
# Out:
#                 params  mean_test_score  rank_test_score
# 0   {'n_neighbors': 3}         0.506742                2
# 1   {'n_neighbors': 5}         0.505504                4
# 2   {'n_neighbors': 7}         0.505998                3
# 3  {'n_neighbors': 11}         0.507175                1
#                 params  mean_test_score  rank_test_score
# 3  {'n_neighbors': 11}         0.507175                1

# %%
rfc_result_df = pd.DataFrame(g_rfc.cv_results_)[['params', 'mean_test_score', 'rank_test_score']]
display(rfc_result_df)

rfc = g_rfc.best_estimator_
print(rfc_result_df[rfc_result_df['rank_test_score'] == 1])
# Out:
#                                          params  mean_test_score  \
# 0   {'max_depth': 40, 'min_samples_split': 110}         0.507484
# 1   {'max_depth': 40, 'min_samples_split': 120}         0.509093
# 2   {'max_depth': 40, 'min_samples_split': 130}         0.511937
# 3   {'max_depth': 40, 'min_samples_split': 140}         0.507545
# 4   {'max_depth': 41, 'min_samples_split': 110}         0.502721
# 5   {'max_depth': 41, 'min_samples_split': 120}         0.509465
# 6   {'max_depth': 41, 'min_samples_split': 130}         0.511875
# 7   {'max_depth': 41, 'min_samples_split': 140}         0.508226
# 8   {'max_depth': 42, 'min_samples_split': 110}         0.508907
# 9   {'max_depth': 42, 'min_samples_split': 120}         0.507484
# 10  {'max_depth': 42, 'min_samples_split': 130}         0.505876
# 11  {'max_depth': 42, 'min_samples_split': 140}         0.510886
# 12  {'max_depth': 43, 'min_samples_split': 110}         0.511009
# 13  {'max_depth': 43, 'min_samples_split': 120}         0.512184
# 14  {'max_depth': 43, 'min_samples_split': 130}         0.509339
# 15  {'max_depth': 43, 'min_samples_split': 140}         0.508041
#
#     rank_test_score
# 0                14
# 1                 8
# 2                 2
# 3                12
# 4                16
# 5                 6
# 6                 3
# 7                10
# 8                 9
# 9                13
# 10               15
# 11                5
# 12                4
# 13                1
# 14                7
# 15               11
#                                          params  mean_test_score  \
# 13  {'max_depth': 43, 'min_samples_split': 120}         0.512184
#
#     rank_test_score
# 13                1

# %% [markdown]
# #### 4-1. Hard voting

# %%
from sklearn.ensemble import VotingClassifier

# 하드 보팅
vch = VotingClassifier(estimators=[('dtc', dtc), 
                                  ('knn', knn), 
                                  ('rfc', rfc)], 
                                  voting='hard', 
                                  n_jobs=-1)

# %%
vch.fit(X_train_over, y_train_over)
# Out:
# VotingClassifier(estimators=[('dtc',
#                               DecisionTreeClassifier(max_depth=41,
#                                                      min_samples_split=140)),
#                              ('knn', KNeighborsClassifier(n_neighbors=11)),
#                              ('rfc',
#                               RandomForestClassifier(max_depth=43,
#                                                      min_samples_split=120))],
#                  n_jobs=-1)

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, confusion_matrix, ConfusionMatrixDisplay

def get_evaluation(y_test, prediction, classifier=None, X_test=None):
    confusion = confusion_matrix(y_test, prediction)
    accuracy = accuracy_score(y_test , prediction)
    precision = precision_score(y_test , prediction)
    recall = recall_score(y_test , prediction)
    f1 = f1_score(y_test, prediction)
    auc = roc_auc_score(y_test, prediction)
    
    print('오차 행렬')
    print(confusion)
    print('정확도: {0:.4f}, 정밀도: {1:.4f}, 재현율: {2:.4f}, F1: {3:.4f}, ROC-AUC: {4:.4f}'.format(accuracy, precision, recall, f1, auc))
    print("#" * 80)
    
    if classifier is not None and  X_test is not None:
        fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12,4))
        titles_options = [("Confusion matrix", None), ("Normalized confusion matrix", "true")]

        for (title, normalize), ax in zip(titles_options, axes.flatten()):
            disp = ConfusionMatrixDisplay.from_estimator(classifier, X_test, y_test, ax=ax, cmap=plt.cm.Blues, normalize=normalize)
            disp.ax_.set_title(title)
        plt.show()

# %%
prediction = vch.predict(X_test)
hv_ac = round(accuracy_score(y_test , prediction), 4)
hv_pr = round(precision_score(y_test , prediction), 4)
hv_rc = round(recall_score(y_test , prediction), 4)
hv_f1 = round(f1_score(y_test , prediction), 4)
hv_rac = round(roc_auc_score(y_test , prediction), 4)

# %%
get_evaluation(y_test, prediction, vch, X_test)
# Out:
# 오차 행렬
# [[1399  628]
#  [ 583 1390]]
# 정확도: 0.6973, 정밀도: 0.6888, 재현율: 0.7045, F1: 0.6966, ROC-AUC: 0.6973
# ################################################################################

# %% [markdown]
# <!-- ### 하드 보팅(Hard Voting)
# <img src="./images/hard_voting_pre.png">
#
# ### 소프트 보팅(soft Voting)
# <img src="./images/soft_voting_pre.png"> -->

# %% [markdown]
# #### 4-2. Soft Voting

# %%
from sklearn.ensemble import VotingClassifier

# 소프트 보팅
vcs = VotingClassifier(estimators=[('dtc', dtc), 
                                  ('knn', knn), 
                                  ('rfc', rfc)], 
                                  voting='soft', 
                                  n_jobs=-1)

# %%
vcs.fit(X_train_over, y_train_over)
# Out:
# VotingClassifier(estimators=[('dtc',
#                               DecisionTreeClassifier(max_depth=41,
#                                                      min_samples_split=140)),
#                              ('knn', KNeighborsClassifier(n_neighbors=11)),
#                              ('rfc',
#                               RandomForestClassifier(max_depth=43,
#                                                      min_samples_split=120))],
#                  n_jobs=-1)

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, confusion_matrix, ConfusionMatrixDisplay

def get_evaluation(y_test, prediction, classifier=None, X_test=None):
    confusion = confusion_matrix(y_test, prediction)
    accuracy = accuracy_score(y_test , prediction)
    precision = precision_score(y_test , prediction)
    recall = recall_score(y_test , prediction)
    f1 = f1_score(y_test, prediction)
    auc = roc_auc_score(y_test, prediction)
    
    print('오차 행렬')
    print(confusion)
    print('정확도: {0:.4f}, 정밀도: {1:.4f}, 재현율: {2:.4f}, F1: {3:.4f}, ROC-AUC: {4:.4f}'.format(accuracy, precision, recall, f1, auc))
    print("#" * 80)
    
    if classifier is not None and  X_test is not None:
        fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12,4))
        titles_options = [("Confusion matrix", None), ("Normalized confusion matrix", "true")]

        for (title, normalize), ax in zip(titles_options, axes.flatten()):
            disp = ConfusionMatrixDisplay.from_estimator(classifier, X_test, y_test, ax=ax, cmap=plt.cm.Blues, normalize=normalize)
            disp.ax_.set_title(title)
        plt.show()

# %%
prediction = vcs.predict(X_test)
sv_ac = round(accuracy_score(y_test , prediction), 4)
sv_pr = round(precision_score(y_test , prediction), 4)
sv_rc = round(recall_score(y_test , prediction), 4)
sv_f1 = round(f1_score(y_test , prediction), 4)
sv_rac = round(roc_auc_score(y_test , prediction), 4)

# %%
get_evaluation(y_test, prediction, vcs, X_test)
# Out:
# 오차 행렬
# [[1399  628]
#  [ 557 1416]]
# 정확도: 0.7037, 정밀도: 0.6928, 재현율: 0.7177, F1: 0.7050, ROC-AUC: 0.7039
# ################################################################################

# %% [markdown]
# ### Voting 시각화

# %%
import matplotlib.pyplot as plt

plt.rcParams['font.family'] = 'Malgun Gothic'
plt.figure(figsize=(10, 6))
colors = ['royalblue', 'slategrey']
accuracies = [hv_ac,
           sv_ac,
             ]
classifiers = ['Hard-Voting', 'Soft-Voting']
plt.bar(classifiers, accuracies, color=colors)
plt.xlabel('분류기법')
plt.ylabel('정확도')
plt.title('정확도 점수 비교')
plt.ylim(0, 1)
# plt.xticks(rotation=60)

for i, v in enumerate(accuracies):
    plt.text(i, v + 0.01, str(v), color='black', ha='center')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.rcParams['font.family'] = 'Malgun Gothic'
plt.figure(figsize=(10, 6))
colors = ['royalblue', 'slategrey']
recalls = [hv_rc,
           sv_rc,
             ]
classifiers = ['Hard-Voting', 'Soft-Voting']
plt.bar(classifiers, recalls, color=colors)
plt.xlabel('분류기법')
plt.ylabel('재현율')
plt.title('재현율 점수 비교')
plt.ylim(0, 1)
# plt.xticks(rotation=60)

for i, v in enumerate(recalls):
    plt.text(i, v + 0.01, str(v), color='black', ha='center')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.rcParams['font.family'] = 'Malgun Gothic'
plt.figure(figsize=(10, 6))
colors = ['royalblue', 'slategrey']
f1s = [hv_f1,
           sv_f1,
             ]
classifiers = ['Hard-Voting', 'Soft-Voting']
plt.bar(classifiers, f1s, color=colors)
plt.xlabel('분류기법')
plt.ylabel('F1 점수')
plt.title('F1 점수 비교')
plt.ylim(0, 1)
# plt.xticks(rotation=60)

for i, v in enumerate(f1s):
    plt.text(i, v + 0.01, str(v), color='black', ha='center')
plt.show()

# %% [markdown]
# ### 📝 Voting 결과
# Hard Voting과 Soft Voting을 각각 사용했을 때, <strong>정확도가 Soft Voting이</strong> 0.7037, Hard Voting이 0.6973로  <strong>더 높은</strong> 정확도가 나왔다.
# 그 외에도 <strong>재현율, F1 점수도 Soft Voting이 더 높은 것으로</strong> 나왔다.
# <strong>그리고 이 다음으로는 Boosting의 Adaboost, GBM, XGBoost, LightGBM 사용해보도록 하겠다.<strong>

# %% [markdown]
# ### 5. Boosting

# %% [markdown]
# ### 5-1. AdaBoosting 결과

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import AdaBoostClassifier

parmeters = {
    'n_estimators': [50, 100, 150],
    'learning_rate': [0.3, 0.5, 0.7, 1]
}

g_ada = GridSearchCV(AdaBoostClassifier(), param_grid=parmeters, cv=5, n_jobs=-1, refit=True, return_train_score=True)
g_ada.fit(X_train_over, y_train_over)
# Out:
# GridSearchCV(cv=5, estimator=AdaBoostClassifier(), n_jobs=-1,
#              param_grid={'learning_rate': [0.3, 0.5, 0.7, 1],
#                          'n_estimators': [50, 100, 150]},
#              return_train_score=True)

# %%
ada_result_df = pd.DataFrame(g_ada.cv_results_)[['params', 'mean_test_score', 'rank_test_score']]
display(ada_result_df)
# Out:
#                                          params  mean_test_score  \
# 0    {'learning_rate': 0.3, 'n_estimators': 50}         0.500309
# 1   {'learning_rate': 0.3, 'n_estimators': 100}         0.501051
# 2   {'learning_rate': 0.3, 'n_estimators': 150}         0.496784
# 3    {'learning_rate': 0.5, 'n_estimators': 50}         0.500556
# 4   {'learning_rate': 0.5, 'n_estimators': 100}         0.500557
# 5   {'learning_rate': 0.5, 'n_estimators': 150}         0.500186
# 6    {'learning_rate': 0.7, 'n_estimators': 50}         0.498701
# 7   {'learning_rate': 0.7, 'n_estimators': 100}         0.498268
# 8   {'learning_rate': 0.7, 'n_estimators': 150}         0.497774
# 9      {'learning_rate': 1, 'n_estimators': 50}         0.497217
# 10    {'learning_rate': 1, 'n_estimators': 100}         0.495238
# 11    {'learning_rate': 1, 'n_estimators': 150}         0.496103
#
#     rank_test_score
# 0                 4
# 1                 1
# 2                10
# 3                 3
# 4                 2
# 5                 5
# 6                 6
# 7                 7
# 8                 8
# 9                 9
# 10               12
# 11               11

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, confusion_matrix, ConfusionMatrixDisplay

def get_evaluation(y_test, prediction, classifier=None, X_test=None):
    confusion = confusion_matrix(y_test, prediction)
    accuracy = accuracy_score(y_test , prediction)
    precision = precision_score(y_test , prediction)
    recall = recall_score(y_test , prediction)
    f1 = f1_score(y_test, prediction)
    auc = roc_auc_score(y_test, prediction)
    
    print('오차 행렬')
    print(confusion)
    print('정확도: {0:.4f}, 정밀도: {1:.4f}, 재현율: {2:.4f}, F1: {3:.4f}, ROC-AUC: {4:.4f}'.format(accuracy, precision, recall, f1, auc))
    print("#" * 80)
    
    if classifier is not None and  X_test is not None:
        fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12,4))
        titles_options = [("Confusion matrix", None), ("Normalized confusion matrix", "true")]

        for (title, normalize), ax in zip(titles_options, axes.flatten()):
            disp = ConfusionMatrixDisplay.from_estimator(classifier, X_test, y_test, ax=ax, cmap=plt.cm.Blues, normalize=normalize)
            disp.ax_.set_title(title)
        plt.show()

# %%
ada = g_ada.best_estimator_
prediction = ada.predict(X_test)
ada_ac = round(accuracy_score(y_test , prediction), 4)
ada_pr = round(precision_score(y_test , prediction), 4)
ada_rc = round(recall_score(y_test , prediction), 4)
ada_f1 = round(f1_score(y_test , prediction), 4)
ada_rac = round(roc_auc_score(y_test , prediction), 4)

# %%
print(ada)
# Out:
# AdaBoostClassifier(learning_rate=0.3, n_estimators=100)

# %%
get_evaluation(y_test, prediction, ada, X_test)
# Out:
# 오차 행렬
# [[ 978 1049]
#  [ 892 1081]]
# 정확도: 0.5148, 정밀도: 0.5075, 재현율: 0.5479, F1: 0.5269, ROC-AUC: 0.5152
# ################################################################################

# %% [markdown]
# ### 📌 5-1. Adabosst 결과
# Adabosst를 사용하여
# <strong>learning_rate=0.3, n_estimators=100으로 설정</strong> 했을 때가 가장 성능이 좋은 것으로 나왔지만,
# <strong>정확도: 0.5148, 정밀도: 0.5075, 재현율: 0.5479, F1: 0.5269, ROC-AUC: 0.5152</strong>로서 다른 분류기들보다 <strong>저조한 성능</strong>인듯 하다.
# <strong>다음으로는 GBM을 사용해보도록 하겠다.</strong>

# %% [markdown]
# ### 5-2. GBM(Gradient Boost Machine)

# %%
pre_df
# Out:
#             age  gender    income  appearance_score  interests_score  \
# 0     -0.458119       1  1.592499          0.478004         1.328635
# 1     -0.911135       1  1.244477         -1.649649         0.001020
# 2      0.749922       1 -0.659865         -0.783905        -0.557829
# 3      1.202937       1  1.697812         -0.963287        -0.850808
# 4      1.353942       1 -0.377454          0.814259        -0.219670
# ...         ...     ...       ...               ...              ...
# 19995 -0.458119       0 -0.790338          0.536182        -0.144253
# 19996 -1.213145       0  0.306068         -0.622184        -1.066632
# 19997  0.296906       1 -1.046839         -0.177191        -1.251873
# 19998  0.598916       0 -1.590829          0.814952         0.498355
# 19999 -1.213145       1  0.101618         -0.004042        -0.068836
#
#        confidence_score  educational_status  job_type  valentine_date
# 0             -0.684104                   0         0               1
# 1              0.915729                   0         0               1
# 2             -0.557457                   3         0               1
# 3             -0.227552                   2         1               1
# 4             -0.603008                   0         0               0
# ...                 ...                 ...       ...             ...
# 19995          1.287735                   1         0               0
# 19996         -1.450547                   1         0               1
# 19997         -0.354544                   3         1               1
# 19998         -0.703429                   2         1               1
# 19999         -0.140244                   2         1               0
#
# [20000 rows x 9 columns]

# %%
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.ensemble import GradientBoostingClassifier

features, targets = pre_df.iloc[:, :-1], pre_df.iloc[:, -1]

parameters = {
    'n_estimators': [50, 100, 500],
    'learning_rate': [0.3, 0.5, 0.7, 1]
}

g_gbc = GridSearchCV(GradientBoostingClassifier(loss='log_loss'), param_grid=parameters, cv=3, n_jobs=-1, refit=True, return_train_score=True)
g_gbc.fit(X_train_over, y_train_over)
# Out:
# GridSearchCV(cv=3, estimator=GradientBoostingClassifier(), n_jobs=-1,
#              param_grid={'learning_rate': [0.3, 0.5, 0.7, 1],
#                          'n_estimators': [50, 100, 500]},
#              return_train_score=True)

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, confusion_matrix, ConfusionMatrixDisplay

def get_evaluation(y_test, prediction, classifier=None, X_test=None):
    confusion = confusion_matrix(y_test, prediction)
    accuracy = accuracy_score(y_test , prediction)
    precision = precision_score(y_test , prediction)
    recall = recall_score(y_test , prediction)
    f1 = f1_score(y_test, prediction)
    auc = roc_auc_score(y_test, prediction)
    
    print('오차 행렬')
    print(confusion)
    print('정확도: {0:.4f}, 정밀도: {1:.4f}, 재현율: {2:.4f}, F1: {3:.4f}, ROC-AUC: {4:.4f}'.format(accuracy, precision, recall, f1, auc))
    print("#" * 80)
    
    if classifier is not None and  X_test is not None:
        fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12,4))
        titles_options = [("Confusion matrix", None), ("Normalized confusion matrix", "true")]

        for (title, normalize), ax in zip(titles_options, axes.flatten()):
            disp = ConfusionMatrixDisplay.from_estimator(classifier, X_test, y_test, ax=ax, cmap=plt.cm.Blues, normalize=normalize)
            disp.ax_.set_title(title)
        plt.show()

# %%
gbc = g_gbc.best_estimator_
prediction = gbc.predict(X_test)
gbc_ac = round(accuracy_score(y_test , prediction), 4)
gbc_pr = round(precision_score(y_test , prediction), 4)
gbc_rc = round(recall_score(y_test , prediction), 4)
gbc_f1 = round(f1_score(y_test , prediction), 4)
gbc_rac = round(roc_auc_score(y_test , prediction), 4)

# %%
print(gbc)
# Out:
# GradientBoostingClassifier(learning_rate=0.5, n_estimators=500)

# %%
get_evaluation(y_test, prediction, gbc, X_test)
# Out:
# 오차 행렬
# [[1532  495]
#  [ 507 1466]]
# 정확도: 0.7495, 정밀도: 0.7476, 재현율: 0.7430, F1: 0.7453, ROC-AUC: 0.7494
# ################################################################################

# %% [markdown]
# ### 📌 5-2. GBM 결과
# <strong>learning_rate=0.5, n_estimators=500</strong> 일 때,
# <strong>정확도: 0.7495, 정밀도: 0.7476, 재현율: 0.7430, F1: 0.7453, ROC-AUC: 0.7494</strong>로써 그전까지 가장 높았던, <strong>RFC보다도 더 높은 성능</strong>이다.
# <strong>다음으론 XGBoost를 사용해보도록 하겠다.</strong>

# %% [markdown]
# ### 5-3. XGBoost(eXtra Gradient Boosting)

# %%
from sklearn.model_selection import train_test_split

features, targets = pre_df.iloc[:, :-1], pre_df.iloc[:, -1]

X_train, X_test, y_train, y_test = \
train_test_split(features, targets, stratify=targets, test_size=0.2, random_state=124)

X_val_train, X_val_test, y_val_train, y_val_test = \
train_test_split(X_train, y_train, stratify=y_train, test_size=0.2, random_state=124)

evals = [(X_val_train, y_val_train), (X_val_test, y_val_test)]

# %%
from sklearn.model_selection import GridSearchCV
from xgboost import XGBClassifier

parameters = {
    'n_estimators': [50, 100, 500],
    'learning_rate': [0.3, 0.5, 0.7, 1]
}

xgb = XGBClassifier()

g_xgb = GridSearchCV(xgb, 
                     param_grid=parameters, 
                     cv=5, 
                     refit=True, 
                     return_train_score=True, 
                     n_jobs=-1)

g_xgb.fit(X_train_over, y_train_over, early_stopping_rounds=50, eval_set=evals)
# Out:
# [0]	validation_0-logloss:0.68936	validation_1-logloss:0.68973
# [1]	validation_0-logloss:0.68684	validation_1-logloss:0.68761
# [2]	validation_0-logloss:0.68402	validation_1-logloss:0.68315
# [3]	validation_0-logloss:0.68123	validation_1-logloss:0.67948
# [4]	validation_0-logloss:0.67994	validation_1-logloss:0.67840
# [5]	validation_0-logloss:0.67683	validation_1-logloss:0.67401
# [6]	validation_0-logloss:0.67472	validation_1-logloss:0.67170
# [7]	validation_0-logloss:0.67298	validation_1-logloss:0.67043
# [8]	validation_0-logloss:0.66996	validation_1-logloss:0.66755
# [9]	validation_0-logloss:0.66890	validation_1-logloss:0.66601
# [10]	validation_0-logloss:0.66687	validation_1-logloss:0.66414
# [11]	validation_0-logloss:0.66415	validation_1-logloss:0.66076
# [12]	validation_0-logloss:0.66292	validation_1-logloss:0.65992
# [13]	validation_0-logloss:0.65999	validation_1-logloss:0.65718
# [14]	validation_0-logloss:0.65780	validation_1-logloss:0.65433
# [15]	validation_0-logloss:0.65675	validation_1-logloss:0.65318
# [16]	validation_0-logloss:0.65535	validation_1-logloss:0.65155
# [17]	validation_0-logloss:0.65334	validation_1-logloss:0.64971
# [18]	validation_0-logloss:0.65166	validation_1-logloss:0.64862
# [19]	validation_0-logloss:0.64931	validation_1-logloss:0.64620
# [20]	validation_0-logloss:0.64855	validation_1-logloss:0.64559
# [21]	validation_0-logloss:0.64611	validation_1-logloss:0.64329
# [22]	validation_0-logloss:0.64348	validation_1-logloss:0.64151
# [23]	validation_0-logloss:0.64130	validation_1-logloss:0.63855
# [24]	validation_0-logloss:0.64054	validation_1-logloss:0.63758
# [25]	validation_0-logloss:0.63884	validation_1-logloss:0.63585
# [26]	validation_0-logloss:0.63721	validation_1-logloss:0.63325
# [27]	validation_0-logloss:0.63533	validation_1-logloss:0.63115
# [28]	validation_0-logloss:0.63497	validation_1-logloss:0.63068
# [29]	validation_0-logloss:0.63284	validation_1-logloss:0.62877
# [30]	validation_0-logloss:0.63131	validation_1-logloss:0.62682
# [31]	validation_0-logloss:0.63100	validation_1-logloss:0.62661
# [32]	validation_0-logloss:0.62940	validation_1-logloss:0.62444
# [33]	validation_0-logloss:0.62786	validation_1-logloss:0.62317
# [34]	validation_0-logloss:0.62701	validation_1-logloss:0.62241
# [35]	validation_0-logloss:0.62466	validation_1-logloss:0.62045
# [36]	validation_0-logloss:0.62319	validation_1-logloss:0.61812
# [37]	validation_0-logloss:0.62162	validation_1-logloss:0.61660
# [38]	validation_0-logloss:0.61972	validation_1-logloss:0.61488
# [39]	validation_0-logloss:0.61714	validation_1-logloss:0.61233
# [40]	validation_0-logloss:0.61605	validation_1-logloss:0.61134
# [41]	validation_0-logloss:0.61434	validation_1-logloss:0.60916
# [42]	validation_0-logloss:0.61362	validation_1-logloss:0.60766
# [43]	validation_0-logloss:0.61160	validation_1-logloss:0.60599
# [44]	validation_0-logloss:0.61035	validation_1-logloss:0.60424
# [45]	validation_0-logloss:0.60930	validation_1-logloss:0.60275
# [46]	validation_0-logloss:0.60748	validation_1-logloss:0.60086
# [47]	validation_0-logloss:0.60611	validation_1-logloss:0.59930
# [48]	validation_0-logloss:0.60459	validation_1-logloss:0.59722
# [49]	validation_0-logloss:0.60343	validation_1-logloss:0.59610
# [50]	validation_0-logloss:0.60255	validation_1-logloss:0.59579
# [51]	validation_0-logloss:0.60098	validation_1-logloss:0.59457
# [52]	validation_0-logloss:0.59932	validation_1-logloss:0.59274
# [53]	validation_0-logloss:0.59860	validation_1-logloss:0.59194
# [54]	validation_0-logloss:0.59719	validation_1-logloss:0.59089
# [55]	validation_0-logloss:0.59554	validation_1-logloss:0.58973
# [56]	validation_0-logloss:0.59410	validation_1-logloss:0.58792
# [57]	validation_0-logloss:0.59261	validation_1-logloss:0.58673
# [58]	validation_0-logloss:0.59062	validation_1-logloss:0.58528
# C:\ProgramData\anaconda3\Lib\site-packages\xgboost\sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [59]	validation_0-logloss:0.58996	validation_1-logloss:0.58429
# [60]	validation_0-logloss:0.58849	validation_1-logloss:0.58353
# [61]	validation_0-logloss:0.58762	validation_1-logloss:0.58231
# [62]	validation_0-logloss:0.58694	validation_1-logloss:0.58179
# [63]	validation_0-logloss:0.58558	validation_1-logloss:0.58078
# [64]	validation_0-logloss:0.58494	validation_1-logloss:0.58003
# [65]	validation_0-logloss:0.58322	validation_1-logloss:0.57870
# [66]	validation_0-logloss:0.58191	validation_1-logloss:0.57718
# [67]	validation_0-logloss:0.58058	validation_1-logloss:0.57657
# [68]	validation_0-logloss:0.57992	validation_1-logloss:0.57602
# [69]	validation_0-logloss:0.57909	validation_1-logloss:0.57496
# [70]	validation_0-logloss:0.57729	validation_1-logloss:0.57294
# [71]	validation_0-logloss:0.57626	validation_1-logloss:0.57195
# [72]	validation_0-logloss:0.57561	validation_1-logloss:0.57093
# [73]	validation_0-logloss:0.57431	validation_1-logloss:0.56957
# [74]	validation_0-logloss:0.57349	validation_1-logloss:0.56794
# [75]	validation_0-logloss:0.57237	validation_1-logloss:0.56718
# [76]	validation_0-logloss:0.57099	validation_1-logloss:0.56592
# [77]	validation_0-logloss:0.56944	validation_1-logloss:0.56405
# [78]	validation_0-logloss:0.56861	validation_1-logloss:0.56345
# [79]	validation_0-logloss:0.56661	validation_1-logloss:0.56146
# [80]	validation_0-logloss:0.56508	validation_1-logloss:0.55949
# [81]	validation_0-logloss:0.56381	validation_1-logloss:0.55853
# [82]	validation_0-logloss:0.56302	validation_1-logloss:0.55770
# [83]	validation_0-logloss:0.56183	validation_1-logloss:0.55646
# [84]	validation_0-logloss:0.56118	validation_1-logloss:0.55583
# [85]	validation_0-logloss:0.55995	validation_1-logloss:0.55500
# [86]	validation_0-logloss:0.55908	validation_1-logloss:0.55452
# [87]	validation_0-logloss:0.55818	validation_1-logloss:0.55372
# [88]	validation_0-logloss:0.55765	validation_1-logloss:0.55320
# [89]	validation_0-logloss:0.55653	validation_1-logloss:0.55154
# [90]	validation_0-logloss:0.55519	validation_1-logloss:0.55051
# [91]	validation_0-logloss:0.55352	validation_1-logloss:0.54977
# [92]	validation_0-logloss:0.55282	validation_1-logloss:0.54831
# [93]	validation_0-logloss:0.55227	validation_1-logloss:0.54730
# [94]	validation_0-logloss:0.55156	validation_1-logloss:0.54651
# [95]	validation_0-logloss:0.55027	validation_1-logloss:0.54522
# [96]	validation_0-logloss:0.54934	validation_1-logloss:0.54364
# [97]	validation_0-logloss:0.54741	validation_1-logloss:0.54201
# [98]	validation_0-logloss:0.54632	validation_1-logloss:0.54060
# [99]	validation_0-logloss:0.54549	validation_1-logloss:0.53945
# GridSearchCV(cv=5,
#              estimator=XGBClassifier(base_score=None, booster=None,
#                                      callbacks=None, colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=None, device=None,
#                                      early_stopping_rounds=None,
#                                      enable_categorical=False, eval_metric=None,
#                                      feature_types=None, gamma=None,
#                                      grow_policy=None, importance_type=None,
#                                      interaction_constraints=None,
#                                      learning_rate=None,...
#                                      max_cat_threshold=None,
#                                      max_cat_to_onehot=None,
#                                      max_delta_step=None, max_depth=None,
#                                      max_leaves=None, min_child_weight=None,
#                                      missing=nan, monotone_constraints=None,
#                                      multi_strategy=None, n_estimators=None,
#                                      n_jobs=None, num_parallel_tree=None,
#                                      random_state=None, ...),
#              n_jobs=-1,
#              param_grid={'learning_rate': [0.3, 0.5, 0.7, 1],
#                          'n_estimators': [50, 100, 500]},
#              return_train_score=True)

# %%
xgb_result_df = pd.DataFrame(g_xgb.cv_results_)[['params', 'mean_test_score', 'rank_test_score']]
display(xgb_result_df)
# Out:
#                                          params  mean_test_score  \
# 0    {'learning_rate': 0.3, 'n_estimators': 50}         0.501361
# 1   {'learning_rate': 0.3, 'n_estimators': 100}         0.508659
# 2   {'learning_rate': 0.3, 'n_estimators': 500}         0.503897
# 3    {'learning_rate': 0.5, 'n_estimators': 50}         0.500804
# 4   {'learning_rate': 0.5, 'n_estimators': 100}         0.496413
# 5   {'learning_rate': 0.5, 'n_estimators': 500}         0.506928
# 6    {'learning_rate': 0.7, 'n_estimators': 50}         0.500246
# 7   {'learning_rate': 0.7, 'n_estimators': 100}         0.504082
# 8   {'learning_rate': 0.7, 'n_estimators': 500}         0.503649
# 9      {'learning_rate': 1, 'n_estimators': 50}         0.498578
# 10    {'learning_rate': 1, 'n_estimators': 100}         0.500494
# 11    {'learning_rate': 1, 'n_estimators': 500}         0.498948
#
#     rank_test_score
# 0                 6
# 1                 1
# 2                 4
# 3                 7
# 4                12
# 5                 2
# 6                 9
# 7                 3
# 8                 5
# 9                11
# 10                8
# 11               10

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, confusion_matrix, ConfusionMatrixDisplay

def get_evaluation(y_test, prediction, classifier=None, X_test=None):
    confusion = confusion_matrix(y_test, prediction)
    accuracy = accuracy_score(y_test , prediction)
    precision = precision_score(y_test , prediction)
    recall = recall_score(y_test , prediction)
    f1 = f1_score(y_test, prediction)
    auc = roc_auc_score(y_test, prediction)
    
    print('오차 행렬')
    print(confusion)
    print('정확도: {0:.4f}, 정밀도: {1:.4f}, 재현율: {2:.4f}, F1: {3:.4f}, ROC-AUC: {4:.4f}'.format(accuracy, precision, recall, f1, auc))
    print("#" * 80)
    
    if classifier is not None and  X_test is not None:
        fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12,4))
        titles_options = [("Confusion matrix", None), ("Normalized confusion matrix", "true")]

        for (title, normalize), ax in zip(titles_options, axes.flatten()):
            disp = ConfusionMatrixDisplay.from_estimator(classifier, X_test, y_test, ax=ax, cmap=plt.cm.Blues, normalize=normalize)
            disp.ax_.set_title(title)
        plt.show()

# %%
xgb = g_xgb.best_estimator_
prediction = xgb.predict(X_test)
xgb_ac = round(accuracy_score(y_test , prediction), 4)
xgb_pr = round(precision_score(y_test , prediction), 4)
xgb_rc = round(recall_score(y_test , prediction), 4)
xgb_f1 = round(f1_score(y_test , prediction), 4)
xgb_rac = round(roc_auc_score(y_test , prediction), 4)

# %%
get_evaluation(y_test, prediction, xgb, X_test)
# Out:
# 오차 행렬
# [[1588  439]
#  [ 489 1484]]
# 정확도: 0.7680, 정밀도: 0.7717, 재현율: 0.7522, F1: 0.7618, ROC-AUC: 0.7678
# ################################################################################

# %% [markdown]
# ### 📌 5-3. XGBoost
# <strong>정확도: 0.7680, 정밀도: 0.7717, 재현율: 0.7522, F1: 0.7618, ROC-AUC: 0.7678</strong>
# Adaboost, GBM을 사용했을 때 보다 전체적으로 <strong>성능이 더 우수</strong>한 것으로 나타났다.
# <strong>마지막으로 LightGBM을을 사용하여 확인해보도록 하겠다.</strong>

# %% [markdown]
# ### 5-4. LightGBM(Light Gradient Boosting Machine)

# %%
from sklearn.model_selection import GridSearchCV, train_test_split
from imblearn.over_sampling import SMOTE
from lightgbm import LGBMClassifier

features, targets = pre_df.iloc[:, :-1], pre_df.iloc[:, -1]

parameters = {
    'n_estimators': [50, 100, 500],
    'learning_rate': [0.3, 0.5, 0.7, 1]
}

X_train, X_test, y_train, y_test = \
train_test_split(features, targets, stratify=targets, test_size=0.2, random_state=124)

X_val_train, X_val_test, y_val_train, y_val_test = \
train_test_split(X_train, y_train, stratify=y_train, test_size=0.2, random_state=124)

evals = [(X_val_train, y_val_train), (X_val_test, y_val_test)]

g_lgbm = GridSearchCV(LGBMClassifier(), param_grid=parameters, cv=3, refit=True, return_train_score=True, n_jobs=-1)
g_lgbm.fit(X_train_over, y_train_over, eval_set=evals)
# Out:
# [LightGBM] [Info] Number of positive: 8084, number of negative: 8084
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000156 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1096
# [LightGBM] [Info] Number of data points in the train set: 16168, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# GridSearchCV(cv=3, estimator=LGBMClassifier(), n_jobs=-1,
#              param_grid={'learning_rate': [0.3, 0.5, 0.7, 1],
#                          'n_estimators': [50, 100, 500]},
#              return_train_score=True)

# %%
lgbm_result_df = pd.DataFrame(g_lgbm.cv_results_)[['params', 'mean_test_score', 'rank_test_score']]
display(lgbm_result_df)

lgbm = g_lgbm.best_estimator_
# Out:
#                                          params  mean_test_score  \
# 0    {'learning_rate': 0.3, 'n_estimators': 50}         0.501114
# 1   {'learning_rate': 0.3, 'n_estimators': 100}         0.508782
# 2   {'learning_rate': 0.3, 'n_estimators': 500}         0.507360
# 3    {'learning_rate': 0.5, 'n_estimators': 50}         0.500742
# 4   {'learning_rate': 0.5, 'n_estimators': 100}         0.508041
# 5   {'learning_rate': 0.5, 'n_estimators': 500}         0.505814
# 6    {'learning_rate': 0.7, 'n_estimators': 50}         0.512556
# 7   {'learning_rate': 0.7, 'n_estimators': 100}         0.505072
# 8   {'learning_rate': 0.7, 'n_estimators': 500}         0.512742
# 9      {'learning_rate': 1, 'n_estimators': 50}         0.509896
# 10    {'learning_rate': 1, 'n_estimators': 100}         0.504948
# 11    {'learning_rate': 1, 'n_estimators': 500}         0.505505
#
#     rank_test_score
# 0                11
# 1                 4
# 2                 6
# 3                12
# 4                 5
# 5                 7
# 6                 2
# 7                 9
# 8                 1
# 9                 3
# 10               10
# 11                8

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, confusion_matrix, ConfusionMatrixDisplay

def get_evaluation(y_test, prediction, classifier=None, X_test=None):
    confusion = confusion_matrix(y_test, prediction)
    accuracy = accuracy_score(y_test , prediction)
    precision = precision_score(y_test , prediction)
    recall = recall_score(y_test , prediction)
    f1 = f1_score(y_test, prediction)
    auc = roc_auc_score(y_test, prediction)
    
    print('오차 행렬')
    print(confusion)
    print('정확도: {0:.4f}, 정밀도: {1:.4f}, 재현율: {2:.4f}, F1: {3:.4f}, ROC-AUC: {4:.4f}'.format(accuracy, precision, recall, f1, auc))
    print("#" * 80)
    
    if classifier is not None and  X_test is not None:
        fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12,4))
        titles_options = [("Confusion matrix", None), ("Normalized confusion matrix", "true")]

        for (title, normalize), ax in zip(titles_options, axes.flatten()):
            disp = ConfusionMatrixDisplay.from_estimator(classifier, X_test, y_test, ax=ax, cmap=plt.cm.Blues, normalize=normalize)
            disp.ax_.set_title(title)
        plt.show()

# %%
lgbm = g_lgbm.best_estimator_
prediction = lgbm.predict(X_test)
lgbm_ac = round(accuracy_score(y_test , prediction), 4)
lgbm_pr = round(precision_score(y_test , prediction), 4)
lgbm_rc = round(recall_score(y_test , prediction), 4)
lgbm_f1 = round(f1_score(y_test , prediction), 4)
lgbm_rac = round(roc_auc_score(y_test , prediction), 4)

# %%
get_evaluation(y_test, prediction, lgbm, X_test)
# Out:
# 오차 행렬
# [[1803  224]
#  [ 202 1771]]
# 정확도: 0.8935, 정밀도: 0.8877, 재현율: 0.8976, F1: 0.8926, ROC-AUC: 0.8936
# ################################################################################

# %% [markdown]
# ### 📌 5-4. LightGBM 결과
# <strong>굉장히 높은 성능이 나왔다.</strong>
# <strong>LightGBM은</strong>
# <strong>정확도: 0.8935, 정밀도: 0.8877, 재현율: 0.8976, F1: 0.8926, ROC-AUC: 0.8936</strong>로 전체적으로 이전 분류기들 보다 매우 높은 성능임을 알 수 있다.

# %% [markdown]
# ### 전체 시각화 비교

# %%
import matplotlib.pyplot as plt

plt.rcParams['font.family'] = 'Malgun Gothic'
plt.figure(figsize=(12, 8))
colors = ['salmon', 'olive', 'orchid', 'royalblue', 'slategrey', 'darkgreen', 'pink', 'mediumpurple', 'mediumseagreen']
accuracies = [dtc_ac,
              knn_ac,
              rfc_ac,
              hv_ac,
              sv_ac,
              ada_ac,
              gbc_ac,
              xgb_ac,
              lgbm_ac
             ]
classifiers = ['DTC', 'KNN', 'RFC', 'Hard-Voting', 'Soft-Voting', 'Adaboost', 'GMB', 'XGBoost', 'LightGBM']
plt.bar(classifiers, accuracies, color=colors)
plt.xlabel('분류기법')
plt.ylabel('정확도')
plt.title('정확도 점수 비교')
plt.ylim(0, 1)
plt.xticks(rotation=60)

for i, v in enumerate(accuracies):
    plt.text(i, v + 0.01, str(v), color='black', ha='center')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.rcParams['font.family'] = 'Malgun Gothic'
plt.figure(figsize=(12, 8))
colors = ['salmon', 'olive', 'orchid', 'royalblue', 'slategrey', 'darkgreen', 'pink', 'mediumpurple', 'mediumseagreen']
recalls = [dtc_rc,
              knn_rc,
              rfc_rc,
              hv_rc,
              sv_rc,
              ada_rc,
              gbc_rc,
              xgb_rc,
              lgbm_rc
             ]
classifiers = ['DTC', 'KNN', 'RFC', 'Hard-Voting', 'Soft-Voting', 'Adaboost', 'GMB', 'XGBoost', 'LightGBM']
plt.bar(classifiers, recalls, color=colors)
plt.xlabel('분류기법')
plt.ylabel('재현율')
plt.title('재현율 점수 비교')
plt.ylim(0, 1)
plt.xticks(rotation=60)

for i, v in enumerate(recalls):
    plt.text(i, v + 0.01, str(v), color='black', ha='center')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.rcParams['font.family'] = 'Malgun Gothic'
plt.figure(figsize=(12, 8))
colors = ['salmon', 'olive', 'orchid', 'royalblue', 'slategrey', 'darkgreen', 'pink', 'mediumpurple', 'mediumseagreen']
f1s = [dtc_f1,
       knn_f1,
       rfc_f1,
       hv_f1,
       sv_f1,
       ada_f1,
       gbc_f1,
       xgb_f1,
       lgbm_f1
      ]
classifiers = ['DTC', 'KNN', 'RFC', 'Hard-Voting', 'Soft-Voting', 'Adaboost', 'GMB', 'XGBoost', 'LightGBM']
plt.bar(classifiers, f1s, color=colors)
plt.xlabel('분류기법')
plt.ylabel('F1')
plt.title('F1 점수 비교')
plt.ylim(0, 1)
plt.xticks(rotation=60)

for i, v in enumerate(f1s):
    plt.text(i, v + 0.01, str(v), color='black', ha='center')
plt.show()

# %% [markdown]
# ### 📋 전체 시각화 결론
# - 1. 정확도
# > LighGMB이 0.8935로 가장 높은 정확도를 가지고 있다.
#
# - 2. 재현율
# > 이 역시 LighGMB이 가장 높은 수치를 가지고 있다.
#
# - 3. F1
# > F1 점수가 가장 높은 분류기법은 LightGBM이 0.8962로 가장 높은 수치를 가지고 있다.
#
# 따라서, <strong>LightGMB 분류기법은</strong> 세 지표에서 일관되게 가장 높은 값을 보여주므로 <strong>다른 분류기들 보다</strong> 전반적으로 <strong>더 높은 성능</strong>을 보이기 때문에 해당 데이터 세트에선 <strong>LightGMB이 가장 적합해</strong> 보인다.
#
# 그렇다면 LightGBM 모델의 성능을 좀 더 향상 시켜보도록 하겠다.

# %% [markdown]
# ### 6. Upgrade
# 위에서 수립했던 '정밀도와 재현율'의 방향에 맞게 <strong>재현율을 더 향상</strong> 시키는 방향으로 작업을 해보도록 하겠다.

# %%
from sklearn.model_selection import GridSearchCV, train_test_split
from imblearn.over_sampling import SMOTE
from lightgbm import LGBMClassifier

features, targets = pre_df.iloc[:, :-1], pre_df.iloc[:, -1]

parameters = {
    'n_estimators': [50, 100, 500],
    'learning_rate': [0.3, 0.5, 0.7, 1]
}

X_train, X_test, y_train, y_test = \
train_test_split(features, targets, stratify=targets, test_size=0.2, random_state=124)

X_val_train, X_val_test, y_val_train, y_val_test = \
train_test_split(X_train, y_train, stratify=y_train, test_size=0.2, random_state=124)

evals = [(X_val_train, y_val_train), (X_val_test, y_val_test)]

g_lgbm = GridSearchCV(LGBMClassifier(), param_grid=parameters, cv=3, refit=True, return_train_score=True, n_jobs=-1)
g_lgbm.fit(X_train_over, y_train_over, eval_set=evals)
# Out:
# [LightGBM] [Info] Number of positive: 8084, number of negative: 8084
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000122 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1096
# [LightGBM] [Info] Number of data points in the train set: 16168, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# GridSearchCV(cv=3, estimator=LGBMClassifier(), n_jobs=-1,
#              param_grid={'learning_rate': [0.3, 0.5, 0.7, 1],
#                          'n_estimators': [50, 100, 500]},
#              return_train_score=True)

# %%
lgbm_result_df = pd.DataFrame(g_lgbm.cv_results_)[['params', 'mean_test_score', 'rank_test_score']]
display(lgbm_result_df)

lgbm = g_lgbm.best_estimator_
# Out:
#                                          params  mean_test_score  \
# 0    {'learning_rate': 0.3, 'n_estimators': 50}         0.501114
# 1   {'learning_rate': 0.3, 'n_estimators': 100}         0.508782
# 2   {'learning_rate': 0.3, 'n_estimators': 500}         0.507360
# 3    {'learning_rate': 0.5, 'n_estimators': 50}         0.500742
# 4   {'learning_rate': 0.5, 'n_estimators': 100}         0.508041
# 5   {'learning_rate': 0.5, 'n_estimators': 500}         0.505814
# 6    {'learning_rate': 0.7, 'n_estimators': 50}         0.512556
# 7   {'learning_rate': 0.7, 'n_estimators': 100}         0.505072
# 8   {'learning_rate': 0.7, 'n_estimators': 500}         0.512742
# 9      {'learning_rate': 1, 'n_estimators': 50}         0.509896
# 10    {'learning_rate': 1, 'n_estimators': 100}         0.504948
# 11    {'learning_rate': 1, 'n_estimators': 500}         0.505505
#
#     rank_test_score
# 0                11
# 1                 4
# 2                 6
# 3                12
# 4                 5
# 5                 7
# 6                 2
# 7                 9
# 8                 1
# 9                 3
# 10               10
# 11                8

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, confusion_matrix, ConfusionMatrixDisplay

def get_evaluation(y_test, prediction, classifier=None, X_test=None):
    confusion = confusion_matrix(y_test, prediction)
    accuracy = accuracy_score(y_test , prediction)
    precision = precision_score(y_test , prediction)
    recall = recall_score(y_test , prediction)
    f1 = f1_score(y_test, prediction)
    auc = roc_auc_score(y_test, prediction)
    
    print('오차 행렬')
    print(confusion)
    print('정확도: {0:.4f}, 정밀도: {1:.4f}, 재현율: {2:.4f}, F1: {3:.4f}, ROC-AUC: {4:.4f}'.format(accuracy, precision, recall, f1, auc))
    print("#" * 80)
    
    if classifier is not None and  X_test is not None:
        fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12,4))
        titles_options = [("Confusion matrix", None), ("Normalized confusion matrix", "true")]

        for (title, normalize), ax in zip(titles_options, axes.flatten()):
            disp = ConfusionMatrixDisplay.from_estimator(classifier, X_test, y_test, ax=ax, cmap=plt.cm.Blues, normalize=normalize)
            disp.ax_.set_title(title)
        plt.show()

# %%
get_evaluation(y_test, prediction, lgbm, X_test)
# Out:
# 오차 행렬
# [[1803  224]
#  [ 202 1771]]
# 정확도: 0.8935, 정밀도: 0.8877, 재현율: 0.8976, F1: 0.8926, ROC-AUC: 0.8936
# ################################################################################

# %%
proba = lgbm.predict_proba(X_test)
prediction = lgbm.predict(X_test)

for proba, predict in zip(proba.tolist(), prediction.tolist()):
    print(proba, predict)
# Out:
# [0.031083850502910737, 0.9689161494970893] 1
# [0.9736300397674521, 0.026369960232547923] 0
# [0.2710476306691505, 0.7289523693308495] 1
# [0.9227095359814882, 0.07729046401851185] 0
# [0.42601908451562065, 0.5739809154843794] 1
# [0.04488948364144063, 0.9551105163585594] 1
# [0.003688404735967654, 0.9963115952640323] 1
# [0.1135488514063574, 0.8864511485936426] 1
# [0.022633038486352453, 0.9773669615136475] 1
# [0.9360088727159902, 0.06399112728400984] 0
# [0.8980459864010267, 0.10195401359897328] 0
# [0.998886194840847, 0.0011138051591531029] 0
# [0.9028764289846991, 0.09712357101530093] 0
# [0.49668423248734817, 0.5033157675126518] 1
# [0.9576306679636828, 0.042369332036317174] 0
# [0.9345087256579024, 0.06549127434209756] 0
# [0.9851363621544972, 0.014863637845502856] 0
# [0.9577302938908121, 0.04226970610918789] 0
# [0.9834487067026652, 0.016551293297334856] 0
# [0.038094412439065306, 0.9619055875609347] 1
# [0.9955017388799589, 0.004498261120041105] 0
# [0.9595815661487123, 0.04041843385128774] 0
# [0.6749452094638475, 0.3250547905361525] 0
# [0.9320013472020596, 0.06799865279794035] 0
# [0.9388978491312655, 0.06110215086873454] 0
# [0.001127360769798802, 0.9988726392302012] 1
# [0.039569495325010084, 0.9604305046749899] 1
# [0.9619956581853899, 0.03800434181461004] 0
# [0.05153129337912221, 0.9484687066208778] 1
# [0.8348468230795383, 0.1651531769204617] 0
# [0.9707361147002902, 0.029263885299709854] 0
# [0.9488665692901733, 0.05113343070982664] 0
# [0.9925716699517916, 0.007428330048208369] 0
# [0.7254296497450312, 0.2745703502549688] 0
# [0.16251116434772372, 0.8374888356522763] 1
# [0.028558106093357738, 0.9714418939066423] 1
# [0.9833519528671633, 0.01664804713283673] 0
# [0.021800244267869195, 0.9781997557321308] 1
# [0.022862341107737993, 0.977137658892262] 1
# [0.05971405732149182, 0.9402859426785082] 1
# [0.9711513439958774, 0.028848656004122557] 0
# [0.983157086623299, 0.016842913376700953] 0
binarizer = Binarizer(threshold=threshold).fit(custom_proba)
custom_prediction = binarizer.transform(custom_proba)

get_evaluation(y_test, custom_prediction)
# Out:
# 오차 행렬
# [[1803  224]
#  [ 202 1771]]
# 정확도: 0.8935, 정밀도: 0.8877, 재현율: 0.8976, F1: 0.8926, ROC-AUC: 0.8936
# ################################################################################

# %%
def get_evaluation_by_thresholds(y_test, proba_class1, thresholds):
    for threshold in thresholds:
        print(threshold)
        binarizer = Binarizer(threshold=threshold).fit(proba_class1)
        custom_prediction = binarizer.transform(proba_class1)
        get_evaluation(y_test, custom_prediction)

# %%
from sklearn.metrics import precision_recall_curve
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

def precision_recall_curve_plot(y_test , proba_class1):

    precisions, recalls, thresholds = precision_recall_curve(y_test, proba_class1)
    
    plt.figure(figsize=(8,6))
    threshold_boundary = thresholds.shape[0]
    plt.plot(thresholds, precisions[0:threshold_boundary], linestyle='--', label='precision')
    plt.plot(thresholds, recalls[0:threshold_boundary],label='recall')
    
    # X축(threshold)의 Scale을 0 ~ 1 단위로 변경
    start, end = plt.xlim()
    plt.xticks(np.round(np.arange(start, end, 0.1),2))
    
    plt.xlabel('Threshold value'); plt.ylabel('Precision and Recall value')
    plt.legend()
    plt.grid()
    plt.show()
    
precision_recall_curve_plot(y_test, lgbm.predict_proba(X_test)[:, 1].reshape(-1, 1))
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
from sklearn.metrics import roc_curve

def roc_curve_plot(y_test , proba_class1):
#     임계값에 따른 FPR, TPR 값
    fprs, tprs, thresholds = roc_curve(y_test, proba_class1)

#     ROC Curve를 plot 곡선으로 그림. 
    plt.plot(fprs , tprs, label='ROC')
#     가운데 대각선 직선을 그림. 
#     TPR과 FPR이 동일한 비율로 떨어진다는 것은 모델이 양성과 음성을 구별하지 못한다는 것을 의미한다.
#     다른 분류기를 판단하기 위한 기준선으로 사용되며, 
#     대각선에 가까울 수록 예측에 사용하기 힘든 모델이라는 뜻이다.
    plt.plot([0, 1], [0, 1], 'k--', label='Standard')
    
    # X축(FPR)의 Scale을 0.1 단위로 변경
    start, end = plt.xlim()
    plt.xticks(np.round(np.arange(start, end, 0.1),2))
    plt.xlim(0,1); plt.ylim(0,1)
    plt.xlabel('FPR( 1 - Sensitivity )'); plt.ylabel('TPR( Recall )')
    plt.legend()
    plt.show()
    
roc_curve_plot(y_test, lgbm.predict_proba(X_test)[:, 1].reshape(-1, 1))

# %%
proba_class1 = lgbm.predict_proba(X_test)[:, 1].reshape(-1, 1)
_, _, thresholds = precision_recall_curve(y_test, proba_class1)
thresholds
# Out:
# array([7.78984576e-06, 5.06149123e-05, 7.47764753e-05, ...,
#        9.99885132e-01, 9.99913415e-01, 9.99921766e-01])

# %%
get_evaluation_by_thresholds(y_test, proba_class1, thresholds)
# Out:
# 7.789845763799118e-06
# 오차 행렬
# [[   1 2026]
#  [   0 1973]]
# 정확도: 0.4935, 정밀도: 0.4934, 재현율: 1.0000, F1: 0.6608, ROC-AUC: 0.5002
# ################################################################################
# 5.061491230116287e-05
# 오차 행렬
# [[   2 2025]
#  [   0 1973]]
# 정확도: 0.4938, 정밀도: 0.4935, 재현율: 1.0000, F1: 0.6609, ROC-AUC: 0.5005
# ################################################################################
# 7.477647526753886e-05
# 오차 행렬
# [[   3 2024]
#  [   0 1973]]
# 정확도: 0.4940, 정밀도: 0.4936, 재현율: 1.0000, F1: 0.6610, ROC-AUC: 0.5007
# ################################################################################
# 9.314814590825363e-05
# 오차 행렬
# [[   3 2024]
#  [   1 1972]]
# 정확도: 0.4938, 정밀도: 0.4935, 재현율: 0.9995, F1: 0.6607, ROC-AUC: 0.5005
# ################################################################################
# 0.00011647259995603581
# 오차 행렬
# [[   4 2023]
#  [   1 1972]]
# 정확도: 0.4940, 정밀도: 0.4936, 재현율: 0.9995, F1: 0.6609, ROC-AUC: 0.5007
# ################################################################################
# 0.00012792270897213267
# 오차 행렬
# [[   5 2022]
#  [   1 1972]]
# 정확도: 0.4943, 정밀도: 0.4937, 재현율: 0.9995, F1: 0.6610, ROC-AUC: 0.5010
# ################################################################################
# 0.00012961751257835617
# 오차 행렬
# [[   6 2021]
#  [   1 1972]]
# 정확도: 0.4945, 정밀도: 0.4939, 재현율: 0.9995, F1: 0.6611, ROC-AUC: 0.5012
# ################################################################################
# 0.00013420895624516107
# 오차 행렬
# [[   6 2021]
#  [   2 1971]]
# 정확도: 0.4943, 정밀도: 0.4937, 재현율: 0.9990, F1: 0.6609, ROC-AUC: 0.5010
# ################################################################################
# 0.00013714837024999497
# 오차 행렬
# [[   7 2020]
#  [   2 1971]]
# 정확도: 0.4945, 정밀도: 0.4939, 재현율: 0.9990, F1: 0.6610, ROC-AUC: 0.5012
# ################################################################################
# 0.00015106694802329292
# 오차 행렬
# [[   8 2019]
#  [   2 1971]]
# 정확도: 0.4948, 정밀도: 0.4940, 재현율: 0.9990, F1: 0.6611, ROC-AUC: 0.5015
# ################################################################################
# 0.00018639166599883708
# 오차 행렬
# [[   8 2019]
#  [   3 1970]]
# 정확도: 0.4945, 정밀도: 0.4939, 재현율: 0.9985, F1: 0.6609, ROC-AUC: 0.5012
# ################################################################################
# 0.00020517965675945232
# 오차 행렬
# [[   9 2018]
#  [   3 1970]]
# 정확도: 0.4948, 정밀도: 0.4940, 재현율: 0.9985, F1: 0.6610, ROC-AUC: 0.5015
# ################################################################################
# 0.00020731700140010233
# 오차 행렬
# [[  10 2017]
#  [   3 1970]]
# 정확도: 0.4950, 정밀도: 0.4941, 재현율: 0.9985, F1: 0.6611, ROC-AUC: 0.5017
# ################################################################################
# 0.00021201225444145112
# 오차 행렬
# [[  11 2016]
#  [   3 1970]]
# 정확도: 0.4953, 정밀도: 0.4942, 재현율: 0.9985, F1: 0.6612, ROC-AUC: 0.5020
# ################################################################################
# 0.0002243893749692677
# 오차 행렬
# [[  12 2015]
#  [   3 1970]]
# 정확도: 0.4955, 정밀도: 0.4944, 재현율: 0.9985, F1: 0.6613, ROC-AUC: 0.5022
# ################################################################################
# 0.00026168737295818097
# 오차 행렬
# [[  12 2015]
#  [   4 1969]]
# 정확도: 0.4953, 정밀도: 0.4942, 재현율: 0.9980, F1: 0.6611, ROC-AUC: 0.5019
# ################################################################################
# 0.0002626565963537264
# 오차 행렬
# [[  13 2014]
#  [   4 1969]]
# 정확도: 0.4955, 정밀도: 0.4944, 재현율: 0.9980, F1: 0.6612, ROC-AUC: 0.5022
# ################################################################################
# 0.00028769368439560713
# 오차 행렬
# [[  14 2013]
#  [   4 1969]]
# 정확도: 0.4958, 정밀도: 0.4945, 재현율: 0.9980, F1: 0.6613, ROC-AUC: 0.5024
# ################################################################################
# 0.000334366973807226
# 오차 행렬
# [[  15 2012]
#  [   4 1969]]
# 정확도: 0.4960, 정밀도: 0.4946, 재현율: 0.9980, F1: 0.6614, ROC-AUC: 0.5027
# ################################################################################
# 0.0003517835385005537
# 오차 행렬
# [[  16 2011]
#  [   4 1969]]
# 정확도: 0.4963, 정밀도: 0.4947, 재현율: 0.9980, F1: 0.6615, ROC-AUC: 0.5029
# ################################################################################
# 0.00035557087693657727
# 오차 행렬
# [[  17 2010]
#  [   4 1969]]
# 정확도: 0.4965, 정밀도: 0.4948, 재현율: 0.9980, F1: 0.6616, ROC-AUC: 0.5032
# ################################################################################
# 0.0003681370877296694
# 오차 행렬
# [[  18 2009]
#  [   4 1969]]
# 정확도: 0.4968, 정밀도: 0.4950, 재현율: 0.9980, F1: 0.6617, ROC-AUC: 0.5034
# ################################################################################
# 0.00040146208035603113
# 오차 행렬
# [[  19 2008]
#  [   4 1969]]
# 정확도: 0.4970, 정밀도: 0.4951, 재현율: 0.9980, F1: 0.6618, ROC-AUC: 0.5037
# ################################################################################
# 0.0004153684823707469
# 오차 행렬
# [[  20 2007]
#  [   4 1969]]
# 정확도: 0.4973, 정밀도: 0.4952, 재현율: 0.9980, F1: 0.6620, ROC-AUC: 0.5039
# ################################################################################
# 0.0004899588558418624
# 오차 행렬
# [[  21 2006]
#  [   4 1969]]
# 정확도: 0.4975, 정밀도: 0.4953, 재현율: 0.9980, F1: 0.6621, ROC-AUC: 0.5042
# ################################################################################
# 0.0004980566025381197
# 오차 행렬
# [[  21 2006]
#  [   5 1968]]
# 정확도: 0.4973, 정밀도: 0.4952, 재현율: 0.9975, F1: 0.6618, ROC-AUC: 0.5039
# ################################################################################
# 0.0005177581158730782
# 오차 행렬
# [[  22 2005]
#  [   5 1968]]
# 정확도: 0.4975, 정밀도: 0.4953, 재현율: 0.9975, F1: 0.6620, ROC-AUC: 0.5042
# ################################################################################
# 0.0005653094584180716
# 오차 행렬
# [[  23 2004]
#  [   5 1968]]
# 정확도: 0.4978, 정밀도: 0.4955, 재현율: 0.9975, F1: 0.6621, ROC-AUC: 0.5044
# ################################################################################
# 0.0005810080729494096
# 오차 행렬
# [[  24 2003]
#  [   5 1968]]
# 정확도: 0.4980, 정밀도: 0.4956, 재현율: 0.9975, F1: 0.6622, ROC-AUC: 0.5047
# ################################################################################
# 0.0005924647002558103
# 오차 행렬
# [[  25 2002]
#  [   5 1968]]
# 정확도: 0.4983, 정밀도: 0.4957, 재현율: 0.9975, F1: 0.6623, ROC-AUC: 0.5049
# ################################################################################
# 0.0006302281841702686
# 오차 행렬
# [[  26 2001]
#  [   5 1968]]
# 정확도: 0.4985, 정밀도: 0.4958, 재현율: 0.9975, F1: 0.6624, ROC-AUC: 0.5051
# ################################################################################
# 0.000631595291567099
# 오차 행렬
# [[  27 2000]
#  [   5 1968]]
# 정확도: 0.4988, 정밀도: 0.4960, 재현율: 0.9975, F1: 0.6625, ROC-AUC: 0.5054
# ################################################################################
# 0.000658194276176988
# 오차 행렬
# [[  27 2000]
#  [   6 1967]]
# 정확도: 0.4985, 정밀도: 0.4958, 재현율: 0.9970, F1: 0.6623, ROC-AUC: 0.5051
# ################################################################################
# 0.0006942373225997665
# 오차 행렬
# [[  28 1999]
#  [   6 1967]]
# 정확도: 0.4988, 정밀도: 0.4960, 재현율: 0.9970, F1: 0.6624, ROC-AUC: 0.5054
# ################################################################################
# 0.0006987245112635823
# 오차 행렬
# [[  29 1998]
#  [   6 1967]]
# 정확도: 0.4990, 정밀도: 0.4961, 재현율: 0.9970, F1: 0.6625, ROC-AUC: 0.5056
# ################################################################################
# 0.000725791868994773
# 오차 행렬
# [[  30 1997]
#  [   6 1967]]
# 정확도: 0.4993, 정밀도: 0.4962, 재현율: 0.9970, F1: 0.6626, ROC-AUC: 0.5059
# ################################################################################
# 0.0007539244080432472
# 오차 행렬
# [[  31 1996]
#  [   6 1967]]
# 정확도: 0.4995, 정밀도: 0.4963, 재현율: 0.9970, F1: 0.6627, ROC-AUC: 0.5061
# ################################################################################
# 0.0008050448296192193
# 오차 행렬
# [[  32 1995]
#  [   6 1967]]
# 정확도: 0.4998, 정밀도: 0.4965, 재현율: 0.9970, F1: 0.6628, ROC-AUC: 0.5064
# ################################################################################
# 0.000819968733543838
# 오차 행렬
# [[  33 1994]
#  [   6 1967]]
# 정확도: 0.5000, 정밀도: 0.4966, 재현율: 0.9970, F1: 0.6630, ROC-AUC: 0.5066
# ################################################################################
# 0.0008283394659138508
# 오차 행렬
# [[  34 1993]
#  [   6 1967]]
# 정확도: 0.5002, 정밀도: 0.4967, 재현율: 0.9970, F1: 0.6631, ROC-AUC: 0.5069
# ################################################################################
# 0.0008765495130590386
# 오차 행렬
# [[  35 1992]
#  [   6 1967]]
# 정확도: 0.5005, 정밀도: 0.4968, 재현율: 0.9970, F1: 0.6632, ROC-AUC: 0.5071
# ################################################################################
# 0.0009146548336190817
# 오차 행렬
# [[  36 1991]
#  [   6 1967]]
# 정확도: 0.5008, 정밀도: 0.4970, 재현율: 0.9970, F1: 0.6633, ROC-AUC: 0.5074
# ################################################################################
# 0.0009184445817674113
# 오차 행렬
# [[  37 1990]
#  [   6 1967]]
# 정확도: 0.5010, 정밀도: 0.4971, 재현율: 0.9970, F1: 0.6634, ROC-AUC: 0.5076
# ################################################################################
# 0.0009215491151706131
# 오차 행렬
# [[  37 1990]
#  [   7 1966]]
# 정확도: 0.5008, 정밀도: 0.4970, 재현율: 0.9965, F1: 0.6632, ROC-AUC: 0.5074
# ################################################################################
# 0.0009528044197616062
# 오차 행렬
# [[  38 1989]
#  [   7 1966]]
# 정확도: 0.5010, 정밀도: 0.4971, 재현율: 0.9965, F1: 0.6633, ROC-AUC: 0.5076
# ################################################################################
# 0.0010080625813921405
# 오차 행렬
# [[  39 1988]
#  [   7 1966]]
# 정확도: 0.5012, 정밀도: 0.4972, 재현율: 0.9965, F1: 0.6634, ROC-AUC: 0.5078
# ################################################################################
# 0.0010160447076222323
# 오차 행렬
# [[  40 1987]
#  [   7 1966]]
# 정확도: 0.5015, 정밀도: 0.4973, 재현율: 0.9965, F1: 0.6635, ROC-AUC: 0.5081
# ################################################################################
# 0.0010226872121079083
# 오차 행렬
# [[  41 1986]
#  [   7 1966]]
# 정확도: 0.5018, 정밀도: 0.4975, 재현율: 0.9965, F1: 0.6636, ROC-AUC: 0.5083
# ################################################################################
# 0.0010527302489538014
# 오차 행렬
# [[  42 1985]
#  [   7 1966]]
# 정확도: 0.5020, 정밀도: 0.4976, 재현율: 0.9965, F1: 0.6637, ROC-AUC: 0.5086
# ################################################################################
# 0.0010531234047337795
# 오차 행렬
# [[  43 1984]
#  [   7 1966]]
# 정확도: 0.5022, 정밀도: 0.4977, 재현율: 0.9965, F1: 0.6639, ROC-AUC: 0.5088
# ################################################################################
# 0.0010544172299049455
# 오차 행렬
# [[  44 1983]
#  [   7 1966]]
# 정확도: 0.5025, 정밀도: 0.4978, 재현율: 0.9965, F1: 0.6640, ROC-AUC: 0.5091
# ################################################################################
# 0.0010552088092134336
# 오차 행렬
# [[  45 1982]
#  [   7 1966]]
# 정확도: 0.5028, 정밀도: 0.4980, 재현율: 0.9965, F1: 0.6641, ROC-AUC: 0.5093
# ################################################################################
# 0.0010662993982694777
# 오차 행렬
# [[  46 1981]
#  [   7 1966]]
# 정확도: 0.5030, 정밀도: 0.4981, 재현율: 0.9965, F1: 0.6642, ROC-AUC: 0.5096
# ################################################################################
# 0.001077284305719918
# 오차 행렬
# [[  47 1980]
#  [   7 1966]]
# 정확도: 0.5032, 정밀도: 0.4982, 재현율: 0.9965, F1: 0.6643, ROC-AUC: 0.5098
# ################################################################################
# 0.0010982288162532754
# 오차 행렬
# [[  47 1980]
#  [   8 1965]]
# 정확도: 0.5030, 정밀도: 0.4981, 재현율: 0.9959, F1: 0.6641, ROC-AUC: 0.5096
# ################################################################################
# 0.0011138051591531029
# 오차 행렬
# [[  48 1979]
#  [   8 1965]]
# 정확도: 0.5032, 정밀도: 0.4982, 재현율: 0.9959, F1: 0.6642, ROC-AUC: 0.5098
# ################################################################################
# 0.001165804396054162
# 오차 행렬
# [[  49 1978]
#  [   8 1965]]
# 정확도: 0.5035, 정밀도: 0.4984, 재현율: 0.9959, F1: 0.6643, ROC-AUC: 0.5101
# ################################################################################
# 0.0012404812329950938
# 오차 행렬
# [[  50 1977]
#  [   8 1965]]
# 정확도: 0.5038, 정밀도: 0.4985, 재현율: 0.9959, F1: 0.6644, ROC-AUC: 0.5103
# ################################################################################
# 0.0012717943560169483
# 오차 행렬
# [[  51 1976]
#  [   8 1965]]
# 정확도: 0.5040, 정밀도: 0.4986, 재현율: 0.9959, F1: 0.6645, ROC-AUC: 0.5106
# ################################################################################
# 0.001274564459042187
# 오차 행렬
# [[  52 1975]
#  [   8 1965]]
# 정확도: 0.5042, 정밀도: 0.4987, 재현율: 0.9959, F1: 0.6646, ROC-AUC: 0.5108
# ################################################################################
# 0.00128888382881643
# 오차 행렬
# [[  53 1974]
#  [   8 1965]]
# 정확도: 0.5045, 정밀도: 0.4989, 재현율: 0.9959, F1: 0.6647, ROC-AUC: 0.5110
# ################################################################################
# 0.0013279104701737017
# 오차 행렬
# [[  54 1973]
#  [   8 1965]]
# 정확도: 0.5048, 정밀도: 0.4990, 재현율: 0.9959, F1: 0.6649, ROC-AUC: 0.5113
# ################################################################################
# 0.001342020267441305
# 오차 행렬
# [[  55 1972]
#  [   8 1965]]
# 정확도: 0.5050, 정밀도: 0.4991, 재현율: 0.9959, F1: 0.6650, ROC-AUC: 0.5115
# ################################################################################
# 0.0013556134020429153
# 오차 행렬
# [[  56 1971]
#  [   8 1965]]
# 정확도: 0.5052, 정밀도: 0.4992, 재현율: 0.9959, F1: 0.6651, ROC-AUC: 0.5118
# ################################################################################
# 0.001467713535681176
# 오차 행렬
# [[  57 1970]
#  [   8 1965]]
# 정확도: 0.5055, 정밀도: 0.4994, 재현율: 0.9959, F1: 0.6652, ROC-AUC: 0.5120
# ################################################################################
# 0.0014706392412074136
# 오차 행렬
# [[  58 1969]
#  [   8 1965]]
# 정확도: 0.5058, 정밀도: 0.4995, 재현율: 0.9959, F1: 0.6653, ROC-AUC: 0.5123
# ################################################################################
# 0.0014975772836527293
# 오차 행렬
# [[  59 1968]
#  [   8 1965]]
# 정확도: 0.5060, 정밀도: 0.4996, 재현율: 0.9959, F1: 0.6654, ROC-AUC: 0.5125
# ################################################################################
# 0.001525082581258201
# 오차 행렬
# [[  60 1967]
#  [   8 1965]]
# 정확도: 0.5062, 정밀도: 0.4997, 재현율: 0.9959, F1: 0.6655, ROC-AUC: 0.5128
# ################################################################################
# 0.0015271896760038813
# 오차 행렬
# [[  60 1967]
#  [   9 1964]]
# 정확도: 0.5060, 정밀도: 0.4996, 재현율: 0.9954, F1: 0.6653, ROC-AUC: 0.5125
# ################################################################################
# 0.0015421370923193371
# 오차 행렬
# [[  61 1966]
#  [   9 1964]]
# 정확도: 0.5062, 정밀도: 0.4997, 재현율: 0.9954, F1: 0.6654, ROC-AUC: 0.5128
# ################################################################################
# 0.0015473562705517658
# 오차 행렬
# [[  62 1965]
#  [   9 1964]]
# 정확도: 0.5065, 정밀도: 0.4999, 재현율: 0.9954, F1: 0.6655, ROC-AUC: 0.5130
# ################################################################################
# 0.0015572160463192695
# 오차 행렬
# [[  63 1964]
#  [   9 1964]]
# 정확도: 0.5068, 정밀도: 0.5000, 재현율: 0.9954, F1: 0.6656, ROC-AUC: 0.5133
# ################################################################################
# 0.0015605778138110852
# 오차 행렬
# [[  64 1963]
#  [   9 1964]]
# 정확도: 0.5070, 정밀도: 0.5001, 재현율: 0.9954, F1: 0.6658, ROC-AUC: 0.5135
# ################################################################################
# 0.0015776650709834585
# 오차 행렬
# [[  65 1962]
#  [   9 1964]]
# 정확도: 0.5072, 정밀도: 0.5003, 재현율: 0.9954, F1: 0.6659, ROC-AUC: 0.5138
# ################################################################################
# 0.001592362999760758
# 오차 행렬
# [[  66 1961]
#  [   9 1964]]
# 정확도: 0.5075, 정밀도: 0.5004, 재현율: 0.9954, F1: 0.6660, ROC-AUC: 0.5140
# ################################################################################
# 0.0016221429164244097
# 오차 행렬
# [[  67 1960]
#  [   9 1964]]
# 정확도: 0.5078, 정밀도: 0.5005, 재현율: 0.9954, F1: 0.6661, ROC-AUC: 0.5142
# ################################################################################
# 0.0016655009354437738
# 오차 행렬
# [[  68 1959]
#  [   9 1964]]
# 정확도: 0.5080, 정밀도: 0.5006, 재현율: 0.9954, F1: 0.6662, ROC-AUC: 0.5145
# ################################################################################
# 0.0016717447564932092
# 오차 행렬
# [[  69 1958]
#  [   9 1964]]
# 정확도: 0.5082, 정밀도: 0.5008, 재현율: 0.9954, F1: 0.6663, ROC-AUC: 0.5147
# ################################################################################
# 0.0016939030762178988
# 오차 행렬
# [[  70 1957]
#  [   9 1964]]
# 정확도: 0.5085, 정밀도: 0.5009, 재현율: 0.9954, F1: 0.6664, ROC-AUC: 0.5150
# ################################################################################
# 0.001712417108188752
# 오차 행렬
# [[  71 1956]
#  [   9 1964]]
# 정확도: 0.5088, 정밀도: 0.5010, 재현율: 0.9954, F1: 0.6666, ROC-AUC: 0.5152
# ################################################################################
# 0.0017307598111764556
# 오차 행렬
# [[  72 1955]
#  [   9 1964]]
# 정확도: 0.5090, 정밀도: 0.5011, 재현율: 0.9954, F1: 0.6667, ROC-AUC: 0.5155
# ################################################################################
# 0.0017538842553482964
# 오차 행렬
# [[  73 1954]
#  [   9 1964]]
# 정확도: 0.5092, 정밀도: 0.5013, 재현율: 0.9954, F1: 0.6668, ROC-AUC: 0.5157
# ################################################################################
# 0.001832828971357329
# 오차 행렬
# [[  74 1953]
#  [   9 1964]]
# 정확도: 0.5095, 정밀도: 0.5014, 재현율: 0.9954, F1: 0.6669, ROC-AUC: 0.5160
# ################################################################################
# 0.0018438231054923237
# 오차 행렬
# [[  75 1952]
#  [   9 1964]]
# 정확도: 0.5098, 정밀도: 0.5015, 재현율: 0.9954, F1: 0.6670, ROC-AUC: 0.5162
# ################################################################################
# 0.001849460023584045
# 오차 행렬
# [[  76 1951]
#  [   9 1964]]
# 정확도: 0.5100, 정밀도: 0.5017, 재현율: 0.9954, F1: 0.6671, ROC-AUC: 0.5165
# ################################################################################
# 0.0019179427425670252
# 오차 행렬
# [[  77 1950]
#  [   9 1964]]
# 정확도: 0.5102, 정밀도: 0.5018, 재현율: 0.9954, F1: 0.6672, ROC-AUC: 0.5167
# ################################################################################
# 0.0019497294361035227
# 오차 행렬
# [[  78 1949]
#  [   9 1964]]
# 정확도: 0.5105, 정밀도: 0.5019, 재현율: 0.9954, F1: 0.6673, ROC-AUC: 0.5170
# ################################################################################
# 0.0019497443986070768
# 오차 행렬
# [[  79 1948]
#  [   9 1964]]
# 정확도: 0.5108, 정밀도: 0.5020, 재현율: 0.9954, F1: 0.6675, ROC-AUC: 0.5172
# ################################################################################
# 0.0019601126393356512
# 오차 행렬
# [[  80 1947]
#  [   9 1964]]
# 정확도: 0.5110, 정밀도: 0.5022, 재현율: 0.9954, F1: 0.6676, ROC-AUC: 0.5175
# ################################################################################
# 0.001998335560098245
# 오차 행렬
# [[  81 1946]
#  [   9 1964]]
# 정확도: 0.5112, 정밀도: 0.5023, 재현율: 0.9954, F1: 0.6677, ROC-AUC: 0.5177
# ################################################################################
# 0.002042095618268345
# 오차 행렬
# [[  82 1945]
#  [   9 1964]]
# 정확도: 0.5115, 정밀도: 0.5024, 재현율: 0.9954, F1: 0.6678, ROC-AUC: 0.5179
# ################################################################################
# 0.0020577009434430546
# 오차 행렬
# [[  83 1944]
#  [   9 1964]]
# 정확도: 0.5118, 정밀도: 0.5026, 재현율: 0.9954, F1: 0.6679, ROC-AUC: 0.5182
# ################################################################################
# 0.0020662811998662482
# 오차 행렬
# [[  84 1943]
#  [   9 1964]]
# 정확도: 0.5120, 정밀도: 0.5027, 재현율: 0.9954, F1: 0.6680, ROC-AUC: 0.5184
# ################################################################################
# 0.0021044971382085955
# 오차 행렬
# [[  85 1942]
#  [   9 1964]]
# 정확도: 0.5122, 정밀도: 0.5028, 재현율: 0.9954, F1: 0.6681, ROC-AUC: 0.5187
# ################################################################################
# 0.0021335077179338896
# 오차 행렬
# [[  85 1942]
#  [  10 1963]]
# 정확도: 0.5120, 정밀도: 0.5027, 재현율: 0.9949, F1: 0.6679, ROC-AUC: 0.5184
# ################################################################################
# 0.0021686967615434307
# 오차 행렬
# [[  86 1941]
#  [  10 1963]]
# 정확도: 0.5122, 정밀도: 0.5028, 재현율: 0.9949, F1: 0.6680, ROC-AUC: 0.5187
# ################################################################################
# 0.0021812368671732334
# 오차 행렬
# [[  87 1940]
#  [  10 1963]]
# 정확도: 0.5125, 정밀도: 0.5029, 재현율: 0.9949, F1: 0.6681, ROC-AUC: 0.5189
# ################################################################################
# 0.0021830555903973987
# 오차 행렬
# [[  88 1939]
#  [  10 1963]]
# 정확도: 0.5128, 정밀도: 0.5031, 재현율: 0.9949, F1: 0.6683, ROC-AUC: 0.5192
# ################################################################################
# 0.002313656154314365
# 오차 행렬
# [[  89 1938]
#  [  10 1963]]
# 정확도: 0.5130, 정밀도: 0.5032, 재현율: 0.9949, F1: 0.6684, ROC-AUC: 0.5194
# ################################################################################
# 0.002319998268352891
# 오차 행렬
# [[  90 1937]
#  [  10 1963]]
# 정확도: 0.5132, 정밀도: 0.5033, 재현율: 0.9949, F1: 0.6685, ROC-AUC: 0.5197
# ################################################################################
# 0.0023302104108697454
# 오차 행렬
# [[  91 1936]
#  [  10 1963]]
# 정확도: 0.5135, 정밀도: 0.5035, 재현율: 0.9949, F1: 0.6686, ROC-AUC: 0.5199
# ################################################################################
# 0.0023319064279558807
# 오차 행렬
# [[  92 1935]
#  [  10 1963]]
# 정확도: 0.5138, 정밀도: 0.5036, 재현율: 0.9949, F1: 0.6687, ROC-AUC: 0.5202
# ################################################################################
# 0.0023463099800529377
# 오차 행렬
# [[  93 1934]
#  [  10 1963]]
# 정확도: 0.5140, 정밀도: 0.5037, 재현율: 0.9949, F1: 0.6688, ROC-AUC: 0.5204
# ################################################################################
# 0.0023702298716760687
# 오차 행렬
# [[  94 1933]
#  [  10 1963]]
# 정확도: 0.5142, 정밀도: 0.5039, 재현율: 0.9949, F1: 0.6689, ROC-AUC: 0.5207
# ################################################################################
# 0.002373258531132758
# 오차 행렬
# [[  95 1932]
#  [  10 1963]]
# 정확도: 0.5145, 정밀도: 0.5040, 재현율: 0.9949, F1: 0.6691, ROC-AUC: 0.5209
# ################################################################################
# 0.0024276611337592994
# 오차 행렬
# [[  95 1932]
#  [  11 1962]]
# 정확도: 0.5142, 정밀도: 0.5039, 재현율: 0.9944, F1: 0.6688, ROC-AUC: 0.5206
# ################################################################################
# 0.002442944643926279
# 오차 행렬
# [[  96 1931]
#  [  11 1962]]
# 정확도: 0.5145, 정밀도: 0.5040, 재현율: 0.9944, F1: 0.6689, ROC-AUC: 0.5209
# ################################################################################
# 0.0024523890406212053
# 오차 행렬
# [[  97 1930]
#  [  11 1962]]
# 정확도: 0.5148, 정밀도: 0.5041, 재현율: 0.9944, F1: 0.6691, ROC-AUC: 0.5211
# ################################################################################
# 0.0025016856452530468
# 오차 행렬
# [[  98 1929]
#  [  11 1962]]
# 정확도: 0.5150, 정밀도: 0.5042, 재현율: 0.9944, F1: 0.6692, ROC-AUC: 0.5214
# ################################################################################
# 0.002532642216523148
# 오차 행렬
# [[  99 1928]
#  [  11 1962]]
# 정확도: 0.5152, 정밀도: 0.5044, 재현율: 0.9944, F1: 0.6693, ROC-AUC: 0.5216
# ################################################################################
# 0.002564016639995808
# 오차 행렬
# [[ 100 1927]
#  [  11 1962]]
# 정확도: 0.5155, 정밀도: 0.5045, 재현율: 0.9944, F1: 0.6694, ROC-AUC: 0.5219
# ################################################################################
# 0.0025698153660487113
# 오차 행렬
# [[ 101 1926]
#  [  11 1962]]
# 정확도: 0.5158, 정밀도: 0.5046, 재현율: 0.9944, F1: 0.6695, ROC-AUC: 0.5221
# ################################################################################
# 0.0026536593027972327
# 오차 행렬
# [[ 102 1925]
#  [  11 1962]]
# 정확도: 0.5160, 정밀도: 0.5048, 재현율: 0.9944, F1: 0.6696, ROC-AUC: 0.5224
# ################################################################################
# 0.0026581453728752574
# 오차 행렬
# [[ 103 1924]
#  [  11 1962]]
# 정확도: 0.5162, 정밀도: 0.5049, 재현율: 0.9944, F1: 0.6697, ROC-AUC: 0.5226
# ################################################################################
# 0.002721370769214513
# 오차 행렬
# [[ 104 1923]
#  [  11 1962]]
# 정확도: 0.5165, 정밀도: 0.5050, 재현율: 0.9944, F1: 0.6699, ROC-AUC: 0.5229
# ################################################################################
# 0.002781981882846371
# 오차 행렬
# [[ 105 1922]
#  [  11 1962]]
# 정확도: 0.5168, 정밀도: 0.5051, 재현율: 0.9944, F1: 0.6700, ROC-AUC: 0.5231
# ################################################################################
# 0.0028217075960668184
# 오차 행렬
# [[ 106 1921]
#  [  11 1962]]
# 정확도: 0.5170, 정밀도: 0.5053, 재현율: 0.9944, F1: 0.6701, ROC-AUC: 0.5234
# ################################################################################
# 0.0028346440987837523
# 오차 행렬
# [[ 107 1920]
#  [  11 1962]]
# 정확도: 0.5172, 정밀도: 0.5054, 재현율: 0.9944, F1: 0.6702, ROC-AUC: 0.5236
# ################################################################################
# 0.002857117283824822
# 오차 행렬
# [[ 108 1919]
#  [  11 1962]]
# 정확도: 0.5175, 정밀도: 0.5055, 재현율: 0.9944, F1: 0.6703, ROC-AUC: 0.5239
# ################################################################################
# 0.002891167864624361
# 오차 행렬
# [[ 109 1918]
#  [  11 1962]]
# 정확도: 0.5178, 정밀도: 0.5057, 재현율: 0.9944, F1: 0.6704, ROC-AUC: 0.5241
# ################################################################################
# 0.0029385281621102433
# 오차 행렬
# [[ 110 1917]
#  [  11 1962]]
# 정확도: 0.5180, 정밀도: 0.5058, 재현율: 0.9944, F1: 0.6705, ROC-AUC: 0.5243
# ################################################################################
# 0.002938712595407042
# 오차 행렬
# [[ 111 1916]
#  [  11 1962]]
# 정확도: 0.5182, 정밀도: 0.5059, 재현율: 0.9944, F1: 0.6707, ROC-AUC: 0.5246
# ################################################################################
# 0.002957739192305094
# 오차 행렬
# [[ 112 1915]
#  [  11 1962]]
# 정확도: 0.5185, 정밀도: 0.5061, 재현율: 0.9944, F1: 0.6708, ROC-AUC: 0.5248
# ################################################################################
# 0.002965851686491948
# 오차 행렬
# [[ 113 1914]
#  [  11 1962]]
# 정확도: 0.5188, 정밀도: 0.5062, 재현율: 0.9944, F1: 0.6709, ROC-AUC: 0.5251
# ################################################################################
# 0.0029874633387368564
# 오차 행렬
# [[ 113 1914]
#  [  12 1961]]
# 정확도: 0.5185, 정밀도: 0.5061, 재현율: 0.9939, F1: 0.6707, ROC-AUC: 0.5248
# ################################################################################
# 0.003027252349993523
# 오차 행렬
# [[ 114 1913]
#  [  12 1961]]
# 정확도: 0.5188, 정밀도: 0.5062, 재현율: 0.9939, F1: 0.6708, ROC-AUC: 0.5251
# ################################################################################
# 0.003044993933402159
# 오차 행렬
# [[ 115 1912]
#  [  12 1961]]
# 정확도: 0.5190, 정밀도: 0.5063, 재현율: 0.9939, F1: 0.6709, ROC-AUC: 0.5253
# ################################################################################
# 0.0030785676633801585
# 오차 행렬
# [[ 116 1911]
#  [  12 1961]]
# 정확도: 0.5192, 정밀도: 0.5065, 재현율: 0.9939, F1: 0.6710, ROC-AUC: 0.5256
# ################################################################################
# 0.003089412185472404
# 오차 행렬
# [[ 117 1910]
#  [  12 1961]]
# 정확도: 0.5195, 정밀도: 0.5066, 재현율: 0.9939, F1: 0.6711, ROC-AUC: 0.5258
# ################################################################################
# 0.003210330773973838
# 오차 행렬
# [[ 117 1910]
#  [  13 1960]]
# 정확도: 0.5192, 정밀도: 0.5065, 재현율: 0.9934, F1: 0.6709, ROC-AUC: 0.5256
# ################################################################################
# 0.0032975886612032117
# 오차 행렬
# [[ 118 1909]
#  [  13 1960]]
# 정확도: 0.5195, 정밀도: 0.5066, 재현율: 0.9934, F1: 0.6710, ROC-AUC: 0.5258
# ################################################################################
# 0.003299690889476747
# 오차 행렬
# [[ 118 1909]
#  [  14 1959]]
# 정확도: 0.5192, 정밀도: 0.5065, 재현율: 0.9929, F1: 0.6708, ROC-AUC: 0.5256
# ################################################################################
# 0.003310598960953762
# 오차 행렬
# [[ 118 1909]
#  [  15 1958]]
# 정확도: 0.5190, 정밀도: 0.5063, 재현율: 0.9924, F1: 0.6705, ROC-AUC: 0.5253
# ################################################################################
# 0.0033918210865006436
# 오차 행렬
# [[ 119 1908]
#  [  15 1958]]
# 정확도: 0.5192, 정밀도: 0.5065, 재현율: 0.9924, F1: 0.6707, ROC-AUC: 0.5256
# ################################################################################
# 0.0033992153354302458
# 오차 행렬
# [[ 120 1907]
#  [  15 1958]]
# 정확도: 0.5195, 정밀도: 0.5066, 재현율: 0.9924, F1: 0.6708, ROC-AUC: 0.5258
# ################################################################################
# 0.003433230906553731
# 오차 행렬
# [[ 121 1906]
#  [  15 1958]]
# 정확도: 0.5198, 정밀도: 0.5067, 재현율: 0.9924, F1: 0.6709, ROC-AUC: 0.5260
# ################################################################################
# 0.003460013936667933
# 오차 행렬
# [[ 122 1905]
#  [  15 1958]]
# 정확도: 0.5200, 정밀도: 0.5069, 재현율: 0.9924, F1: 0.6710, ROC-AUC: 0.5263
# ################################################################################
# 0.0035145879760764363
# 오차 행렬
# [[ 123 1904]
#  [  15 1958]]
# 정확도: 0.5202, 정밀도: 0.5070, 재현율: 0.9924, F1: 0.6711, ROC-AUC: 0.5265
# ################################################################################
# 0.003538734410051683
# 오차 행렬
# [[ 124 1903]
#  [  15 1958]]
# 정확도: 0.5205, 정밀도: 0.5071, 재현율: 0.9924, F1: 0.6712, ROC-AUC: 0.5268
# ################################################################################
# 0.0035543547055218254
# 오차 행렬
# [[ 125 1902]
#  [  15 1958]]
# 정확도: 0.5208, 정밀도: 0.5073, 재현율: 0.9924, F1: 0.6714, ROC-AUC: 0.5270
# ################################################################################
# 0.003653576810569397
# 오차 행렬
# [[ 126 1901]
#  [  15 1958]]
# 정확도: 0.5210, 정밀도: 0.5074, 재현율: 0.9924, F1: 0.6715, ROC-AUC: 0.5273
# ################################################################################
# 0.0037736986951847525
# 오차 행렬
# [[ 127 1900]
#  [  15 1958]]
# 정확도: 0.5212, 정밀도: 0.5075, 재현율: 0.9924, F1: 0.6716, ROC-AUC: 0.5275
# ################################################################################
# 0.003816710760493823
# 오차 행렬
# [[ 128 1899]
#  [  15 1958]]
# 정확도: 0.5215, 정밀도: 0.5076, 재현율: 0.9924, F1: 0.6717, ROC-AUC: 0.5278
# ################################################################################
# 0.003918008004388183
# 오차 행렬
# [[ 129 1898]
#  [  15 1958]]
# 정확도: 0.5218, 정밀도: 0.5078, 재현율: 0.9924, F1: 0.6718, ROC-AUC: 0.5280
# ################################################################################
# 0.003937199609528226
# 오차 행렬
# [[ 130 1897]
#  [  15 1958]]
# 정확도: 0.5220, 정밀도: 0.5079, 재현율: 0.9924, F1: 0.6719, ROC-AUC: 0.5283
# ################################################################################
# 0.003948387551435917
# 오차 행렬
# [[ 131 1896]
#  [  15 1958]]
# 정확도: 0.5222, 정밀도: 0.5080, 재현율: 0.9924, F1: 0.6720, ROC-AUC: 0.5285
# ################################################################################
# 0.004033943603811838
# 오차 행렬
# [[ 132 1895]
#  [  15 1958]]
# 정확도: 0.5225, 정밀도: 0.5082, 재현율: 0.9924, F1: 0.6722, ROC-AUC: 0.5288
# ################################################################################
# 0.004054311034354775
# 오차 행렬
# [[ 133 1894]
#  [  15 1958]]
# 정확도: 0.5228, 정밀도: 0.5083, 재현율: 0.9924, F1: 0.6723, ROC-AUC: 0.5290
# ################################################################################
# 0.004061134536818845
# 오차 행렬
# [[ 134 1893]
#  [  15 1958]]
# 정확도: 0.5230, 정밀도: 0.5084, 재현율: 0.9924, F1: 0.6724, ROC-AUC: 0.5293
# ################################################################################
# 0.004108892065446216
# 오차 행렬
# [[ 134 1893]
#  [  16 1957]]
# 정확도: 0.5228, 정밀도: 0.5083, 재현율: 0.9919, F1: 0.6722, ROC-AUC: 0.5290
# ################################################################################
# 0.0042490672464425205
# 오차 행렬
# [[ 135 1892]
#  [  16 1957]]
# 정확도: 0.5230, 정밀도: 0.5084, 재현율: 0.9919, F1: 0.6723, ROC-AUC: 0.5292
# ################################################################################
# 0.004266475701806225
# 오차 행렬
# [[ 136 1891]
#  [  16 1957]]
# 정확도: 0.5232, 정밀도: 0.5086, 재현율: 0.9919, F1: 0.6724, ROC-AUC: 0.5295
# ################################################################################
# 0.0043542608052713865
# 오차 행렬
# [[ 137 1890]
#  [  16 1957]]
# 정확도: 0.5235, 정밀도: 0.5087, 재현율: 0.9919, F1: 0.6725, ROC-AUC: 0.5297
# ################################################################################
# 0.004390277197852913
# 오차 행렬
# [[ 138 1889]
#  [  16 1957]]
# 정확도: 0.5238, 정밀도: 0.5088, 재현율: 0.9919, F1: 0.6726, ROC-AUC: 0.5300
# ################################################################################
# 0.0044803211770718596
# 오차 행렬
# [[ 139 1888]
#  [  16 1957]]
# 정확도: 0.5240, 정밀도: 0.5090, 재현율: 0.9919, F1: 0.6727, ROC-AUC: 0.5302
# ################################################################################
# 0.004486317851312576
# 오차 행렬
# [[ 140 1887]
#  [  16 1957]]
# 정확도: 0.5242, 정밀도: 0.5091, 재현율: 0.9919, F1: 0.6729, ROC-AUC: 0.5305
# ################################################################################
# 0.004498261120041105
# 오차 행렬
# [[ 141 1886]
#  [  16 1957]]
# 정확도: 0.5245, 정밀도: 0.5092, 재현율: 0.9919, F1: 0.6730, ROC-AUC: 0.5307
# ################################################################################
# 0.004527227689261418
# 오차 행렬
# [[ 142 1885]
#  [  16 1957]]
# 정확도: 0.5248, 정밀도: 0.5094, 재현율: 0.9919, F1: 0.6731, ROC-AUC: 0.5310
# ################################################################################
# 0.004556983736163404
# 오차 행렬
# [[ 143 1884]
#  [  16 1957]]
# 정확도: 0.5250, 정밀도: 0.5095, 재현율: 0.9919, F1: 0.6732, ROC-AUC: 0.5312
# ################################################################################
# 0.0045818557337157185
# 오차 행렬
# [[ 144 1883]
#  [  16 1957]]
# 정확도: 0.5252, 정밀도: 0.5096, 재현율: 0.9919, F1: 0.6733, ROC-AUC: 0.5315
# ################################################################################
# 0.0045884080270564625
# 오차 행렬
# [[ 145 1882]
#  [  16 1957]]
# 정확도: 0.5255, 정밀도: 0.5098, 재현율: 0.9919, F1: 0.6734, ROC-AUC: 0.5317
# ################################################################################
# 0.004614324544875682
# 오차 행렬
# [[ 146 1881]
#  [  16 1957]]
# 정확도: 0.5258, 정밀도: 0.5099, 재현율: 0.9919, F1: 0.6736, ROC-AUC: 0.5320
# ################################################################################
# 0.004632175075897775
# 오차 행렬
# [[ 147 1880]
#  [  16 1957]]
# 정확도: 0.5260, 정밀도: 0.5100, 재현율: 0.9919, F1: 0.6737, ROC-AUC: 0.5322
# ################################################################################
# 0.004683342350311878
# 오차 행렬
# [[ 148 1879]
#  [  16 1957]]
# 정확도: 0.5262, 정밀도: 0.5102, 재현율: 0.9919, F1: 0.6738, ROC-AUC: 0.5325
# ################################################################################
# 0.004701588932105373
# 오차 행렬
# [[ 149 1878]
#  [  16 1957]]
# 정확도: 0.5265, 정밀도: 0.5103, 재현율: 0.9919, F1: 0.6739, ROC-AUC: 0.5327
# ################################################################################
# 0.004710491326709291
# 오차 행렬
# [[ 150 1877]
#  [  16 1957]]
# 정확도: 0.5268, 정밀도: 0.5104, 재현율: 0.9919, F1: 0.6740, ROC-AUC: 0.5329
# ################################################################################
# 0.004725032520249105
# 오차 행렬
# [[ 151 1876]
#  [  16 1957]]
# 정확도: 0.5270, 정밀도: 0.5106, 재현율: 0.9919, F1: 0.6741, ROC-AUC: 0.5332
# ################################################################################
# 0.004737629057869671
# 오차 행렬
# [[ 152 1875]
#  [  16 1957]]
# 정확도: 0.5272, 정밀도: 0.5107, 재현율: 0.9919, F1: 0.6742, ROC-AUC: 0.5334
# ################################################################################
# 0.004757237150865658
# 오차 행렬
# [[ 153 1874]
#  [  16 1957]]
# 정확도: 0.5275, 정밀도: 0.5108, 재현율: 0.9919, F1: 0.6744, ROC-AUC: 0.5337
# ################################################################################
# 0.004802565798012042
# 오차 행렬
# [[ 154 1873]
#  [  16 1957]]
# 정확도: 0.5278, 정밀도: 0.5110, 재현율: 0.9919, F1: 0.6745, ROC-AUC: 0.5339
# ################################################################################
# 0.004842085813112083
# 오차 행렬
# [[ 155 1872]
#  [  16 1957]]
# 정확도: 0.5280, 정밀도: 0.5111, 재현율: 0.9919, F1: 0.6746, ROC-AUC: 0.5342
# ################################################################################
# 0.004845385022241069
# 오차 행렬
# [[ 155 1872]
#  [  17 1956]]
# 정확도: 0.5278, 정밀도: 0.5110, 재현율: 0.9914, F1: 0.6744, ROC-AUC: 0.5339
# ################################################################################
# 0.004866714369850178
# 오차 행렬
# [[ 156 1871]
#  [  17 1956]]
# 정확도: 0.5280, 정밀도: 0.5111, 재현율: 0.9914, F1: 0.6745, ROC-AUC: 0.5342
# ################################################################################
# 0.0048896743717798015
# 오차 행렬
# [[ 157 1870]
#  [  17 1956]]
# 정확도: 0.5282, 정밀도: 0.5112, 재현율: 0.9914, F1: 0.6746, ROC-AUC: 0.5344
# ################################################################################
# 0.004904643663177795
# 오차 행렬
# [[ 158 1869]
#  [  17 1956]]
# 정확도: 0.5285, 정밀도: 0.5114, 재현율: 0.9914, F1: 0.6747, ROC-AUC: 0.5347
# ################################################################################
# 0.004948516495358798
# 오차 행렬
# [[ 159 1868]
#  [  17 1956]]
# 정확도: 0.5288, 정밀도: 0.5115, 재현율: 0.9914, F1: 0.6748, ROC-AUC: 0.5349
# ################################################################################
# 0.00500485642650944
# 오차 행렬
# [[ 160 1867]
#  [  17 1956]]
# 정확도: 0.5290, 정밀도: 0.5116, 재현율: 0.9914, F1: 0.6749, ROC-AUC: 0.5352
# ################################################################################
# 0.005021901260163363
# 오차 행렬
# [[ 161 1866]
#  [  17 1956]]
# 정확도: 0.5292, 정밀도: 0.5118, 재현율: 0.9914, F1: 0.6751, ROC-AUC: 0.5354
# ################################################################################
# 0.005034388140072401
# 오차 행렬
# [[ 162 1865]
#  [  17 1956]]
# 정확도: 0.5295, 정밀도: 0.5119, 재현율: 0.9914, F1: 0.6752, ROC-AUC: 0.5357
# ################################################################################
# 0.005043425109700316
# 오차 행렬
# [[ 163 1864]
#  [  17 1956]]
# 정확도: 0.5298, 정밀도: 0.5120, 재현율: 0.9914, F1: 0.6753, ROC-AUC: 0.5359
# ################################################################################
# 0.005053366196852739
# 오차 행렬
# [[ 164 1863]
#  [  17 1956]]
# 정확도: 0.5300, 정밀도: 0.5122, 재현율: 0.9914, F1: 0.6754, ROC-AUC: 0.5361
# ################################################################################
# 0.0050660480359801955
# 오차 행렬
# [[ 165 1862]
#  [  17 1956]]
# 정확도: 0.5302, 정밀도: 0.5123, 재현율: 0.9914, F1: 0.6755, ROC-AUC: 0.5364
# ################################################################################
# 0.0050873521896381635
# 오차 행렬
# [[ 166 1861]
#  [  17 1956]]
# 정확도: 0.5305, 정밀도: 0.5124, 재현율: 0.9914, F1: 0.6756, ROC-AUC: 0.5366
# ################################################################################
# 0.005126859028855616
# 오차 행렬
# [[ 167 1860]
#  [  17 1956]]
# 정확도: 0.5308, 정밀도: 0.5126, 재현율: 0.9914, F1: 0.6758, ROC-AUC: 0.5369
# ################################################################################
# 0.005150086491759193
# 오차 행렬
# [[ 168 1859]
#  [  17 1956]]
# 정확도: 0.5310, 정밀도: 0.5127, 재현율: 0.9914, F1: 0.6759, ROC-AUC: 0.5371
# ################################################################################
# 0.005150142693297463
# 오차 행렬
# [[ 169 1858]
#  [  17 1956]]
# 정확도: 0.5312, 정밀도: 0.5128, 재현율: 0.9914, F1: 0.6760, ROC-AUC: 0.5374
# ################################################################################
# 0.0052633067208166205
# 오차 행렬
# [[ 170 1857]
#  [  17 1956]]
# 정확도: 0.5315, 정밀도: 0.5130, 재현율: 0.9914, F1: 0.6761, ROC-AUC: 0.5376
# ################################################################################
# 0.005281643238839896
# 오차 행렬
# [[ 171 1856]
#  [  17 1956]]
# 정확도: 0.5317, 정밀도: 0.5131, 재현율: 0.9914, F1: 0.6762, ROC-AUC: 0.5379
# ################################################################################
# 0.0053604547102086885
# 오차 행렬
# [[ 172 1855]
#  [  17 1956]]
# 정확도: 0.5320, 정밀도: 0.5133, 재현율: 0.9914, F1: 0.6763, ROC-AUC: 0.5381
# ################################################################################
# 0.005387883651515392
# 오차 행렬
# [[ 173 1854]
#  [  17 1956]]
# 정확도: 0.5323, 정밀도: 0.5134, 재현율: 0.9914, F1: 0.6765, ROC-AUC: 0.5384
# ################################################################################
# 0.0054277848497541765
# 오차 행렬
# [[ 174 1853]
#  [  17 1956]]
# 정확도: 0.5325, 정밀도: 0.5135, 재현율: 0.9914, F1: 0.6766, ROC-AUC: 0.5386
# ################################################################################
# 0.005477678127228279
# 오차 행렬
# [[ 175 1852]
#  [  17 1956]]
# 정확도: 0.5327, 정밀도: 0.5137, 재현율: 0.9914, F1: 0.6767, ROC-AUC: 0.5389
# ################################################################################
# 0.00550674478068449
# 오차 행렬
# [[ 176 1851]
#  [  17 1956]]
# 정확도: 0.5330, 정밀도: 0.5138, 재현율: 0.9914, F1: 0.6768, ROC-AUC: 0.5391
# ################################################################################
# 0.005509737678767326
# 오차 행렬
# [[ 177 1850]
#  [  17 1956]]
# 정확도: 0.5333, 정밀도: 0.5139, 재현율: 0.9914, F1: 0.6769, ROC-AUC: 0.5394
# ################################################################################
# 0.0055268672463326006
# 오차 행렬
# [[ 178 1849]
#  [  17 1956]]
# 정확도: 0.5335, 정밀도: 0.5141, 재현율: 0.9914, F1: 0.6771, ROC-AUC: 0.5396
# ################################################################################
# 0.005546113188961976
# 오차 행렬
# [[ 179 1848]
#  [  17 1956]]
# 정확도: 0.5337, 정밀도: 0.5142, 재현율: 0.9914, F1: 0.6772, ROC-AUC: 0.5398
# ################################################################################
# 0.005547752536692775
# 오차 행렬
# [[ 180 1847]
#  [  17 1956]]
# 정확도: 0.5340, 정밀도: 0.5143, 재현율: 0.9914, F1: 0.6773, ROC-AUC: 0.5401
# ################################################################################
# 0.005575624330326052
# 오차 행렬
# [[ 181 1846]
#  [  17 1956]]
# 정확도: 0.5343, 정밀도: 0.5145, 재현율: 0.9914, F1: 0.6774, ROC-AUC: 0.5403
# ################################################################################
# 0.005677027991162356
# 오차 행렬
# [[ 181 1846]
#  [  18 1955]]
# 정확도: 0.5340, 정밀도: 0.5143, 재현율: 0.9909, F1: 0.6772, ROC-AUC: 0.5401
# ################################################################################
# 0.00576649307155419
# 오차 행렬
# [[ 182 1845]
#  [  18 1955]]
# 정확도: 0.5343, 정밀도: 0.5145, 재현율: 0.9909, F1: 0.6773, ROC-AUC: 0.5403
# ################################################################################
# 0.005773473255732123
# 오차 행렬
# [[ 183 1844]
#  [  18 1955]]
# 정확도: 0.5345, 정밀도: 0.5146, 재현율: 0.9909, F1: 0.6774, ROC-AUC: 0.5406
# ################################################################################
# 0.00578309452219075
# 오차 행렬
# [[ 184 1843]
#  [  18 1955]]
# 정확도: 0.5347, 정밀도: 0.5147, 재현율: 0.9909, F1: 0.6775, ROC-AUC: 0.5408
# ################################################################################
# 0.005853271342182545
# 오차 행렬
# [[ 185 1842]
#  [  18 1955]]
# 정확도: 0.5350, 정밀도: 0.5149, 재현율: 0.9909, F1: 0.6776, ROC-AUC: 0.5411
# ################################################################################
# 0.005902263693017413
# 오차 행렬
# [[ 186 1841]
#  [  18 1955]]
# 정확도: 0.5353, 정밀도: 0.5150, 재현율: 0.9909, F1: 0.6778, ROC-AUC: 0.5413
# ################################################################################
# 0.005918419579766261
# 오차 행렬
# [[ 186 1841]
#  [  19 1954]]
# 정확도: 0.5350, 정밀도: 0.5149, 재현율: 0.9904, F1: 0.6775, ROC-AUC: 0.5411
# ################################################################################
# 0.005924776293396183
# 오차 행렬
# [[ 187 1840]
#  [  19 1954]]
# 정확도: 0.5353, 정밀도: 0.5150, 재현율: 0.9904, F1: 0.6776, ROC-AUC: 0.5413
# ################################################################################
# 0.005926300319074673
# 오차 행렬
# [[ 188 1839]
#  [  19 1954]]
# 정확도: 0.5355, 정밀도: 0.5152, 재현율: 0.9904, F1: 0.6778, ROC-AUC: 0.5416
# ################################################################################
# 0.005982268807977804
# 오차 행렬
# [[ 188 1839]
#  [  20 1953]]
# 정확도: 0.5353, 정밀도: 0.5150, 재현율: 0.9899, F1: 0.6775, ROC-AUC: 0.5413
# ################################################################################
# 0.0060008329948433746
# 오차 행렬
# [[ 189 1838]
#  [  20 1953]]
# 정확도: 0.5355, 정밀도: 0.5152, 재현율: 0.9899, F1: 0.6777, ROC-AUC: 0.5416
# ################################################################################
# 0.006006405641867183
# 오차 행렬
# [[ 190 1837]
#  [  20 1953]]
# 정확도: 0.5357, 정밀도: 0.5153, 재현율: 0.9899, F1: 0.6778, ROC-AUC: 0.5418
# ################################################################################
# 0.006012795842247996
# 오차 행렬
# [[ 191 1836]
#  [  20 1953]]
# 정확도: 0.5360, 정밀도: 0.5154, 재현율: 0.9899, F1: 0.6779, ROC-AUC: 0.5420
# ################################################################################
# 0.006019704367930264
# 오차 행렬
# [[ 192 1835]
#  [  20 1953]]
# 정확도: 0.5363, 정밀도: 0.5156, 재현율: 0.9899, F1: 0.6780, ROC-AUC: 0.5423
# ################################################################################
# 0.006055481089151675
# 오차 행렬
# [[ 193 1834]
#  [  20 1953]]
# 정확도: 0.5365, 정밀도: 0.5157, 재현율: 0.9899, F1: 0.6781, ROC-AUC: 0.5425
# ################################################################################
# 0.006061105355465111
# 오차 행렬
# [[ 194 1833]
#  [  20 1953]]
# 정확도: 0.5367, 정밀도: 0.5158, 재현율: 0.9899, F1: 0.6782, ROC-AUC: 0.5428
# ################################################################################
# 0.006102737584888519
# 오차 행렬
# [[ 195 1832]
#  [  20 1953]]
# 정확도: 0.5370, 정밀도: 0.5160, 재현율: 0.9899, F1: 0.6784, ROC-AUC: 0.5430
# ################################################################################
# 0.006177541503843898
# 오차 행렬
# [[ 196 1831]
#  [  20 1953]]
# 정확도: 0.5373, 정밀도: 0.5161, 재현율: 0.9899, F1: 0.6785, ROC-AUC: 0.5433
# ################################################################################
# 0.006179310156107133
# 오차 행렬
# [[ 197 1830]
#  [  20 1953]]
# 정확도: 0.5375, 정밀도: 0.5163, 재현율: 0.9899, F1: 0.6786, ROC-AUC: 0.5435
# ################################################################################
# 0.00619585722949823
# 오차 행렬
# [[ 198 1829]
#  [  20 1953]]
# 정확도: 0.5377, 정밀도: 0.5164, 재현율: 0.9899, F1: 0.6787, ROC-AUC: 0.5438
# ################################################################################
# 0.006214727157062152
# 오차 행렬
# [[ 198 1829]
#  [  21 1952]]
# 정확도: 0.5375, 정밀도: 0.5163, 재현율: 0.9894, F1: 0.6785, ROC-AUC: 0.5435
# ################################################################################
# 0.0062340211489068965
# 오차 행렬
# [[ 199 1828]
#  [  21 1952]]
# 정확도: 0.5377, 정밀도: 0.5164, 재현율: 0.9894, F1: 0.6786, ROC-AUC: 0.5438
# ################################################################################
# 0.006265888111693843
# 오차 행렬
# [[ 200 1827]
#  [  21 1952]]
# 정확도: 0.5380, 정밀도: 0.5165, 재현율: 0.9894, F1: 0.6787, ROC-AUC: 0.5440
# ################################################################################
# 0.0062840831496694255
# 오차 행렬
# [[ 201 1826]
#  [  21 1952]]
# 정확도: 0.5383, 정밀도: 0.5167, 재현율: 0.9894, F1: 0.6788, ROC-AUC: 0.5443
# ################################################################################
# 0.006293596800851179
# 오차 행렬
# [[ 202 1825]
#  [  21 1952]]
# 정확도: 0.5385, 정밀도: 0.5168, 재현율: 0.9894, F1: 0.6790, ROC-AUC: 0.5445
# ################################################################################
# 0.006348693699357404
# 오차 행렬
# [[ 203 1824]
#  [  21 1952]]
# 정확도: 0.5387, 정밀도: 0.5169, 재현율: 0.9894, F1: 0.6791, ROC-AUC: 0.5448
# ################################################################################
# 0.00635248516741995
# 오차 행렬
# [[ 203 1824]
#  [  22 1951]]
# 정확도: 0.5385, 정밀도: 0.5168, 재현율: 0.9888, F1: 0.6788, ROC-AUC: 0.5445
# ################################################################################
# 0.006368124660359326
# 오차 행렬
# [[ 203 1824]
#  [  23 1950]]
# 정확도: 0.5383, 정밀도: 0.5167, 재현율: 0.9883, F1: 0.6786, ROC-AUC: 0.5442
# ################################################################################
# 0.006391147748853588
# 오차 행렬
# [[ 204 1823]
#  [  23 1950]]
# 정확도: 0.5385, 정밀도: 0.5168, 재현율: 0.9883, F1: 0.6787, ROC-AUC: 0.5445
# ################################################################################
# 0.006409123621281117
# 오차 행렬
# [[ 205 1822]
#  [  23 1950]]
# 정확도: 0.5387, 정밀도: 0.5170, 재현율: 0.9883, F1: 0.6789, ROC-AUC: 0.5447
# ################################################################################
# 0.006418642996607114
# 오차 행렬
# [[ 206 1821]
#  [  23 1950]]
# 정확도: 0.5390, 정밀도: 0.5171, 재현율: 0.9883, F1: 0.6790, ROC-AUC: 0.5450
# ################################################################################
# 0.006481784175096465
# 오차 행렬
# [[ 207 1820]
#  [  23 1950]]
# 정확도: 0.5393, 정밀도: 0.5172, 재현율: 0.9883, F1: 0.6791, ROC-AUC: 0.5452
# ################################################################################
# 0.006488365089101756
# 오차 행렬
# [[ 208 1819]
#  [  23 1950]]
# 정확도: 0.5395, 정밀도: 0.5174, 재현율: 0.9883, F1: 0.6792, ROC-AUC: 0.5455
# ################################################################################
# 0.006518225669118375
# 오차 행렬
# [[ 209 1818]
#  [  23 1950]]
# 정확도: 0.5397, 정밀도: 0.5175, 재현율: 0.9883, F1: 0.6793, ROC-AUC: 0.5457
# ################################################################################
# 0.006618059992212387
# 오차 행렬
# [[ 210 1817]
#  [  23 1950]]
# 정확도: 0.5400, 정밀도: 0.5177, 재현율: 0.9883, F1: 0.6794, ROC-AUC: 0.5460
# ################################################################################
# 0.006651929170202243
# 오차 행렬
# [[ 211 1816]
#  [  23 1950]]
# 정확도: 0.5403, 정밀도: 0.5178, 재현율: 0.9883, F1: 0.6796, ROC-AUC: 0.5462
# ################################################################################
# 0.006684120088047973
# 오차 행렬
# [[ 212 1815]
#  [  23 1950]]
# 정확도: 0.5405, 정밀도: 0.5179, 재현율: 0.9883, F1: 0.6797, ROC-AUC: 0.5465
# ################################################################################
# 0.006744359992665591
# 오차 행렬
# [[ 213 1814]
#  [  23 1950]]
# 정확도: 0.5407, 정밀도: 0.5181, 재현율: 0.9883, F1: 0.6798, ROC-AUC: 0.5467
# ################################################################################
# 0.006788124907285705
# 오차 행렬
# [[ 214 1813]
#  [  23 1950]]
# 정확도: 0.5410, 정밀도: 0.5182, 재현율: 0.9883, F1: 0.6799, ROC-AUC: 0.5470
# ################################################################################
# ...
# ################################################################################
# 0.9978078848821004
# 오차 행렬
# [[2022    5]
#  [1901   72]]
# 정확도: 0.5235, 정밀도: 0.9351, 재현율: 0.0365, F1: 0.0702, ROC-AUC: 0.5170
# ################################################################################
# 0.9978166807719919
# 오차 행렬
# [[2022    5]
#  [1902   71]]
# 정확도: 0.5232, 정밀도: 0.9342, 재현율: 0.0360, F1: 0.0693, ROC-AUC: 0.5168
# ################################################################################
# 0.9978286390387591
# 오차 행렬
# [[2022    5]
#  [1903   70]]
# 정확도: 0.5230, 정밀도: 0.9333, 재현율: 0.0355, F1: 0.0684, ROC-AUC: 0.5165
# ################################################################################
# 0.997839543034023
# 오차 행렬
# [[2022    5]
#  [1904   69]]
# 정확도: 0.5228, 정밀도: 0.9324, 재현율: 0.0350, F1: 0.0674, ROC-AUC: 0.5163
# ################################################################################
# 0.9978417355640813
# 오차 행렬
# [[2022    5]
#  [1905   68]]
# 정확도: 0.5225, 정밀도: 0.9315, 재현율: 0.0345, F1: 0.0665, ROC-AUC: 0.5160
# ################################################################################
# 0.9978428842829151
# 오차 행렬
# [[2022    5]
#  [1906   67]]
# 정확도: 0.5222, 정밀도: 0.9306, 재현율: 0.0340, F1: 0.0655, ROC-AUC: 0.5157
# ################################################################################
# 0.9978582072821822
# 오차 행렬
# [[2022    5]
#  [1907   66]]
# 정확도: 0.5220, 정밀도: 0.9296, 재현율: 0.0335, F1: 0.0646, ROC-AUC: 0.5155
# ################################################################################
# 0.9978881533746985
# 오차 행렬
# [[2022    5]
#  [1908   65]]
# 정확도: 0.5218, 정밀도: 0.9286, 재현율: 0.0329, F1: 0.0636, ROC-AUC: 0.5152
# ################################################################################
# 0.9979247224860899
# 오차 행렬
# [[2022    5]
#  [1909   64]]
# 정확도: 0.5215, 정밀도: 0.9275, 재현율: 0.0324, F1: 0.0627, ROC-AUC: 0.5150
# ################################################################################
# 0.9979304927034225
# 오차 행렬
# [[2022    5]
#  [1910   63]]
# 정확도: 0.5212, 정밀도: 0.9265, 재현율: 0.0319, F1: 0.0617, ROC-AUC: 0.5147
# ################################################################################
# 0.9979443274781399
# 오차 행렬
# [[2022    5]
#  [1911   62]]
# 정확도: 0.5210, 정밀도: 0.9254, 재현율: 0.0314, F1: 0.0608, ROC-AUC: 0.5145
# ################################################################################
# 0.9980125569223175
# 오차 행렬
# [[2022    5]
#  [1912   61]]
# 정확도: 0.5208, 정밀도: 0.9242, 재현율: 0.0309, F1: 0.0598, ROC-AUC: 0.5142
# ################################################################################
# 0.9980848642650251
# 오차 행렬
# [[2022    5]
#  [1913   60]]
# 정확도: 0.5205, 정밀도: 0.9231, 재현율: 0.0304, F1: 0.0589, ROC-AUC: 0.5140
# ################################################################################
# 0.9980908149114256
# 오차 행렬
# [[2022    5]
#  [1914   59]]
# 정확도: 0.5202, 정밀도: 0.9219, 재현율: 0.0299, F1: 0.0579, ROC-AUC: 0.5137
# ################################################################################
# 0.998168210935648
# 오차 행렬
# [[2022    5]
#  [1915   58]]
# 정확도: 0.5200, 정밀도: 0.9206, 재현율: 0.0294, F1: 0.0570, ROC-AUC: 0.5135
# ################################################################################
# 0.9981810953225897
# 오차 행렬
# [[2022    5]
#  [1916   57]]
# 정확도: 0.5198, 정밀도: 0.9194, 재현율: 0.0289, F1: 0.0560, ROC-AUC: 0.5132
# ################################################################################
# 0.9982364373871077
# 오차 행렬
# [[2022    5]
#  [1917   56]]
# 정확도: 0.5195, 정밀도: 0.9180, 재현율: 0.0284, F1: 0.0551, ROC-AUC: 0.5130
# ################################################################################
# 0.9982623694682303
# 오차 행렬
# [[2022    5]
#  [1918   55]]
# 정확도: 0.5192, 정밀도: 0.9167, 재현율: 0.0279, F1: 0.0541, ROC-AUC: 0.5127
# ################################################################################
# 0.9982996426177851
# 오차 행렬
# [[2022    5]
#  [1919   54]]
# 정확도: 0.5190, 정밀도: 0.9153, 재현율: 0.0274, F1: 0.0531, ROC-AUC: 0.5125
# ################################################################################
# 0.998300053818804
# 오차 행렬
# [[2022    5]
#  [1920   53]]
# 정확도: 0.5188, 정밀도: 0.9138, 재현율: 0.0269, F1: 0.0522, ROC-AUC: 0.5122
# ################################################################################
# 0.9983149833777858
# 오차 행렬
# [[2023    4]
#  [1920   53]]
# 정확도: 0.5190, 정밀도: 0.9298, 재현율: 0.0269, F1: 0.0522, ROC-AUC: 0.5124
# ################################################################################
# 0.9983635791156966
# 오차 행렬
# [[2023    4]
#  [1921   52]]
# 정확도: 0.5188, 정밀도: 0.9286, 재현율: 0.0264, F1: 0.0513, ROC-AUC: 0.5122
# ################################################################################
# 0.9983720526150639
# 오차 행렬
# [[2023    4]
#  [1922   51]]
# 정확도: 0.5185, 정밀도: 0.9273, 재현율: 0.0258, F1: 0.0503, ROC-AUC: 0.5119
# ################################################################################
# 0.998465838552047
# 오차 행렬
# [[2023    4]
#  [1923   50]]
# 정확도: 0.5182, 정밀도: 0.9259, 재현율: 0.0253, F1: 0.0493, ROC-AUC: 0.5117
# ################################################################################
# 0.9984823877198026
# 오차 행렬
# [[2023    4]
#  [1924   49]]
# 정확도: 0.5180, 정밀도: 0.9245, 재현율: 0.0248, F1: 0.0484, ROC-AUC: 0.5114
# ################################################################################
# 0.9984906291919966
# 오차 행렬
# [[2023    4]
#  [1925   48]]
# 정확도: 0.5178, 정밀도: 0.9231, 재현율: 0.0243, F1: 0.0474, ROC-AUC: 0.5112
# ################################################################################
# 0.9985354410023389
# 오차 행렬
# [[2023    4]
#  [1926   47]]
# 정확도: 0.5175, 정밀도: 0.9216, 재현율: 0.0238, F1: 0.0464, ROC-AUC: 0.5109
# ################################################################################
# 0.9986061730080315
# 오차 행렬
# [[2023    4]
#  [1927   46]]
# 정확도: 0.5172, 정밀도: 0.9200, 재현율: 0.0233, F1: 0.0455, ROC-AUC: 0.5107
# ################################################################################
# 0.9986066444141088
# 오차 행렬
# [[2023    4]
#  [1928   45]]
# 정확도: 0.5170, 정밀도: 0.9184, 재현율: 0.0228, F1: 0.0445, ROC-AUC: 0.5104
# ################################################################################
# 0.9986725438047379
# 오차 행렬
# [[2023    4]
#  [1929   44]]
# 정확도: 0.5168, 정밀도: 0.9167, 재현율: 0.0223, F1: 0.0435, ROC-AUC: 0.5102
# ################################################################################
# 0.9987588049925843
# 오차 행렬
# [[2023    4]
#  [1930   43]]
# 정확도: 0.5165, 정밀도: 0.9149, 재현율: 0.0218, F1: 0.0426, ROC-AUC: 0.5099
# ################################################################################
# 0.9987731795096029
# 오차 행렬
# [[2023    4]
#  [1931   42]]
# 정확도: 0.5162, 정밀도: 0.9130, 재현율: 0.0213, F1: 0.0416, ROC-AUC: 0.5097
# ################################################################################
# 0.9988021604906774
# 오차 행렬
# [[2023    4]
#  [1932   41]]
# 정확도: 0.5160, 정밀도: 0.9111, 재현율: 0.0208, F1: 0.0406, ROC-AUC: 0.5094
# ################################################################################
# 0.9988093198884112
# 오차 행렬
# [[2023    4]
#  [1933   40]]
# 정확도: 0.5158, 정밀도: 0.9091, 재현율: 0.0203, F1: 0.0397, ROC-AUC: 0.5092
# ################################################################################
# 0.9988186307571972
# 오차 행렬
# [[2023    4]
#  [1934   39]]
# 정확도: 0.5155, 정밀도: 0.9070, 재현율: 0.0198, F1: 0.0387, ROC-AUC: 0.5089
# ################################################################################
# 0.9988369117357011
# 오차 행렬
# [[2023    4]
#  [1935   38]]
# 정확도: 0.5152, 정밀도: 0.9048, 재현율: 0.0193, F1: 0.0377, ROC-AUC: 0.5086
# ################################################################################
# 0.9988726392302012
# 오차 행렬
# [[2023    4]
#  [1936   37]]
# 정확도: 0.5150, 정밀도: 0.9024, 재현율: 0.0188, F1: 0.0367, ROC-AUC: 0.5084
# ################################################################################
# 0.9989189675941859
# 오차 행렬
# [[2023    4]
#  [1937   36]]
# 정확도: 0.5148, 정밀도: 0.9000, 재현율: 0.0182, F1: 0.0358, ROC-AUC: 0.5081
# ################################################################################
# 0.998920152262414
# 오차 행렬
# [[2024    3]
#  [1937   36]]
# 정확도: 0.5150, 정밀도: 0.9231, 재현율: 0.0182, F1: 0.0358, ROC-AUC: 0.5084
# ################################################################################
# 0.9989208691774354
# 오차 행렬
# [[2024    3]
#  [1938   35]]
# 정확도: 0.5148, 정밀도: 0.9211, 재현율: 0.0177, F1: 0.0348, ROC-AUC: 0.5081
# ################################################################################
# 0.9989343897953419
# 오차 행렬
# [[2024    3]
#  [1939   34]]
# 정확도: 0.5145, 정밀도: 0.9189, 재현율: 0.0172, F1: 0.0338, ROC-AUC: 0.5079
# ################################################################################
# 0.9989516743407065
# 오차 행렬
# [[2024    3]
#  [1940   33]]
# 정확도: 0.5142, 정밀도: 0.9167, 재현율: 0.0167, F1: 0.0329, ROC-AUC: 0.5076
# ################################################################################
# 0.9989593560666025
# 오차 행렬
# [[2024    3]
#  [1941   32]]
# 정확도: 0.5140, 정밀도: 0.9143, 재현율: 0.0162, F1: 0.0319, ROC-AUC: 0.5074
# ################################################################################
# 0.998992418253888
# 오차 행렬
# [[2024    3]
#  [1942   31]]
# 정확도: 0.5138, 정밀도: 0.9118, 재현율: 0.0157, F1: 0.0309, ROC-AUC: 0.5071
# ################################################################################
# 0.9990669407506036
# 오차 행렬
# [[2024    3]
#  [1943   30]]
# 정확도: 0.5135, 정밀도: 0.9091, 재현율: 0.0152, F1: 0.0299, ROC-AUC: 0.5069
# ################################################################################
# 0.9991227492225123
# 오차 행렬
# [[2024    3]
#  [1944   29]]
# 정확도: 0.5132, 정밀도: 0.9062, 재현율: 0.0147, F1: 0.0289, ROC-AUC: 0.5066
# ################################################################################
# 0.9991666275120973
# 오차 행렬
# [[2024    3]
#  [1945   28]]
# 정확도: 0.5130, 정밀도: 0.9032, 재현율: 0.0142, F1: 0.0279, ROC-AUC: 0.5064
# ################################################################################
# 0.9992773854221608
# 오차 행렬
# [[2024    3]
#  [1946   27]]
# 정확도: 0.5128, 정밀도: 0.9000, 재현율: 0.0137, F1: 0.0270, ROC-AUC: 0.5061
# ################################################################################
# 0.9992986803855947
# 오차 행렬
# [[2024    3]
#  [1947   26]]
# 정확도: 0.5125, 정밀도: 0.8966, 재현율: 0.0132, F1: 0.0260, ROC-AUC: 0.5058
# ################################################################################
# 0.9993238732945747
# 오차 행렬
# [[2024    3]
#  [1948   25]]
# 정확도: 0.5122, 정밀도: 0.8929, 재현율: 0.0127, F1: 0.0250, ROC-AUC: 0.5056
# ################################################################################
# 0.9993451529875018
# 오차 행렬
# [[2024    3]
#  [1949   24]]
# 정확도: 0.5120, 정밀도: 0.8889, 재현율: 0.0122, F1: 0.0240, ROC-AUC: 0.5053
# ################################################################################
# 0.9993658271770982
# 오차 행렬
# [[2024    3]
#  [1950   23]]
# 정확도: 0.5118, 정밀도: 0.8846, 재현율: 0.0117, F1: 0.0230, ROC-AUC: 0.5051
# ################################################################################
# 0.9993751350867827
# 오차 행렬
# [[2024    3]
#  [1951   22]]
# 정확도: 0.5115, 정밀도: 0.8800, 재현율: 0.0112, F1: 0.0220, ROC-AUC: 0.5048
# ################################################################################
# 0.9993787905946455
# 오차 행렬
# [[2025    2]
#  [1951   22]]
# 정확도: 0.5118, 정밀도: 0.9167, 재현율: 0.0112, F1: 0.0220, ROC-AUC: 0.5051
# ################################################################################
# 0.9994317599382694
# 오차 행렬
# [[2025    2]
#  [1952   21]]
# 정확도: 0.5115, 정밀도: 0.9130, 재현율: 0.0106, F1: 0.0210, ROC-AUC: 0.5048
# ################################################################################
# 0.9994673083815729
# 오차 행렬
# [[2025    2]
#  [1953   20]]
# 정확도: 0.5112, 정밀도: 0.9091, 재현율: 0.0101, F1: 0.0201, ROC-AUC: 0.5046
# ################################################################################
# 0.9994890794579055
# 오차 행렬
# [[2025    2]
#  [1954   19]]
# 정확도: 0.5110, 정밀도: 0.9048, 재현율: 0.0096, F1: 0.0191, ROC-AUC: 0.5043
# ################################################################################
# 0.9995028853553468
# 오차 행렬
# [[2025    2]
#  [1955   18]]
# 정확도: 0.5108, 정밀도: 0.9000, 재현율: 0.0091, F1: 0.0181, ROC-AUC: 0.5041
# ################################################################################
# 0.9995194706433677
# 오차 행렬
# [[2025    2]
#  [1956   17]]
# 정확도: 0.5105, 정밀도: 0.8947, 재현율: 0.0086, F1: 0.0171, ROC-AUC: 0.5038
# ################################################################################
# 0.9995265833494289
# 오차 행렬
# [[2025    2]
#  [1957   16]]
# 정확도: 0.5102, 정밀도: 0.8889, 재현율: 0.0081, F1: 0.0161, ROC-AUC: 0.5036
# ################################################################################
# 0.9995568191679257
# 오차 행렬
# [[2025    2]
#  [1958   15]]
# 정확도: 0.5100, 정밀도: 0.8824, 재현율: 0.0076, F1: 0.0151, ROC-AUC: 0.5033
# ################################################################################
# 0.9995569695020536
# 오차 행렬
# [[2025    2]
#  [1959   14]]
# 정확도: 0.5098, 정밀도: 0.8750, 재현율: 0.0071, F1: 0.0141, ROC-AUC: 0.5031
# ################################################################################
# 0.9995810126270245
# 오차 행렬
# [[2025    2]
#  [1960   13]]
# 정확도: 0.5095, 정밀도: 0.8667, 재현율: 0.0066, F1: 0.0131, ROC-AUC: 0.5028
# ################################################################################
# 0.9996775217053322
# 오차 행렬
# [[2025    2]
#  [1961   12]]
# 정확도: 0.5092, 정밀도: 0.8571, 재현율: 0.0061, F1: 0.0121, ROC-AUC: 0.5025
# ################################################################################
# 0.9996788465023058
# 오차 행렬
# [[2025    2]
#  [1962   11]]
# 정확도: 0.5090, 정밀도: 0.8462, 재현율: 0.0056, F1: 0.0111, ROC-AUC: 0.5023
# ################################################################################
# 0.9996920875168662
# 오차 행렬
# [[2025    2]
#  [1963   10]]
# 정확도: 0.5088, 정밀도: 0.8333, 재현율: 0.0051, F1: 0.0101, ROC-AUC: 0.5020
# ################################################################################
# 0.9997182297304533
# 오차 행렬
# [[2025    2]
#  [1964    9]]
# 정확도: 0.5085, 정밀도: 0.8182, 재현율: 0.0046, F1: 0.0091, ROC-AUC: 0.5018
# ################################################################################
# 0.9997198881820852
# 오차 행렬
# [[2025    2]
#  [1965    8]]
# 정확도: 0.5082, 정밀도: 0.8000, 재현율: 0.0041, F1: 0.0081, ROC-AUC: 0.5015
# ################################################################################
# 0.9997233449052748
# 오차 행렬
# [[2025    2]
#  [1966    7]]
# 정확도: 0.5080, 정밀도: 0.7778, 재현율: 0.0035, F1: 0.0071, ROC-AUC: 0.5013
# ################################################################################
# 0.9997593841872741
# 오차 행렬
# [[2026    1]
#  [1966    7]]
# 정확도: 0.5082, 정밀도: 0.8750, 재현율: 0.0035, F1: 0.0071, ROC-AUC: 0.5015
# ################################################################################
# 0.999781152039965
# 오차 행렬
# [[2026    1]
#  [1967    6]]
# 정확도: 0.5080, 정밀도: 0.8571, 재현율: 0.0030, F1: 0.0061, ROC-AUC: 0.5013
# ################################################################################
# 0.999794858700993
# 오차 행렬
# [[2026    1]
#  [1968    5]]
# 정확도: 0.5078, 정밀도: 0.8333, 재현율: 0.0025, F1: 0.0051, ROC-AUC: 0.5010
# ################################################################################
# 0.9998017697216298
# 오차 행렬
# [[2027    0]
#  [1968    5]]
# 정확도: 0.5080, 정밀도: 1.0000, 재현율: 0.0025, F1: 0.0051, ROC-AUC: 0.5013
# ################################################################################
# 0.9998186356600901
# 오차 행렬
# [[2027    0]
#  [1969    4]]
# 정확도: 0.5078, 정밀도: 1.0000, 재현율: 0.0020, F1: 0.0040, ROC-AUC: 0.5010
# ################################################################################
# 0.9998616154575021
# 오차 행렬
# [[2027    0]
#  [1970    3]]
# 정확도: 0.5075, 정밀도: 1.0000, 재현율: 0.0015, F1: 0.0030, ROC-AUC: 0.5008
# ################################################################################
# 0.9998851317057144
# 오차 행렬
# [[2027    0]
#  [1971    2]]
# 정확도: 0.5072, 정밀도: 1.0000, 재현율: 0.0010, F1: 0.0020, ROC-AUC: 0.5005
# ################################################################################
# 0.9999134148726222
# 오차 행렬
# [[2027    0]
#  [1972    1]]
# 정확도: 0.5070, 정밀도: 1.0000, 재현율: 0.0005, F1: 0.0010, ROC-AUC: 0.5003
# ################################################################################
# 0.9999217663036395
# 오차 행렬
# [[2027    0]
#  [1973    0]]
# 정확도: 0.5068, 정밀도: 0.0000, 재현율: 0.0000, F1: 0.0000, ROC-AUC: 0.5000
# ################################################################################
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
from sklearn.preprocessing import Binarizer

threshold = 0.2711612913222499

proba = lgbm.predict_proba(X_test)
prediction = lgbm.predict(X_test)

# %%
custom_proba = proba[:, 1].reshape(-1, 1)
binarizer = Binarizer(threshold=threshold).fit(custom_proba)
custom_prediction = binarizer.transform(custom_proba)

get_evaluation_by_custom_proba(y_test, custom_prediction, visualize=True)
# Out:
# 오차 행렬
# [[1744  283]
#  [ 141 1832]]
# 정확도: 0.8940, 정밀도: 0.8662, 재현율: 0.9285, F1: 0.8963, ROC-AUC: 0.8945
# ################################################################################

# %%
from sklearn.preprocessing import Binarizer

threshold = 0.2711612913222499

proba = lgbm.predict_proba(X_test)
prediction = lgbm.predict(X_test)
lgbm_ac1 = round(accuracy_score(y_test, custom_prediction), 4)
lgbm_pr1 = round(precision_score(y_test, custom_prediction), 4)
lgbm_f11 = round(f1_score(y_test, custom_prediction), 4)
lgbm_rc1 = round(recall_score(y_test, custom_prediction), 4)
lgbm_rac1 = round(roc_auc_score(y_test, custom_prediction), 4)

# %%
lgbm_rc1
# Out:
# 0.9285

# %%
from sklearn.metrics import roc_curve

def roc_curve_plot(y_test , proba_class1):
#     임계값에 따른 FPR, TPR 값
    fprs, tprs, thresholds = roc_curve(y_test, proba_class1)

#     ROC Curve를 plot 곡선으로 그림. 
    plt.plot(fprs , tprs, label='ROC')
#     가운데 대각선 직선을 그림. 
#     TPR과 FPR이 동일한 비율로 떨어진다는 것은 모델이 양성과 음성을 구별하지 못한다는 것을 의미한다.
#     다른 분류기를 판단하기 위한 기준선으로 사용되며, 
#     대각선에 가까울 수록 예측에 사용하기 힘든 모델이라는 뜻이다.
    plt.plot([0, 1], [0, 1], 'k--', label='Standard')
    
    # X축(FPR)의 Scale을 0.1 단위로 변경
    start, end = plt.xlim()
    plt.xticks(np.round(np.arange(start, end, 0.1),2))
    plt.xlim(0,1); plt.ylim(0,1)
    plt.xlabel('FPR( 1 - Sensitivity )'); plt.ylabel('TPR( Recall )')
    plt.legend()
    plt.show()
    
roc_curve_plot(y_test, custom_prediction)

# %%
import matplotlib.pyplot as plt

# Setting up the fonts and figure
plt.rcParams['font.family'] = 'Malgun Gothic'

# Data for the graphs
metrics = {
    '정확도': [lgbm_ac, lgbm_ac1],
    '정밀도': [lgbm_pr, lgbm_pr1],
    '재현율': [lgbm_rc, lgbm_rc1],
    'F1 점수': [lgbm_f1, lgbm_f11],
    'ROC-AUC': [lgbm_rac, lgbm_rac1]
}

colors = ['beige', 'darkolivegreen']
classifiers = ['Previous LGBM', 'Next LGBM']

# Plotting
for metric, values in metrics.items():
    plt.figure(figsize=(10, 6))
    plt.bar(classifiers, values, color=colors)
    plt.xlabel('분류기법')
    plt.ylabel(metric)
    plt.title(f'{metric} 점수 비교')
    plt.ylim(0, 1)

    for i, v in enumerate(values):
        plt.text(i, v + 0.01, str(v), color='black', ha='center')

    plt.show()

# %% [markdown]
# ### 6. Upgrade 결과
#
# 먼저 최초 <strong>Previous LGBM</strong>과 임계치를 수정하여 얻은 <strong>Next LGBM</strong>의 차이를 살펴보도록 하겠다.
#
# 기존의 <strong>Previous LGBM</strong>에서 <strong>임계치(threshold)</strong>의 값은 <strong>0.5</strong>로
# <strong>정확도: 0.8935, 정밀도: 0.8877, 재현율: 0.8976, F1: 0.8926, ROC-AUC: 0.8936</strong> 였다.
# 그리고 <strong>임계치를 0.2711612913222499</strong>로 <strong>조정</strong>한 <strong>Next LGBM</strong>에서
# <strong>정확도: 0.8940, 정밀도: 0.8662, 재현율: 0.9285, F1: 0.8963, ROC-AUC: 0.8945</strong> 으로 <strong>약간의 차이</strong>가 있었다.
# 자세히 살펴본다면, <strong>정확도, 재현율, F1, ROC-AUC 모두 아주 미세하게 상승</strong> 하였지만, 정밀도도 아주 미세하게 감소 하였다.
# <strong>재현율이 상승은</strong> 당초 수립했던 '정밀도와 재현율'의 방향에 <strong>부합한 변화</strong>라고 할 수 있다.
