# %% [markdown]
# ### Cross Validation Task

# %% [markdown]
# ### 약물 A, B, C, X, Y
# ##### 다중 분류(Multiclass Classification)
# - 의학 연구원으로서 동일한 질병을 앓고 있는 일련의 환자에 대한 데이터를 수집했다.
# - 치료 과정 동안 각 환자는 5가지 약물, 즉 약물 A, 약물 B, 약물 c, 약물 x 및 y 중 하나에 반응했다.
# -  미래에 동일한 질병을 앓는 환자에게 어떤 약물이 적합할 수 있는지 알아보기 위한 모델을 구축한다.

# %% [markdown]
# featur
# - Age: 환자의 나이
# - Sex: 환자의 성별
# - BP: 혈압
# - Cholesterol: 콜레스테롤 수치
# - Na_to_K: 나트륨-칼륨
#
# target
# - Drug: 의약품, 환자에게 효과가 있던 약

# %%
import pandas as pd
drug_df = pd.read_csv('./datasets/drugs.csv')
drug_df
# Out:
#      Age Sex      BP Cholesterol  Na_to_K   Drug
# 0     23   F    HIGH        HIGH   25.355  drugY
# 1     47   M     LOW        HIGH   13.093  drugC
# 2     47   M     LOW        HIGH   10.114  drugC
# 3     28   F  NORMAL        HIGH    7.798  drugX
# 4     61   F     LOW        HIGH   18.043  drugY
# ..   ...  ..     ...         ...      ...    ...
# 195   56   F     LOW        HIGH   11.567  drugC
# 196   16   M     LOW        HIGH   12.006  drugC
# 197   52   M  NORMAL        HIGH    9.894  drugX
# 198   23   M  NORMAL      NORMAL   14.020  drugX
# 199   40   F     LOW      NORMAL   11.349  drugX
#
# [200 rows x 6 columns]

# %%
# 각 feature에 있는 값들을 모두 숫자로 바꿈

drug_df['Sex'] = drug_df['Sex'].replace({'F': 0, 'M': 1})
drug_df['BP'] = drug_df['BP'].replace({'LOW': 0, 'NORMAL': 1, 'HIGH' : 2})
drug_df['Cholesterol'] = drug_df['Cholesterol'].replace({'LOW': 0, 'NORMAL': 1, 'HIGH' : 2})
drug_df
# Out:
#      Age  Sex  BP  Cholesterol  Na_to_K   Drug
# 0     23    0   2            2   25.355  drugY
# 1     47    1   0            2   13.093  drugC
# 2     47    1   0            2   10.114  drugC
# 3     28    0   1            2    7.798  drugX
# 4     61    0   0            2   18.043  drugY
# ..   ...  ...  ..          ...      ...    ...
# 195   56    0   0            2   11.567  drugC
# 196   16    1   0            2   12.006  drugC
# 197   52    1   1            2    9.894  drugX
# 198   23    1   1            1   14.020  drugX
# 199   40    0   0            1   11.349  drugX
#
# [200 rows x 6 columns]

# %%
drug_df.isna().sum()
# Out:
# Age            0
# Sex            0
# BP             0
# Cholesterol    0
# Na_to_K        0
# Drug           0
# dtype: int64

# %%
na_to_k_df = drug_df.loc[:, 'Na_to_K'].reset_index()
na_to_k_df
# Out:
#      index  Na_to_K
# 0        0   25.355
# 1        1   13.093
# 2        2   10.114
# 3        3    7.798
# 4        4   18.043
# ..     ...      ...
# 195    195   11.567
# 196    196   12.006
# 197    197    9.894
# 198    198   14.020
# 199    199   11.349
#
# [200 rows x 2 columns]

# %%
# target의 값을 표준화
from sklearn.preprocessing import StandardScaler

std = StandardScaler()
std_na_to_k = std.fit_transform(na_to_k_df[['Na_to_K']])
std_na_to_k
# Out:
# array([[ 1.28652212],
#        [-0.4151454 ],
#        [-0.82855818],
#        [-1.14996267],
#        [ 0.27179427],
#        [-1.03769314],
#        [ 0.02643885],
#        [-0.70046821],
#        [-0.12676951],
#        [ 0.45567206],
#        [-0.59916196],
#        [ 0.43221897],
#        [-0.09832049],
#        [ 0.674105  ],
#        [-0.46926791],
#        [-0.0788919 ],
#        [-0.64245998],
#        [-0.29316156],
#        [-1.21935052],
#        [ 1.37242427],
#        [ 0.42236589],
#        [ 1.36451406],
#        [ 2.00995979],
#        [-0.14550423],
#        [ 2.41490725],
#        [ 0.37809645],
#        [ 1.9819271 ],
#        [-0.93028076],
#        [ 0.91765633],
#        [ 0.25902691],
#        [-1.01784822],
#        [-0.90446848],
#        [-0.70366006],
#        [ 2.19147839],
#        [-0.27081868],
#        [-1.2211546 ],
#        [-0.92139911],
#        [-0.29787994],
#        [-0.88476233],
#        [-0.97149714],
#        [ 0.43527203],
#        [-0.25610845],
#        [-0.04086736],
#        [-0.53074555],
#        [-0.5258884 ],
#        [-1.10708099],
#        [-0.41542295],
#        [-0.80399488],
#        [ 2.16511101],
#        [ 0.51506806],
#        [ 0.46233329],
#        [-0.71975804],
#        [ 1.54020408],
#        [ 0.32924741],
#        [-0.81815   ],
#        [-0.26707173],
#        [-0.65841918],
#        [ 1.62943685],
#        [-0.83175002],
#        [ 0.36338623],
#        [ 1.91378824],
#        [-0.91723584],
#        [ 0.63954985],
#        [-1.07058298],
#        [-0.3860025 ],
#        [ 1.52174691],
#        [-0.44803523],
#        [-0.72891723],
#        [ 1.18979546],
#        [ 1.13678315],
#        [-0.29385544],
#        [ 0.4982762 ],
#        [-0.76041931],
#        [ 0.94652168],
#        [ 0.13662675],
#        [ 0.6695254 ],
#        [-0.67812533],
#        [ 0.42694549],
#        [-0.38461474],
#        [-0.72780703],
#        [-0.29843504],
#        [-1.15509738],
#        [-0.884346  ],
#        [-0.66036204],
#        [-0.83508063],
#        [-0.29829626],
#        [-0.34520245],
#        [-0.08416537],
#        [ 0.97233395],
#        [ 0.1563329 ],
#        [ 0.0707083 ],
#        [-0.12885115],
#        [ 1.85480857],
#        [ 1.82996772],
#        [-0.14841852],
#        [-0.64676202],
#        [ 3.07561832],
#        [ 1.29207314],
#        [ 2.71369132],
#        [ 0.08888791],
#        [-0.58472929],
#        [-0.44831279],
#        [-0.41042702],
#        [-0.98787267],
#        [ 1.69438387],
#        [-0.98759512],
#        [-0.57334968],
#        [ 0.54518238],
#        [-0.88920315],
#        [ 0.10623487],
#        [-1.19270559],
#        [-1.30469757],
#        [-0.95956243],
#        [-0.32133303],
#        [-0.94415833],
#        [ 0.30676574],
#        [-0.91182359],
#        [-0.83008471],
#        [-0.8038561 ],
#        [ 1.3031752 ],
#        [ 1.52368977],
#        [ 0.15563902],
#        [ 0.88421139],
#        [ 0.09277363],
#        [-0.49813326],
#        [ 1.37173039],
#        [ 0.0364307 ],
#        [-1.14344022],
#        [ 2.42267869],
#        [-1.19450967],
#        [ 0.61123961],
#        [ 2.33663776],
#        [-0.34506367],
#        [ 1.34633444],
#        [ 0.68714991],
#        [-0.57529254],
#        [-0.70879476],
#        [-0.44276176],
#        [-0.65800285],
#        [-0.83535819],
#        [-1.36215071],
#        [ 1.34008953],
#        [-1.03575028],
#        [-0.08999395],
#        [-0.89100724],
#        [-0.92167666],
#        [-0.56599457],
#        [-0.52422309],
#        [-1.21352194],
#        [-1.10097486],
#        [-1.024787  ],
#        [-0.70435393],
#        [-1.22448522],
#        [-0.20018185],
#        [ 0.08874914],
#        [-0.76985606],
#        [-0.67410083],
#        [ 0.95457067],
#        [-0.7827622 ],
#        [-0.43873726],
#        [-0.78290097],
#        [-0.85201127],
#        [-0.44761891],
#        [ 1.74129005],
#        [ 0.40557404],
#        [ 0.30676574],
#        [ 1.46554276],
#        [-0.2593003 ],
#        [ 0.96012169],
#        [-0.66924368],
#        [-0.44484339],
#        [-0.84201942],
#        [ 0.15827576],
#        [ 0.36838215],
#        [-0.46052505],
#        [ 0.31412086],
#        [-0.78248465],
#        [ 0.40612914],
#        [-0.01602651],
#        [-0.02685101],
#        [ 0.93444819],
#        [-0.30537382],
#        [-0.61040279],
#        [-0.08250007],
#        [ 2.92865486],
#        [ 1.36118344],
#        [-0.86533373],
#        [-0.788452  ],
#        [ 2.62459732],
#        [ 0.67271724],
#        [ 0.40335363],
#        [-1.12040345],
#        [ 0.031296  ],
#        [-1.29276286],
#        [ 2.58143808],
#        [-0.6269171 ],
#        [-0.56599457],
#        [-0.85908883],
#        [-0.28650033],
#        [-0.6571702 ]])

# %%
na_to_k_df['Na_to_K'] = std_na_to_k
na_to_k_df
# Out:
#      index   Na_to_K
# 0        0  1.286522
# 1        1 -0.415145
# 2        2 -0.828558
# 3        3 -1.149963
# 4        4  0.271794
# ..     ...       ...
# 195    195 -0.626917
# 196    196 -0.565995
# 197    197 -0.859089
# 198    198 -0.286500
# 199    199 -0.657170
#
# [200 rows x 2 columns]

# %%
cond1 = na_to_k_df['Na_to_K'] >= -1.96
cond2 = na_to_k_df['Na_to_K'] <= 1.96
cond = cond1&cond2

drug_df = drug_df.iloc[na_to_k_df[cond].index].reset_index(drop=True)
drug_df
# Out:
#      Age  Sex  BP  Cholesterol  Na_to_K   Drug
# 0     23    0   2            2   25.355  drugY
# 1     47    1   0            2   13.093  drugC
# 2     47    1   0            2   10.114  drugC
# 3     28    0   1            2    7.798  drugX
# 4     61    0   0            2   18.043  drugY
# ..   ...  ...  ..          ...      ...    ...
# 183   56    0   0            2   11.567  drugC
# 184   16    1   0            2   12.006  drugC
# 185   52    1   1            2    9.894  drugX
# 186   23    1   1            1   14.020  drugX
# 187   40    0   0            1   11.349  drugX
#
# [188 rows x 6 columns]

# %%
drug_enc_df = drug_df.copy()

# %%
drug_enc_df
# Out:
#      Age  Sex  BP  Cholesterol  Na_to_K   Drug
# 0     23    0   2            2   25.355  drugY
# 1     47    1   0            2   13.093  drugC
# 2     47    1   0            2   10.114  drugC
# 3     28    0   1            2    7.798  drugX
# 4     61    0   0            2   18.043  drugY
# ..   ...  ...  ..          ...      ...    ...
# 183   56    0   0            2   11.567  drugC
# 184   16    1   0            2   12.006  drugC
# 185   52    1   1            2    9.894  drugX
# 186   23    1   1            1   14.020  drugX
# 187   40    0   0            1   11.349  drugX
#
# [188 rows x 6 columns]

# %%
from sklearn.preprocessing import LabelEncoder

drug_encoder = LabelEncoder()

targets = drug_encoder.fit_transform(drug_df['Drug'].tolist())
drug_enc_df['Drug'] = targets

gender_encoder = LabelEncoder()
genders = gender_encoder.fit_transform(drug_df['Sex'].tolist())
drug_enc_df['Sex'] = genders

blood_pressure_encoder = LabelEncoder()
blood_pressures = blood_pressure_encoder.fit_transform(drug_df['BP'].tolist())
drug_enc_df['BP'] = blood_pressures

choleserol_encoder = LabelEncoder()
choleserols = choleserol_encoder.fit_transform(drug_df['Cholesterol'].tolist())
drug_enc_df['Cholesterol'] = choleserols

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.metrics import accuracy_score
import numpy as np

features, targets = drug_enc_df.iloc[:,:-1] , drug_enc_df.iloc[:,-1]

X_train, X_test, y_train, y_test = \
train_test_split(features, targets, test_size=0.2, random_state=124)

dtc = DecisionTreeClassifier()
parameters = {'max_depth': [2, 3, 4], 'min_samples_split': [15, 16, 17]}

# %%
g_dtc = GridSearchCV(dtc, 
              param_grid=parameters,
              cv=5,
              refit=True,
              return_train_score=True,
              n_jobs=-1)

# %%
g_dtc.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(), n_jobs=-1,
#              param_grid={'max_depth': [2, 3, 4],
#                          'min_samples_split': [15, 16, 17]},
#              return_train_score=True)

# %%
g_dtc.cv_results_
# Out:
# {'mean_fit_time': array([0.00440021, 0.00439963, 0.00420136, 0.00280027, 0.00239987,
#         0.00260134, 0.00240002, 0.00220032, 0.00219994]),
#  'std_fit_time': array([0.00048992, 0.00048941, 0.00074898, 0.00074853, 0.00080016,
#         0.00049112, 0.00049   , 0.00039926, 0.00039981]),
#  'mean_score_time': array([0.00179954, 0.00200109, 0.00139923, 0.00100045, 0.00180149,
#         0.0012001 , 0.00160017, 0.0013999 , 0.00140162]),
#  'std_score_time': array([4.00401312e-04, 2.62650287e-06, 4.89825395e-04, 1.57717089e-06,
#         4.00548095e-04, 3.99638090e-04, 4.90193622e-04, 4.88986999e-04,
#         4.88656089e-04]),
#  'param_max_depth': masked_array(data=[2, 2, 2, 3, 3, 3, 4, 4, 4],
#               mask=[False, False, False, False, False, False, False, False,
#                     False],
#         fill_value='?',
#              dtype=object),
#  'param_min_samples_split': masked_array(data=[15, 16, 17, 15, 16, 17, 15, 16, 17],
#               mask=[False, False, False, False, False, False, False, False,
#                     False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'max_depth': 2, 'min_samples_split': 15},
#   {'max_depth': 2, 'min_samples_split': 16},
#   {'max_depth': 2, 'min_samples_split': 17},
#   {'max_depth': 3, 'min_samples_split': 15},
#   {'max_depth': 3, 'min_samples_split': 16},
#   {'max_depth': 3, 'min_samples_split': 17},
#   {'max_depth': 4, 'min_samples_split': 15},
#   {'max_depth': 4, 'min_samples_split': 16},
#   {'max_depth': 4, 'min_samples_split': 17}],
#  'split0_test_score': array([0.86666667, 0.86666667, 0.86666667, 0.8       , 0.8       ,
#         0.8       , 1.        , 1.        , 1.        ]),
#  'split1_test_score': array([0.8, 0.8, 0.8, 0.9, 0.9, 0.9, 1. , 1. , 1. ]),
#  'split2_test_score': array([0.8, 0.8, 0.8, 0.9, 0.9, 0.9, 1. , 1. , 1. ]),
#  'split3_test_score': array([0.8       , 0.8       , 0.8       , 0.83333333, 0.83333333,
#         0.83333333, 0.96666667, 0.96666667, 0.96666667]),
#  'split4_test_score': array([0.83333333, 0.83333333, 0.83333333, 0.93333333, 0.93333333,
#         0.93333333, 1.        , 1.        , 1.        ]),
#  'mean_test_score': array([0.82      , 0.82      , 0.82      , 0.87333333, 0.87333333,
#         0.87333333, 0.99333333, 0.99333333, 0.99333333]),
#  'std_test_score': array([0.02666667, 0.02666667, 0.02666667, 0.04898979, 0.04898979,
#         0.04898979, 0.01333333, 0.01333333, 0.01333333]),
#  'rank_test_score': array([7, 7, 7, 4, 4, 4, 1, 1, 1]),
#  'split0_train_score': array([0.81666667, 0.81666667, 0.81666667, 0.91666667, 0.91666667,
#         0.91666667, 1.        , 1.        , 1.        ]),
#  'split1_train_score': array([0.83333333, 0.83333333, 0.83333333, 0.91666667, 0.91666667,
#         0.91666667, 1.        , 1.        , 1.        ]),
#  'split2_train_score': array([0.83333333, 0.83333333, 0.83333333, 0.90833333, 0.90833333,
#         0.90833333, 1.        , 1.        , 1.        ]),
#  'split3_train_score': array([0.825     , 0.825     , 0.825     , 0.93333333, 0.93333333,
#         0.93333333, 1.        , 1.        , 1.        ]),
#  'split4_train_score': array([0.825     , 0.825     , 0.825     , 0.90833333, 0.90833333,
#         0.90833333, 1.        , 1.        , 1.        ]),
#  'mean_train_score': array([0.82666667, 0.82666667, 0.82666667, 0.91666667, 0.91666667,
#         0.91666667, 1.        , 1.        , 1.        ]),
#  'std_train_score': array([0.0062361 , 0.0062361 , 0.0062361 , 0.00912871, 0.00912871,
#         0.00912871, 0.        , 0.        , 0.        ])}

# %%
result_df = pd.DataFrame(g_dtc.cv_results_)
result_df
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.004400      0.000490         0.001800        0.000400
# 1       0.004400      0.000489         0.002001        0.000003
# 2       0.004201      0.000749         0.001399        0.000490
# 3       0.002800      0.000749         0.001000        0.000002
# 4       0.002400      0.000800         0.001801        0.000401
# 5       0.002601      0.000491         0.001200        0.000400
# 6       0.002400      0.000490         0.001600        0.000490
# 7       0.002200      0.000399         0.001400        0.000489
# 8       0.002200      0.000400         0.001402        0.000489
#
#   param_max_depth param_min_samples_split  \
# 0               2                      15
# 1               2                      16
# 2               2                      17
# 3               3                      15
# 4               3                      16
# 5               3                      17
# 6               4                      15
# 7               4                      16
# 8               4                      17
#
#                                       params  split0_test_score  \
# 0  {'max_depth': 2, 'min_samples_split': 15}           0.866667
# 1  {'max_depth': 2, 'min_samples_split': 16}           0.866667
# 2  {'max_depth': 2, 'min_samples_split': 17}           0.866667
# 3  {'max_depth': 3, 'min_samples_split': 15}           0.800000
# 4  {'max_depth': 3, 'min_samples_split': 16}           0.800000
# 5  {'max_depth': 3, 'min_samples_split': 17}           0.800000
# 6  {'max_depth': 4, 'min_samples_split': 15}           1.000000
# 7  {'max_depth': 4, 'min_samples_split': 16}           1.000000
# 8  {'max_depth': 4, 'min_samples_split': 17}           1.000000
#
#    split1_test_score  split2_test_score  ...  mean_test_score  std_test_score  \
# 0                0.8                0.8  ...         0.820000        0.026667
# 1                0.8                0.8  ...         0.820000        0.026667
# 2                0.8                0.8  ...         0.820000        0.026667
# 3                0.9                0.9  ...         0.873333        0.048990
# 4                0.9                0.9  ...         0.873333        0.048990
# 5                0.9                0.9  ...         0.873333        0.048990
# 6                1.0                1.0  ...         0.993333        0.013333
# 7                1.0                1.0  ...         0.993333        0.013333
# 8                1.0                1.0  ...         0.993333        0.013333
#
#    rank_test_score  split0_train_score  split1_train_score  \
# 0                7            0.816667            0.833333
# 1                7            0.816667            0.833333
# 2                7            0.816667            0.833333
# 3                4            0.916667            0.916667
# 4                4            0.916667            0.916667
# 5                4            0.916667            0.916667
# 6                1            1.000000            1.000000
# 7                1            1.000000            1.000000
# 8                1            1.000000            1.000000
#
#    split2_train_score  split3_train_score  split4_train_score  \
# 0            0.833333            0.825000            0.825000
# 1            0.833333            0.825000            0.825000
# 2            0.833333            0.825000            0.825000
# 3            0.908333            0.933333            0.908333
# 4            0.908333            0.933333            0.908333
# 5            0.908333            0.933333            0.908333
# 6            1.000000            1.000000            1.000000
# 7            1.000000            1.000000            1.000000
# 8            1.000000            1.000000            1.000000
#
#    mean_train_score  std_train_score
# 0          0.826667         0.006236
# 1          0.826667         0.006236
# 2          0.826667         0.006236
# 3          0.916667         0.009129
# 4          0.916667         0.009129
# 5          0.916667         0.009129
# 6          1.000000         0.000000
# 7          1.000000         0.000000
# 8          1.000000         0.000000
#
# [9 rows x 22 columns]

# %%
print(g_dtc.best_params_, g_dtc.best_score_, sep="\n")
# Out:
# {'max_depth': 4, 'min_samples_split': 15}
# 0.9933333333333334

# %%
g_dtc.best_estimator_
# Out:
# DecisionTreeClassifier(max_depth=4, min_samples_split=15)

# %%
dtc = g_dtc.best_estimator_
prediction = dtc.predict(X_test)
# round(accuracy_score(y_test, prediction), 4)
accuracy_score(y_test, prediction)
# Out:
# 0.9736842105263158
